# %% [markdown]
# ### Preprocessing ASAP-AES
#
# 1. Preprocessing
# 2. Calculating NLP features from Uto et al. (2020)

# %%
import numpy as np
import pandas as pd

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

set3 = pd.read_csv('set3_features.csv')
# set3['lemmatized'] = set3['essay'].apply(lambda x: ' '.join([token.lemma_ for token in nlp(x)]))

# %%
data = pd.read_csv('training_set_rel3.tsv', sep='\t', encoding='ISO-8859-1')
data.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         1          1  Dear local newspaper, I think effects computer...
# 1         2          1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2         3          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3         4          1  Dear Local Newspaper, @CAPS1 I have found that...
# 4         5          1  Dear @LOCATION1, I know having computers has a...
#
#    rater1_domain1  rater2_domain1  rater3_domain1  domain1_score  \
# 0               4               4             NaN              8
# 1               5               4             NaN              9
# 2               4               3             NaN              7
# 3               5               5             NaN             10
# 4               4               4             NaN              8
#
#    rater1_domain2  rater2_domain2  domain2_score  ...  rater2_trait3  \
# 0             NaN             NaN            NaN  ...            NaN
# 1             NaN             NaN            NaN  ...            NaN
# 2             NaN             NaN            NaN  ...            NaN
# 3             NaN             NaN            NaN  ...            NaN
# 4             NaN             NaN            NaN  ...            NaN
#
#    rater2_trait4  rater2_trait5  rater2_trait6  rater3_trait1  rater3_trait2  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    rater3_trait3  rater3_trait4  rater3_trait5  rater3_trait6
# 0            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN
#
# [5 rows x 28 columns]

# %%
set3 = data[data['essay_set'] == 3]
set4 = data[data['essay_set'] == 4]
set5 = data[data['essay_set'] == 5]
set6 = data[data['essay_set'] == 6]

# %%
import re
import string
from spacy.tokenizer import Tokenizer
from spacy.lang.en import English
import spacy
from spellchecker import SpellChecker
import textstat

nlp = spacy.load('en_core_web_sm')

spell = SpellChecker()
english = English()
tokenizer = Tokenizer(english.vocab)

def count_commas(text):
  count = 0  
  for i in range (0, len(text)):   
    if text[i] == ',':  
        count = count + 1
  return count

def count_exclamation_marks(text):
  count = 0 
  for i in range (0, len(text)):   
    if text[i] == '!':  
        count = count + 1
  return count

def count_question_marks(text):
    count = 0
    for i in range (0, len(text)):
        if text[i] == '?':  
            count = count + 1
    return count

def lemmatize(text):
    doc = nlp(text)
    return [token.lemma_ for token in doc]

def average_word_length(text):
    sentences = [sent.text for sent in nlp(text).sents]
    length_words = 0
    total_words = 0
    for sentence in sentences:
        words = tokenizer(sentence)
        for word in words:
            length_words += len(word)
            total_words += 1
    return length_words / total_words

def average_sentence_length(text):
    sentences = [sent.text for sent in nlp(text).sents]
    length_sentences = 0
    total_sentences = 0
    for sentence in sentences:
        length_sentences += len(tokenizer(sentence))
        total_sentences += 1
    return length_sentences / total_sentences

def number_of_nouns(text):
    # find number of nouns in text
    doc = nlp(text)
    pos = [token.pos_ for token in doc]
    return pos.count('NOUN') + pos.count('PROPN')

def number_of_verbs(text):
    # find number of verbs in text
    doc = nlp(text)
    pos = [token.pos_ for token in doc]
    return pos.count('VERB')

def number_of_adverbs(text):
    # find number of adverbs in text
    doc = nlp(text)
    pos = [token.pos_ for token in doc]
    return pos.count('ADV')

def number_of_adjectives(text):
    # find number of adjectives in text
    doc = nlp(text)
    pos = [token.pos_ for token in doc]
    return pos.count('ADJ')

def number_of_conjunctions(text):
    # find number of conjunctions in text
    doc = nlp(text)
    pos = [token.pos_ for token in doc]
    return pos.count('CCONJ')

def number_of_spelling_errors(text):
    misspelled = spell.unknown([token.text for token in tokenizer(text)])
    return len(misspelled)

def num_stopwords(text):
    # find number of stopwords in text
    doc = nlp(text)
    stop_words = [token.text for token in doc if token.is_stop]
    return len(stop_words)

# %% [markdown]
# ### Features
#
# <img src="./features.jpeg" width="600">

# %%
def generate_features(frame):
    data = frame.copy()
    # length-based features
    print('Calculating number of words...')
    data['num_words'] = data['essay'].apply(lambda x: len(x.split()))
    print('Calculating number of sentences...')
    data['num_sentences'] = data['essay'].apply(lambda x: len(list(nlp(x).sents)))
    print('Calculating number of lemmas...')
    data['num_lemmas'] = data['essay'].apply(lambda x: len(lemmatize(x)))
    print('Calculating number of commas...')
    data['num_commas'] = data['essay'].apply(lambda x: count_commas(x))
    print('Calculating number of exclamation marks...')
    data['num_exclamation_marks'] = data['essay'].apply(lambda x: count_exclamation_marks(x))
    print('Calculating number of question marks...')
    data['num_question_marks'] = data['essay'].apply(lambda x: count_question_marks(x))
    print('Calculating average word length...')
    data['average_word_length'] = data['essay'].apply(lambda x: average_word_length(x))
    print('Calculating average sentence length...')
    data['average_sentence_length'] = data['essay'].apply(lambda x: average_sentence_length(x))

    # synctatic features
    print('Calculating number of nouns...')
    data['num_nouns'] = data['essay'].apply(lambda x: number_of_nouns(x))
    print('Calculating number of verbs...')
    data['num_verbs'] = data['essay'].apply(lambda x: number_of_verbs(x))
    print('Calculating number of adjectives...')
    data['num_adjectives'] = data['essay'].apply(lambda x: number_of_adjectives(x))
    print('Calculating number of adverbs...')
    data['num_adverbs'] = data['essay'].apply(lambda x: number_of_adverbs(x))
    print('Calculating number of conjunctions...')
    data['num_conjunctions'] = data['essay'].apply(lambda x: number_of_conjunctions(x))

    # word-based features
    print('Calculating number of spelling errors...')
    data['num_spelling_errors'] = data['essay'].apply(lambda x: number_of_spelling_errors(x))
    print('Calculating number of stopwords...')
    data['num_stopwords'] = data['essay'].apply(lambda x: num_stopwords(x))

    # readability features
    print('Calculating readability features...')
    data['automated_readability_index'] = data['essay'].apply(lambda x: textstat.automated_readability_index(x))
    data['coleman_liau_index'] = data['essay'].apply(lambda x: textstat.coleman_liau_index(x))
    data['dale_chall_index'] = data['essay'].apply(lambda x: textstat.dale_chall_readability_score(x))
    data['difficult_word_count'] = data['essay'].apply(lambda x: textstat.difficult_words(x))
    data['flesch_kincaid_grade'] = data['essay'].apply(lambda x: textstat.flesch_kincaid_grade(x))
    data['gunning_fog'] = data['essay'].apply(lambda x: textstat.gunning_fog(x))
    data['linsear_write_formula'] = data['essay'].apply(lambda x: textstat.linsear_write_formula(x))
    data['smog_index'] = data['essay'].apply(lambda x: textstat.smog_index(x))
    data['syllables_count'] = data['essay'].apply(lambda x: textstat.syllable_count(x))
    
    print('done')
    return data

# %% [markdown]
# ### Split into sets

# %%
def split_in_sets(data):
    essay_sets = []
    min_scores = []
    max_scores = []
    for s in range(1,9):
        essay_set = data[data["essay_set"] == s]
        essay_set.dropna(axis=1, inplace=True)
        n, d = essay_set.shape
        set_scores = essay_set["domain1_score"]
        print ("Set", s, ": Essays = ", n , "\t Attributes = ", d)
        min_scores.append(set_scores.min())
        max_scores.append(set_scores.max())
        essay_sets.append(essay_set)
    return (essay_sets, min_scores, max_scores)

# %%
essay_sets, data_min_scores, data_max_scores = split_in_sets(data)
set1, set2, set3, set4, set5, set6, set7, set8 = tuple(essay_sets)
# Out:
# Set 1 : Essays =  1783 	 Attributes =  7
# Set 2 : Essays =  1800 	 Attributes =  10
# Set 3 : Essays =  1726 	 Attributes =  7
# Set 4 : Essays =  1770 	 Attributes =  7
# Set 5 : Essays =  1805 	 Attributes =  7
# Set 6 : Essays =  1800 	 Attributes =  7
# Set 7 : Essays =  1569 	 Attributes =  15
# Set 8 : Essays =  723 	 Attributes =  19
# /Users/SidharrthNagappan/.virtualenvs/multitask-bert/lib/python3.8/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
set3 = generate_features(set3)
set4 = generate_features(set4)
set5 = generate_features(set5)
set6 = generate_features(set6)
# Out:
# Calculating number of words...
# Calculating number of sentences...
# Calculating number of lemmas...
# Calculating number of commas...
# Calculating number of exclamation marks...
# Calculating number of question marks...
# Calculating average word length...
# Calculating average sentence length...
# Calculating number of nouns...
# Calculating number of verbs...
# Calculating number of adjectives...
# Calculating number of adverbs...
# Calculating number of conjunctions...
# Calculating number of spelling errors...
# Calculating number of stopwords...
# Calculating readability features...
# done
# Calculating number of words...
# Calculating number of sentences...
# Calculating number of lemmas...
# Calculating number of commas...
# Calculating number of exclamation marks...
# Calculating number of question marks...
# Calculating average word length...
# Calculating average sentence length...
# Calculating number of nouns...
# Calculating number of verbs...
# Calculating number of adjectives...
# Calculating number of adverbs...
# Calculating number of conjunctions...
# Calculating number of spelling errors...
# Calculating number of stopwords...
# Calculating readability features...
# done
# Calculating number of words...
# Calculating number of sentences...
# Calculating number of lemmas...
# Calculating number of commas...
# Calculating number of exclamation marks...
# Calculating number of question marks...
# Calculating average word length...
# Calculating average sentence length...
# Calculating number of nouns...
# Calculating number of verbs...
# Calculating number of adjectives...
# Calculating number of adverbs...
# Calculating number of conjunctions...
# Calculating number of spelling errors...
# Calculating number of stopwords...
# Calculating readability features...
# done
# Calculating number of words...
# Calculating number of sentences...
# Calculating number of lemmas...
# Calculating number of commas...
# Calculating number of exclamation marks...
# Calculating number of question marks...
# Calculating average word length...
# Calculating average sentence length...
# Calculating number of nouns...
# Calculating number of verbs...
# Calculating number of adjectives...
# Calculating number of adverbs...
# Calculating number of conjunctions...
# Calculating number of spelling errors...
# Calculating number of stopwords...
# Calculating readability features...
# done

# %%
set3.to_csv('set3_features.csv', index=False)
set4.to_csv('set4_features.csv', index=False)
set5.to_csv('set5_features.csv', index=False)
set6.to_csv('set6_features.csv', index=False)

# %% [markdown]
# ### Keyword Selection

# %%
def get_quotes(text):
    quotes = re.findall(r'"([^"]*)"', text)
    return quotes

# %%
set3_keywords = set()
for i in set3['essay']:
    unicode_converted = i.replace("\x93", '"').replace("\x94", '"')
    quotes = get_quotes(unicode_converted)
    if len(quotes) > 0:
        print(quotes, "\n")
        set3_keywords.update(quotes)
# Out:
# ['I was traveling through the high deserts of California in June.', 'brackish water faling somewhere in the neighborhood of two hundred degrees', 'The sun was beginning to beat down', ' and the growing realization that I could drop from heatstroke on a gorgous day in June', 'About forty miles into the pedal, I arrived at the first \x91town\x92 but on that morning it fit the traditional definition of a ghost town.']
#
# ['town', 'One ramshackle sheds several rusty pumps and a coral that couldnt hold the lamesh mule.', 'In the story the speeker says ', ' that are very hot and dry, and he says ']
#
# ['Rough Road Ahead: Do Not Exceed Posted Speed Limit', 'The water bottles contained only a few tantalizing sips.']
#
# ['Rough Road Ahead: Do Not Exceed Posted Speed Limit', 'the sun was beginning to beat down.', 'The water bottle contained only dehydration which can cause death. Joe Kurmaskie\x92s story, ']
#
# [' shortcut', ' Flat road was repalced by short rolling hills.', ' I wiped the sweat from my eyes to make sure it wasn\x92t a mirage, and tried not to get too excited with what I believed was my last burst of energy. I manouvered down the hill.', ' success is not final, failure is not fatal: it is the courage it takes to continues that counts.']
#
# ['I eased past, trying to keep my balance in my dehydrated state.', 'Wide rings of dried sweat circled my shirt, and the growing realization that I could drop from heat stroke']
#
# ['Rough Road Ahead:Do Not Exceed Posted Speed Limit,', 'flat road was replaced by short rolling hills.']
#
# ['Rough Road Ahead']
#
# ['a tarlike substance oozed out', 'short, rolling hills', 'tumble weeds crossed my path and a ridiculously large snake']
#
# ['ghost town']
#
# ['Do Not Exceed Posted Speed Limit']
#
# ['somewhere in the neighborhood of two hundred degrees. The cyclist also had to deal with a lot of ']
#
# ['town']
#
# ['dehydration', 'death.']
#
# ['I could drop from a heatstroke']
#
# ['I rode into the morning with strong legs and a smile on my face.', 'sometimes life can feel so cruel']
#
# ['Do Not Exceed posted speed Limit']
#
# ['no one in sight, not a building, car, or structure of any kind.', 'The water bottle contained only a few tantalizing sips.', ' one long, crippling hill.']
#
# ['I wiped the sweat from my eyes to make sure it wasn\x92t a mirage, and tried not to get too excited.']
#
# ['battery acid,']
#
# ['rough road ahead :do not exceed posted limit']
#
# ['I chuckled, checked my water supply, and moved on.', 'This sight was troubling', 'At some point, tumble weed crossed my path and a ridiculously large snake', 'I was going to die and the birds would pick me clean.', 'I had overwhelming urge to seek out Gary and Wilber, Kiss them and buy some bait.']
#
# ['Rough road ahead: do not exceed speed limit', 'The sun was beginning to beat down', 'shortcut.', 'one ramshackle shop, several rusty pumps and a corral that couldn\x92t hold the lamest male.', 'battery-acid', 'had an overwhelming urge to seek out @ORGANIZATION1, kiss them and buy some bait.']
#
# ['Rough Road Ahead: Do not Exceed Posted Speed Limit.', 'Flat road was replaced by short, rolling hills.', 'The water bottle contained only a few tontalizing sips.']
#
# ['traveling through the high deserts of @LOCATION1 in June.', 'water feeling somewhere in the neighborhood of two hundred degrees.', 'Flat road was replaced by short, rolling hills,']
#
# ['Rough Road ahead', 'I had been huting my water pretty regularly... the high deserts of California in June']
#
# ['Do Not Exceed Posted Speed Limit', 'through the high desert of california in June.', 'a tarlike substance followed by brackish water', 'l cald drop from heat stroke on a gorgeous day in June.']
#
# ['old timers who haven\x92t left the confines of their porches since Carter was in office', 'Flat road was replaced by short rolling hills']
#
# ['Do not exceed posted speed limit', 'he stops and asks for directions to Yosemite state park']
#
# ['Flat road was replaced by short rolling hills', 'I toiled on at some point tumbleweed crossed my path', 'Summer time']
#
# ['Do not exceed posted speed limit']
#
# ['the cool pines and rushing rivers\x85']
#
# ['I eased past, trying to keep my balance in my dehydrated state']
#
# ['Do Not Exceed Posted Speed Limit']
#
# ['I had been hitting my water bottles pretty regularly', 'Flat road was replaced by short, rolling hills.', ' I was doing a water-depleting 12 mph']
#
# ['\x85. I came to a fork of sorts, One ramshackle shed, several rusty pumps, and a corral that couldn\x92t hold in the largest mule greeted me. This side was troubling. ', 'Not two miles into this next section of ride, I notice the terrain changing. Flat road was replaced by short, rolling hills. ']
#
# ['I was travelling through the high parts of California in June', 'I toiled on.At some point,tumbleweeds crossed my path t a ridiculously larger skilt it really did look like adiamond back']
#
# ['The sun was beginning to beat down.']
#
# ['I was traveling through the high deserts of california in june.', 'the growing realization that I could drop from heatstroke. ', 'I was going to die and the birds would pick me clean. ']
#
# ['town', 'town']
#
# ['short rolling hills,', 'ridiculously large snake,']
#
# ['I brely noticed it [the sun], the cool pines and rushing hills of Yosemite had my name written all over them. Although the cyclist began to feel the toll that the trip and the sun was going to take on him, he erased the morning with the hope and bealy of arriving at Yosemite. The more the cyclist noticedthe sun the more he drank untill his water supply seemed low, striping as an old rusty water pump he had hope of being replenished but the taste of bitter battery acid caused the cyclist to stop drinking. The rolling hills, Sun and tumbleweds did nothing to quech the cyclist thirst or at least divert his assertion. If the cyclists was to see a sign that said Yosemite @NUM1 miles away his spirits would have risen, instead he saw a sign that said, ']
#
# ['Do not exceed posted speed limit']
#
# ['Somewhere in the neighborhood of two hundred degrees.', 'tumbleweeds crossed my path and a ridiculously large snake.', 'no one in sight, not a building, car, or structure of any kind.']
#
# ['the high deserts of California in June,']
#
# ['The water bottles contained only a few tantalizing sips.', 'Not two miles into the next section.', 'I noticed the terrain changing, flat road was replaced by short, rolling hills.']
#
# ['Rough Road Ahead: Do Not Exceed Posted Speed Limit,', 'resevoir compground', 'the serenity of an early-summer evening and he\x92s headed toward ', ' He\x92s in a beautiful setting and this affects the cyclist because he\x92s anticipating another one. However, when he moves to the ', ' and the ', ' he\x92s less confident and becoming more doubtful about the mens advice. However, he\x92s still optimistic, finally it funny that it was once ', ' Next, when the cyclist comes to ', ' he knows that things are in bad shape and he @CAPS1 water. However, all the have is a ', ' so he moves on, having no choice. When he comes to the ', ' it effects the cyclist by letting him know that things are at their worst and he can either give up, or keep pushing through. I doubt it could get any worse, and so does the cyclist. Finally, at the end the cyclists enters a rather modern bathroom']
#
# ['There was no one in sight, not a building, or structure of any kind.', 'In an ironic twist the building abandoned years easlier, by the looks of it-had been a Welch\x92s Grape Juice factory', 'GRAPE AND @CAPS1\x92S FISH CAMP']
#
# ['Flat road was replaced by short, rolling hills.', 'Over on long, crippling hill', 'crippling']
#
# ['several rusty bumps,']
#
# ['Rough Road Ahead: Do Not Exceed Posted Speed Limit', ' and the growing realization that I could drop from a heatstroke on a gorgeous day in June simply because ', 'A sand blasted picture of a young boy pouring a refreshing glass of juice into his mouth could still be seen.']
#
# ['there was none in sight, not a building, car or structure of any kind']
#
# ['The sun was beginning to beat down', 'Flat road was replaced by short, rolling hills', 'I stubled into a rather modern in bathroom and drank deeply from the sink']
#
# ['DO NOT Exceed posted speed limit,', '\x85 of two hundred degrees, deteriorating brain, birds would pick me up clean and drop from heatstroke.']
#
# ['Rough Road ahead', 'I had been hitting my water bottles quite regularly', 'a ridiculously large snake blocked the majority of the pavement in front of me.']
#
# ['Rough Road Ahead: Do Not Exceed Posted Speed Limit,', 'I rode in the morning with strong legs and a smile on my face.', 'The cool pines and rushing rivers of Yosemite had my name written all over them.', 'traveling through the high deserts of California in June', 'At some point, tumbleweeds crossed my path and a ridiculously larg snake - it really did look like a diamondback-blocked the majority of the pavement in front of me.']
#
# ['Rough Road Ahead, Do Not Exceed Posted Speed Limit, ', '\x85A young   pouring a refreshing glass of juice into his mouth could still be seen. I hung  my head ', ' At some point, tumbleweeds crossed my path...']
#
# ['a ghost town.', 'traveling through the deserts of California in June.']
#
# ['Rough @CAPS2 ahead: Do not Exceed posted Speed Limit.']
#
# ['This place might have been a thriving little spot at one time-say, before the last world war-but on that morning it fit the tradition of a ghost town.', 'One ramshackle shed, several rusty pumps, and a coral they couldn\x92t had in the larger mule greeted me.', 'old timers']
#
# ['toun']
#
# ['@CAPS1 Juice']
#
# ['Do not exceed speed limit', 'The high deserts of California in June', 'over one long, crippling hill,', 'There was no one in sight, not a building, car, or structure of any kind.']
#
# ['the cool pines and rushing rivers of Yosemite had my name written all over them.', ' flat road was replaced by short, rolling hills.']
#
# ['Wide rings of dried sweat circled my shirt', 'The water bottles contained only a few tantalizing sips', 'With any luck I\x92d hit a bump and lodge one in my throat']
#
# ['Do Not @CAPS1 Posted Speed Limit', ' I pumped that handle for several minutes but the water wouldn\x92t calm down nor I tried a drip or two,it had the flaver of beatterly acid.When @CAPS2 set out for the next train @CAPS2 came to a road that read ']
#
# ['I could drop from heat stroke on a gorgerous day in June ', 'ROUGH ROAD AHEAD:DO NOT EXCEED POSTED SPEED LIMIT.']
#
# [' I was gonna die and the birds would pick me clean', 'I own a very good map']
#
# ['ramshackeled sched, several rusty bumps and the corral\x85 This sight troubled me. In the desert his water tasted like the flavor of ', ' It also goes on to say that it was a ']
#
# ['long and a               ']
#
# ['california in June. This obviously is going to have an affect on him because it will be very fast. At one point he says, \x91The sun was beginning to beat down, but I barely noticed.', 'I wiped the sweat from my eyes to make sure it wasn\x92t a mirage\x85']
#
# [' The cool pines and rushing rivers of Yosemite my name written all it ', 'So he had to pedal harder and would tire him faster.']
#
# ['Rough Road Ahead: Do Not Exceed Posted Speed Limit', 'The sun was beginning to beat down']
#
# ['The cool pines and rushing rivers of Yosemite had my name written all over them,', 'slowly gaining elevation while losing hope.']
#
# ['Rough Road Ahead: Do Not Exceed speed Limit']
#
# ['Do not exceed posted speed limit', 'a young boy pouring a refreshing glass of juice into his mouth,']
#
# ['wide rings of dried sweat']
#
# ['town', 'The cool pires and rushing rivers of Yosemite had my name written all over them,', 'troubling sights']
#
# ['the sun was beginning to beat down and l was traveling through the high deserts of California in June.', 'ridiculously large snake', 'trying to keep his balance in his dehydrates state. Kurmaskie ran out of water, due to the extreme heat, and upon reaching a water pump, finds the water to be unfit for drinking and ']
#
# ['@CAPS1\x92t exceed @CAPS2 Speed Limit.']
#
# ['It was sad, hopeless laught, mind you, but at least I still had energy to feel bad for self.']
#
# ['Do Not Exceed Posted Speed Limit,', 'I was doing a water-depleting @NUM1,']
#
# ['I arrived at the first ', '. This place might have been a thriving little spot at one time... refer the @NUM1 word war.', 'I pumped the handle for several minutes but the water wouldn\x92t cool down.']
#
# ['flat road was replaced by short, rolling hills.', 'high deserts of California in June.', 'summer time']
#
# ['Rough Road ahead: Do Not Exceed Posted Speed Limit', 'shortcut', 'Gary and Wilber\x92s fish camp', 'Gary and Wilber\x92s fish camp']
#
# ['Rough Road Ahead', 'The water bottles contained only a few tantalizing sips.']
#
# ['Rough Road Ahead']
#
# ['ghost town']
#
# [' The water bottle contained only a few tantalizing sips. Wide rings of dried sweat circled my shirt, and the growing realization that I could drop from heat stroke on a gorgeous day in June.', '. One more thing that got in his way was the poisonous snake.']
#
# [' Then he was going to wrong direction and he wasn\x92t prepared for the journey because the weather condition was']
#
# ['I had been hitting my water bottles pretty regularly, and I was traveling through the high deserts of California in June.', 'trying to keep my balance in my dehydrated state.', '\x85I could drop from heatstroke\x85', 'I was going to die and the birds would pick me clean\x85']
#
# ['There was no one in sight, not a building, car, or structure of any kind', 'working the handle of the rusted water pump with all my strength', 'Flat road was replaced by short, rolling hills', 'I was traveling through the high deserts of California in June']
#
# ['wiped the sweat from my eyes to make sure it wasn\x92t a mirage.']
#
# ['Do not exceed the posted speed limit', 'There was no one in sight, not a building, car, or structure of any kind.']
#
# ['Rough Road Ahead Do Not Exceed Posted Speed Limit', 'The water bottles contained only a few tantalizing sips, wide rings of dried sweat circled my shirt, and the growing realization that I needed a drop from heatstroke on a gorgeous day in June\x85']
#
# ['Over are long, crippling hill...', '...tumbleweeds crossed my path and a ridiculously large snake it really did look like a diamondbuck-blooked the majority of the pavement in front of me.']
#
# ['Rough road ahead.']
#
# [' he isn\x92t really warried he is kind of laughing and thinks his funny by saying.', ' Then after he says that it ways he chuckled. When he gets the dark in the road with the risky pipe of water he begins to switch into conservation made and begins to get is scared. He says.']
#
# ['Do not exceed posted speed limit, the faetures of the setting effect the cyclist. To keep cool on a hot summer day, is might be neccessary for one to find shade. Just to add to the misfortune of the story. There was no one in eight, not a building, car or structure of any kind.', 'The water bottle contained only a few tatalizing sips.', 'flat roads was replaced by short, rolling hills.']
#
# ['Wide rings of dried sweat circled my shirt, and the growing realization that I could drop from a heat stroke...laugh.']
#
# ['Rough Road Ahead. Do not exceed posted speed limit.', 'First ', ' This place might have been a thriving little spot at one point but anthor warning it fit the outsides of ghost town']
#
# ['Rough Road Ahead: Do Not Exceed Posted Speed Limit']
#
# ['Rough Road Ahead: Do Not Exceed Posted Speed Limit', 'I was traveling through the high deserts of California in June.', 'ghost town', 'Rough Road Ahead,', 'Rough Road Ahead: Do Not Exceed Posted Speed Limit.']
#
# ['Do not exceed the posted speed limit', 'There was no one in sight, not a building, car, or structure of any kind. I began breaking the ride down into distances I could see on the horizon telling myself that if I could make it that far , I\x92d be fine', 'It didn\x92t really matter. I was going to die and the birds would pick me clean leaving only some expensive outdoor gear and a diary', 'Rough Road Ahead']
#
# ['Gary and wilbells fish camp.']
#
# ['Do not exceed posted speed limit.']
#
# ['I wipe the sweat from my eyes.']
#
# [' Rough road ahead: do non excee posted speed limit.', 'old-timers', "they'd  sounded so sure of themselves when pointing off out land marks and spouting off towns  I would come to along this breezy aunt."]
#
# [' yes sir! I own a very good map']
#
# ['Do Not Exceed Posted Speed Limit', 'denyoved the serenity of an early- summer- evening.', 'denyoyed', 'At some point, tumble weeds crossed my path and the growing realization that I could drop from heatstroke']
#
# ['short, rolling hills', 'tumbleweeds and ridiculously large snakes.']
#
# ['Do not exceed posted speed limit', '.I could drop from heat stroke, on a gorgeous day in June.', 'Old timers who haven\x92t left the confines of their perches since water was in offing']
#
# ['Do not exeed posted speed limit', 'I noticed the terrain changing flat road was replaced by short, rolling hills.', 'At some point, tumbleweeds crossed my path', 'Do not exceed posted speed limit']
#
# ['Rough road ahead', 'The water bottles contain only a few tantalizing sips. wide rings of dried sweat circled my shirt,']
#
# ['Rough road Ahead, do not exceed posted speed limit', 'Then, as easily as randing a bend my troubles, thirst, and fear were all behind me.']
#
# ['A sand blasted picture of a young boy pouring a refreshing glass of juice into his mouth could still be seen. I hung my head.', ' Somehow I climed away from the abandoned factory of juices and dreams, slowly gaining elevation while losing hope.', ' @CAPS1 is when he saw ']
#
# ['the high deserts California in June,', 'rolling hills', 'ROUGH ROAD AHEAD: DO NOT EXCEED POSTED SPEED LIMIT']
#
# ['When I tried a drop it had the flavor of battery acid', 'the growing realization that I could drop from heatstroke caused me to laugh,']
#
# ['Do Not Exceed Posted Speed Limit.', 'It didn\x92t really matter. I was going to die\x85']
#
# ['rough road ahead: do not exceed posted speed limit.']
#
# ['Rough Road Ahead: Do Not Exceed Posted Speed Limit', 'I could drop from heat stroke']
#
# ['Trying to keep my balance in my dehydrated state. The water bottles contained only a few tantalizing sips.', ' I was traveling through the high deserts of California in June.', ' Because I listened to some gentlemen who hadn\x92t been off their porch in decades, caused me to laugh.']
#
# ['. ', 'After he got threw the hills, he came to a sigh ', '.  Now he has to go through bumply roads. ', '. Now the poor guy had to deal with snakes bigger than him! Thankfully he got by the snake, alive. ', '. The man thinks he found someplace to get water, but its an abonded building . ']
#
# ['the sun was beating on me']
#
# ['Rough Road Ahead: Do Not Exceed Posted Speed Limit,', 'There was no one in sight, not a building, car, structure of any kind. ']
#
# ['Do not exceed posted spedd limit', 'town', 'this place might have been a thriving little spot at one time \x96 say, before the last world war.', 'The sight was troubling.']
#
# ['Rough Road Ahead', 'I was going to die and the birds would pick me clean.']
#
# ['Do Not Exceed Posted Speed Limit', 'Ghost towns', 'what I believed was my last burst of energy,', 'I was going to die.']
#
# ['I had been hitting my water bottles pretty regularly, and I was traveling through the high deserts of California in June.', 'A tarlike substance oozed out, followed by brackish water feeling somewhere in the neighborhood of two hundred degrees.']
#
# ['Rough Rode Ahead', 'I eased past trying to keep my balance in my dehydrated @NUM1). The narrator is really really taking a beating from the travel and this rocks, dry climate is really takens a tale. From reading this story the setting does not do any good for him other than the general store he finds in the end. Like the title states the setting of this story was a ']
#
# ['Rough Road Ahead Do Not Exceed Posted Speed Limit']
#
# ['Over one long, crippling hill']
#
# ['travelling through the high deserts of California in June.']
#
# ['dehydrated state.']
#
# ['This sight is troubling,', 'Rough Road Ahead']
#
# ['sometimes life can be so cruel.', 'it really did look like a diamond back,']
#
# ['@PERSON1', 'I could drop from a heatstroke on a gorgeous day in June']
#
# ['might have been a thriving little spot at one time-sat, before the last world war\x92. The cyclist is given almost a hopelessness as well as determination to survive as he runs out of water. For example he says ']
#
# [" (kurmaskie). We all know desserts are steaming hot and dry especially in june. She also encounters hills (kurmaskie) to make matters wose she was travelling on hills in the extreme heat.Though the cyclist goes through many perilous obstacles she makes it to a camp a lives I could seethe horizon, telling myself that I could make it that par, I'd be fine."]
#
# ['Do not exceed posted speed limit,', 'one ramshackle shed\x85and a corral that couldn\x92t hold the lamest mule\x85', 'The cool pines and rushing rivers of Yosemite\x85']
#
# ['Do Not Exceed Posted Speed Limit']
#
# ['ghost town.']
#
# ['@PERSON1\x92s Grape Juice', 'old timers and the give him a ', ' to the park. He then goes on his bike to the park taking their ', ' While traveling starts to run out of water and then he thinks he is going to die out in the desert. ']
#
# ['Do Not Exceed Posted Speed Limit,', '\x85Rough Road Ahead: Do Not Exceed Posted Speed Limit.', '\x85 and the growing realization that I could drop from heatstroke\x85']
#
# [' brakish water feeling some where in the neighborhood of two hundred degrees.', 'the high desert of June,', 'large highway signs dumped out at me. It read ROUGH ROAD AHEAD DO NOT EXCEED POSTED SPEED LIMIT. ']
#
# ['that the old men would have been right,had he been riding,', ' But any ', ' he rode into, was just a run down, deserted, and abandoned piece of desert. He says,', ' @CAPS1 that he was getting more and more dehydrated, but was not quite ready to die. He still had enough energy to keep going, But ', ' Then all at once after climbing a large hill he gains all hope back. He sees ']
#
# ['DO Not Exceed Posted Speed limit ', 'wide rings of dried sweat circled my shirt and the growing realization that I could drop from heat stroke on a gorgeous day in June.', 'Flat road was replaced by short rolling hills.', 'Yosemite.']
#
# ['I was traveling through the high deserts of California in June,', 'I was going to die', 'Flat road was replaced by short, rolling hills']
#
# ['I enjoyed the serenity of an early-summer evening the.', 'this breezy jaunt.', 'traditional definition of a ghost town.', 'Twenty miles up the road, i came to a fork of sorts.', 'This sight was troubling.', 'I was traveling through the high deserts of California in June.', 'hitting my water bottles pretty regularly.', 'two hundred degrees.', 'I notices the terrain changing']
#
# ['I was going to die and the birds would pick me clean.']
#
# ['with any luck I\x92d hit a bump and lodge one in my throat']
#
# [' i toiled on at some point, tumbleweeds crossed any path.', ' i was going to die and the birds would pick me clean']
#
# ['I rode into the morning with strong legs and a smile on my face.', 'This site was trebling.', 'A tarlike substance oozed out, followed by brickish water feeling some which is in the neighborhood of two hundred trees', ' Then as easily as rounding a body my troubles, thirst and fear were all behind me ']
#
# ['Flat Road was replaced by short rolling hills.']
#
# ['devation']
#
# ['There was no one in sight, not a building, car, or structures of any kind.']
#
# ['Do Not Exceed Posted Speed Limit,', 'through the high deserts of California in June', 'gathered up a few pebbles and stuck them in [his] mouth']
#
# ['along, crippling hill,']
#
# ['Rough Road Ahead: Do Not Exceed Posted Speed Limit', 'Ramshackle @CAPS2, several rusty pumps, and a corral, ', 'sad', 'hopeless', 'behind']
#
# ['ghost town', 'I was going to die and the birds would pick me clean.']
#
# ['Rough Road Ahead: Do Not Exceed Posted Speed Limit', 'rode into the morning with strong legs and a smile on [his] face.', 'the sun was beginning to beat down', 'I came to a ramshackle shed [and] several rusty pumps the sight was troubling. ']
#
# ['old wise men', 'town', 'codgens', ' codgers']
#
# ['\x85Simply because I listened to some gentlemen who hadn\x92t been off their porch in decades,']
#
# ['This place might have been a thriving little spot at one time-say, before the last world war.']
#
# ['High deserts of California in June.', 'Flat road was replaced by short, rolling hills.']
#
# ['Like a foolish youth, the next morning I followed their advice\x85']
#
# ['tumbleweeds crossed my path and a ridiculously large snake']
#
# ['I was traveling through the high deserts of California in June.', 'This place might have been a thriving little spetatore time say, before the last world war-last on that morning it fit the traditional definition of a ghost town.', 'conserve my water and go instead for an hour or so a lest of my inner spirit.']
#
# ['Rough Road Ahead: Do Not Exceed Posted Speed Limit', 'Never accept braid advice from  a collection of old- timers who haven\x92t let be able centres of their porch since carter was in office. ']
#
# ['old timers who hadn\x92t left the confines of their porches since Carter was in office,', 'tested like battery acid', 'ridiculously large snake']
#
# ['Rough Road', 'ease past, trying to keep my balance in my dehidrated state.']
#
# ['I followed their advice and launched out at first line, nd along a \x91short cut', ' This is describing how the cyclist takes the short cut from the old timers which almost gets him killed @CAPS1, the sun had a warming affect on the cyclist causing him to dehydrate. For example, ', ' This is showing you an image of just how hot the climate he is in. Finally, a lack of water can cause major problems, such as heatstroke or dehydration, yoth which can lead to death. For example ']
#
# ['Do Not Exceed Posted Speed Limit,', 'One ramshackle shed, several rusty pumps, and a corral that couldn\x92t hold in the lamest mule greeted me', 'I was traveling through the high deserts of California in June.', '@CAPS1 road was replaced by short, rolling hills.']
#
# ['Rough Road Ahead: Do not exceed posted speed limit,', 'traveling through the high desserts', 'trying to keep balance in my dehydrated state.', 'A far like substance']
#
# ['shortcut', ' there was no one in sight, not a building, car, or structure of any kind.', ' the growing realization that I could drop from heatstroke']
#
# ['Do Not Exceed Posted Speed Limit,', 'I eased past, trying to keep my balance in my dehydrated state. ', 'ROUGH ROAD AHEAD: DO NOT EXcEED POSTED SPEED LIMIT.']
#
# ['I and the growing ??? :??? That I could drop from heat stroke.']
#
# ['cool pines and risum river']
#
# ['Do Not Exceed Posted Speed Limit', 'I chuckled, check my water supply, and moved @NUM1). Soon after, the cyclist is troubled by a ', ' (@NUM2). He is agitated by this, makes a significant dent in his water supply, and unfortunately continues. At the point where he is still isolated and lost beyond repair, the cyclist tries to stay hopeful but soon breaksdown. He reflects, ']
#
# ['the cool pines and rushing rivers of Yosemite had my name written all over them.']
#
# ['The sun was beginning to beat down', 'I was doing a water-depleting 12 mph,']
#
# ['Rough Road Ahead: Do Not Exceed Posted Speed Limit']
#
# ['Do Not Exceed Posted Speed Limit,']
#
# ['wide rings of dried sweet circled my shirt, and the growing realization that I could drop from heatstroke on a gorgeous day in June simply because I listened to some old gentlemen who hadn\x92t been off their porch in decades. Caused me to lough.', 'Rough Road ahead: Do not exceed posted speed limit.']
#
# ['It was sad, hopeless laugh, mind you, but atleast I still had the energy to feel sorry for myself.']
#
# ['a tar like substance oozed out, followed by blackish water feeling somewhere in the neighborhood of two hundred degrees.']
#
# ['looked the majority of the pavement in front of me and ceased past tilling to keep my balance in my dehydrated state.', 'it didn\x92t really matter I was going to die and the birds will pick me cleary waveng only some experience outdoor gears.']
#
# ['Rough Road ahead', 'trying to keep my balance in my dehydrated state.', 'there was no one in sight, not a building, car, or structure of any kind. Since there was rolling now, the cyclist had to keep cycling and drinking his water until he could find a place to stop. Lastly, the ']
#
# ['shortcut']
#
# ['beautiful @DATE1.']
#
# ['High deserts of California in June', 'short rolling hills']
#
# ['Do Not Exceed Posted Speed limit,', 'I began to pump the old rusted water pump, but nothing came out except nasty blackish water.']
#
# ['Rough Road Ahead: Do not exceed speed limit']
#
# ['Do Not Exceed Posted Speed Limit']
#
# ['sometimes life can feel so cruel', 'somehow i climbed away from the abandoned factory of of juice and dreams, slowly gaining elevation while losing hope.']
#
# [' short, rolling hills,']
#
# ['Do Not Exceed Posted Speed Limit']
#
# ['Rough Road Ahead: Do Not Exceed Posted Speed Limit, his hope was faint because he was doing a water-depleting @NUM1 per hour. Because of the rate of the water, he felt life was cruel sometimes and he thought that he was at the point of losing water. Also when he came across the tumbleweeds and the large snake he tried to avoid them. If he would have been bitten he would have died. Finally because of the heat he might have also did from the heatsroke ']
#
# ['Do Not Exceed Posted Speed Limit', 'I had been hitting my water bottles pretty regularly,and i was traveling through the high deserts of California,in June', 'flat rode was replaced by short,rolling hills,']
#
# ['I eased past, trying to keep my balance in my dehydrated state', ' I toiled on, at some point, tumbleweeds crossed my path and a ridiculously large snake- it really did look like a diamond back- blocked the majority of the pavement in front of me ']
#
# ['traveling through the high deserts of California in June.', ' brakish water feeling somewhere in the neighborhood of two hundred degrees. ', ' had the flavor of battery acid.', 'rolling  hills', 'Rough @CAPS1.']
#
# ['Rough Road Ahead: Do Not Exceed Posted Speed Limit,', 'The water bottles contained only a few tentalizing sips, wide rings of dried sweat circled my shirt, and the growing realization that i could drop from heatsroke on a gorgeouse day in June.', 'tentalizing']
#
# [' by Joe Kurmaskie was about a man traveling through some pretty difficult settings. The cyclist\x92s mood was detirmined by the setting as well as his needs and his detirmination to make it. The setting of the story early summer in California. The weather is described as hot as, ', ' He, ', ' Because of the excessive heat, he needed more water, which shortly became the conflict of this story. As things got more difficult his attitude towards the old men\x92s advice changed from gracious for their help to wishing he had never listened to them. Also as the difficulty increased his detirmination to move on also increased by, ']
#
# ['Do Not Exceed Posted Speed Limit. Their are many features that affected the cyclist. For example, ', " they were starting to get hot, than tired. Than when he came to all the bumps in the road, It was harder to pedal. He was also drinking his bottle of water hard. So that means he's hot getting tired and lost "]
#
# ['shortcut']
#
# ['No @CAPS2\x92s @CAPS3']
#
# ['over one long cripping hill, a bulding came into view.']
#
# ['have not left their porch since @PERSON1 was in office']
#
# ['drop from heatstroke.', 'building-abandoned years ealier.']
#
# ['Do not exceed the posted speed limit,', 'The sun was beginning to beat down, but i borely noticed it.']
#
# ['I was traveling through the high deserts of California in June', 'There was no one in sight not a building, car or structure of any kind ']
#
# ['high deserts of California in June.', 'somewhere in the neighborhood of two hundred degrees,', 'long crippling hill']
#
# ['Do not exceed posted speed limit', 'I noticed the terrain changing, Flat road was replaced by short, rolling hills', '\x85 in the neighborhood of two hundred degrees.']
#
# [' He barely noticed that the sun was starting to beat down.', ' I checked my water supply.']
#
# ['my troubles, thirsts, and fear were all behind me.']
#
# ['Rough Road Ahead', 'short cut']
#
# ['The sun was begining to beat dow, but I barely Noticed it.', 'I had been hitting my water bottles pritty regularly and I was travling through the high dezerts in califonia in June.']
#
# ['Do not Exceed posted speed Limit.', 'It was a sad hopeless laugh mind you, but at least l still had the energy to feel sorry for myself.']
#
# ['Rough Road Ahead: Do Not Exceed Posted Speed Limit', 'with strong legs and a smile on my face.', 'Flat road was replaced by short, rolling hills.', 'There was no one in sight, not a building, car or structure of any kind', 'I was going to die and the birds would pick me clean']
#
# ['No Not Exceed Posted Speed Limit']
#
# ['challenge', 'gbost town', 'had my name written all over them.', 'ramshackle shed.']
#
# ['I could drop from heatstroke']
#
# ['it fit the traditional definition of a ghost town.', 'town']
#
# ['Rough Road ahead: Do Not Exceed Posted Speed Limit', 'town', 'I chuckled, checked my water supply, and moved on. The sun was beginning to beat down, but I barely noticed it.', 'I had been hitting my water bottles pretty regularly, and I was traveling through the high deserts of california in June.', 'and a ridiculously large snake. It really did look like a diamond back-blocked the majority of the pavement in front of me. I eased past, trying to keep my balanc in my dehydrated state.']
#
# ['This place might have been a thriving little spot at time \x96say, before the last war-but on that morning it fit the traditional definition of a ghost town. I chucked, checked my water supply and moved on. The the sun was beginning to beat down. The summer heat is thriving how during this @DATE1 and he is drinking lots of water.']
#
# ['@CAPS1 through the high desert of California', 'short, rolling hills.', 'the traditional definition of a ghost town']
#
# ['I rode into the morning with strong legs and a smile on my face', 'With what I believed was my last burst of energy, I maneuvered down the hill,']
#
# ['short, rolling hills']
#
# ['The speed limit was @NUM1. I was doing a water-depleting @NUM2. Sometimes life can feel so cruel', 'There was no one in sight, not a building, car, or structure of any kind. ']
#
# ['who haven\x92t left the confines of their porches since Carter was in office']
#
# ['I was traveling through the high deserts of California in June.', 'Flat road was replaced by short, rolling hills,']
#
# ['I was traveling through the high deserts of California in June.', 'One ramshackle shed. Several rusty pipes and a corral that couldn\x92t hold the lamest mule greeted me.']
#
# ['Do not exceed posted speed limit']
#
# ['town.']
#
# ['Flat road was replaced by short, rolling hills.', 'Over one long, crippling hill.', 'It didn\x92t really matter. I was going to die and the birds would pick me clean.', 'Slowly gaining elevation while losing hope.', 'Then, as easily as rounding a bend, my troubles, thirst and fear were all behind me.']
#
# ['old timers', "rode into the morning with strong legs and a smile on my face.'' As he continues forward, he notices that there are no buildings, cars, or people of any kind. He passes abandoned towns and creeps into the desert flat land. The flatland however, morphs into crippling hills with tumbleweeds and snakes awaiting. Not only is the terrain suddenly different, but the cyclist is rapidly deteriorating. Tiredness and lack of water make the cyclist think "]
#
# ['Rough Road Ahead Do Not Exceed posted Speed Limit.', 'At some point, humble weeds crossed my path', '@CAPS1 hill, a building came into view']
#
# ['I was traveling through the high deserts of California in June.', 'The water bottles only contained & few tantalizing sips.']
#
# ['their were no cars nor buildings in sight', 'oldtimer']
#
# ['town']
#
# ['Rough Road Ahead : Do Not @CAPS1 Posted Speed Limit,', '  the features of the setting affects the cyclist. Dehydration caused by heat could not enough water caused the cyclist to sweat and to feel nautious. ']
#
# ['The water, bottles contained only a few tantalizing sips, water is a big importance. To stort men. Your body need water to work right. The @CAPS1 humid, dry weather of California was a affect To. ', ' ', ' The sun is unbearable, expessary without shade and water, @CAPS2 affect on the cyclist up. The have of animals ', ' It would have been a lot easier for the cyclist if store or people would have been around, @CAPS2 exact is the animals. ', ' ']
#
# ['Do Not Exceed Posted speed limit,', 'had been nitting my water bottles pretty regularly. ', 'somewhere in the neighbar had of two hundred degrees. If the water has reached such a high temperature, the reader infe that it must be not outside the author implied nthis when he says he is California in June, it is agarsears day, and the sun was beating down. Another aspect of the setting, the lane, dirty, ', ' infested land, had a larse affect on the cycle. As he begins to see how hope. He cannot see any signs of madon life; ']
#
# ['The water bottles contained only a few tantalizing sips.']
#
# ['Do Not Exceed Posted Speed Limit', 'town', 'chuckled and moved on', 'the fork of sorts', 'the sight was troubling to him his water supply was somewhat deterriorating, so he became a bit uncered. Finally when the cyclist read the sign that said ']
#
# ['Not the miles into the next section of the ride, he noticed a terrain change.', 'A large highway sign jumped out at him saying or reading,', 'Rough Road Ahead: Do Not exceed Posted Speed Limit. And that was 55. Last the author says, ']
#
# ['Rough Road Ahead: Do Not exceed the speed limit', 'At a resevoir campground outside of Lodi, California, I enjoyed the serenity of an early summer evening.', 'old-timers.', 'About forty miles in to the pedal, I arrived at the first ', ', a ghost town,', 'The sun was beginning to heat down,', 'A Rough Road Ahead']
#
# ['\x85@CAPS1 blues tune \x91summer time\x92 rattled around in\x85my deteriorating brain.', '\x85haven\x92t left their porches since Carter was in office.']
#
# ['with strong legs and a smile on my face', 'It was a sad, hopeless laugh, mind you, but at least I still had the energy to feel sorry for myself. ']
#
# ['to', ' to']
#
# ['Do not exceed Posted Speed limit,', 'wide rings of sweat circled my shirt.']
#
# ['I maneuvered down the hill.']
#
# ['The sun was beginning to beat down', 'Flat road was replaced by short, rolling hills']
#
# ['Do not exceed speed limit,']
#
# ['Rough Road Ahead; Do Not Exceed Posted Speed Limit', '\x85I was travelling through the high deserts of California  in June.', 'towns', 'There was no one in sight, not a building, car, or a structure of any kind.']
#
# [' I got down on my hands working the hande of the rusted water pump with all my strength']
#
# ['some where in the neighborhood of two hundred degrees.']
#
# ['losing hope']
#
# ['Do not Exceed Posted Speed Limit,']
#
# ['The water bottles contained only a few tantalizing sps,wide cings of sweat circled my shirt and the growing realizating that I could drop from heat stroke on a gorgeous day in June\x85']
#
# ['town', '\x85(the town) fit the traditional definition of a ghost town. I chuckled\x85', 'a tar like substance  oozed out of the water pump at the next stop the author became a little unsettled, as the author was running low on water. But he was still optomistic. Once the rolling expansive hills came into view, the author  let out a ']
#
# ['Rough Road Ahead Do Not Exceed Speed Limit', 'town', 'when I tried a drop or two, it had the flavor of battery acid.', ' this quote shows that despite his condition the cyclist most perservere. Also quote ']
#
# ['HUNG HIS HEAD.']
#
# ['traveling through the high deserts of California in June.', 'ghost town']
#
# ['This place might have been a thriving little spot at one time but on @TIME1, it fit the traditonal definition of a ghost town. ']
#
# ['Do not Exceed Posted Speed limit', ' I could die form a heatstroke on a gergeous day in June.', ' I eased past, trying to keep my balance in my dehydrated state.', ' on that morning it fit the traditional detinition at a ghost town.']
#
# ['\x85 I could drop from heatstroke\x85', '\x85look like a diamondback- blocked the majority of the pavement\x85']
#
# ['Rough road Ahead']
#
# ['the bulding abandoned years earlier.']
#
# ['trying to keep my balance in my dehydrated state.']
#
# ['Rough Road Ahead', ' no one in sight, not a building, car, or structure of any kind.', 'One ramshackle shed in many miles, the cyclist almost looses hope. However, hope is renewed when he thinks of ']
#
# ['Do not Exceed Posted Speed Limit', 'cool pines, rushing rivers of upsemite had my name written all over them.', 'One ramshackleshed, several rusty pumps, and a corral that couldn\x92t hold in the lamest Mule greet me.', 'flat road was replaced by short rolling hills...tumbleweeds crossed my path and a ridiculously large snake.']
#
# ['One ramshackle shed, several rusty pumps, and a corral that couldn\x92t hold in the lamest mule greeted me.', 'The speed limit was @NUM2. I was doing a water-depleting @NUM3. sometimes life can feel so cruel.']
#
# ['There was no one in sight, not a building, car, or structure of any kind']
#
# ['Do Not Exceed Posted Speed Limit.', 'The water bottles contained only a few tantalizing sips.']
#
# ['Flat road was replaced by short, rolling hills,', ' and a ridiculously, large snake-it really did look like a diamondback-blocked the majority of the pavement in front of me.']
#
# ['I was travelling through the high deserts of California.', 'I was travelling in June.', 'blackish water feeling somewhere in the neighborhood of two hundred degrees.', 'had the flavor of battery acid.', 'had been hitting (his) water bottles pretty regularly.', 'The water bottle contained only a few tantalizing sips.']
#
# ['Rough Road Ahead', 'His name written over them']
#
# ['Do Not Exceed Posted Speed Limit', 'I arrived at the first ', '\x85this place might have been a thriving little spot at one time\x85but on that morning it fit the traditional definition of a ghost @NUM1). In the essay, the cyclist takes directions from a few old men to get to Yosemite National Park. The cyclist has a limited amount of water, and it was a very humid day for traveling. Because of the humidity, the cyclist nearly ran out of water when he had to cycle up, ']
#
# ['Rough Road Ahead']
#
# ['Do not exceed posted speed limit', 'crippling hills,']
#
# ['I was traveling the high desserts of California in June.']
#
# ['This place might have been a thriving little spot at one time- say, before the last world war,', 'but on that morning it fit the traditional definition of a ghost town.', 'shortcut.', 'Not two miles into the next section of the ride, I noticed the terrain changing,', ' By the looks of it- had been a Welch\x92s Grape Juice Factory.']
#
# ['flat road was replaced by short, rolling hills', ' At some point tumbleweeds crossed my path and a ridiculously large snake']
#
# ['A sea worry ', 'my son body-surfs. He says it\x92s his ']
#
# ['I was travelling through the high desert of California in June.', 'dehydrated state']
#
# ['Rough Road Ahead.', 'I could drop from heatstroke in a gorgeous day in June (@CAPS1).', 'I toiled on( @CAPS2).']
#
# ['Do not Exceed Posted Speed limit']
#
# ['ghost town']
#
# ['The sun was beginning to beat down, but I barely noticed. The cool pines and rushing rivers']
#
# ['Drop from heatstroke.']
#
# ['over one long, crippling hill.']
#
# ['I was traveling through the high deserts of California.', 'Not two miles into this next section of the ride, I noticed the terrain changing. Flat road was replaced by short, rolling hills.']
#
# ['Rough Road Ahead: Do Not Exceed Posted Speed Limit,', ' things began well enough.', 'got back on the bike, but not bothered gathered up a few peldder and stuck them in my mouth.']
#
# ['Rough Road Ahead', 'over a long crippling hill,']
#
# ['The water bottles contained only a few tantalizing sips and the growing realization that I could drop from heatstroke (pG @NUM1 kurmaskie).', 'shortcut']
#
# ['high deserts of colifornia in June', 'few bottles of water', 'ridiculously large snake. It really looked like a diamond back', 'ease post', 'replaced by short, rolling hills']
#
# ['I eased past trying to keep my balance in my dehydrated state']
#
# ['Do Not Exceed Posted Speed Limit', 'cool pines and rushing rivers,', 'rushing river', 'Do not exceed posted speed limit,']
#
# ['wide rings of dried sweat circled my shirt.']
#
# ['The bottles contained only a few drops this shows that he had drank almost all of his water. Then it says ']
#
# ['tantalizing sips. Dry sweat circled his shirt and he was afraid he could froz up heatstrokes. Where he was at was in the middle of no where, with no buildings, cars or structures in sight. Over were of the hills he saw a building came in no view. He wiped the sweat off his eyes so makee sure it was not a malinge,', ' He is a dehydrated and tired that he could see a ']
#
# ['Do Not Exceed Posted Speed Limit', 'old timers who haven\x92t left the confines of their porches @CAPS1 was in office']
#
# ['Do not exceed posted speed limit', 'The sun was beginning to beat down,', '@CAPS2 were replaced by short, rolling hills.', 'dimond back-blocked the majority of the pavement in front of me.']
#
# [' I was travelling through the high deserts of California in June.', 'toiled', ' over one long, crippling hill\x85']
#
# ['The water bottles contained only a few tantalizing sips', 'With what I believe, was my last burst of energy, I maneuvered down the hill,']
#
# ['Do not exceed Posted Speed limit']
#
# ['\x85and the growing realization that I could drop from heatstroke\x85', '\x85ride down into distances I could see over the horizon, telling myself that if I could make it that far, I\x92d be fine.']
#
# ['Rough Road Ahead: Do Not Exceed the Speed Limit']
#
# ['Do Not Exceed Posted Speed Limit', 'Rough Road Ahead: Do not Exceed Posted Speed Limit.']
#
# ['Do Not exceed Posted Speed Limit']
#
# ['Do Not Exceed Posted Speed Limit,', 'old folks', 'tumbleweeds crossed my path, and a ridiculously large snake\x85', 'crippling hill']
#
# ['Do Not Exceed Posted Speed Limit']
#
# ['Rough Road Ahead: Do Not Exceed Posted Speed Limit', 'tarlike', 'in the neighborhood of two hundred degrees']
#
# ['Rough Road Ahead: Do Not Exceed Posted Speed Limit,', 'beginning to beat down', 'could trap from heatstroke on a gorgeous day in June.', 'flat road was replaced by short, rolling hills']
#
# ['Rough Road Ahead', 'Wide rings of dried sweat circled my shirt, and the growing realization that I could drop from a heatstroke.', 'I wiped the sweat from my eyes to make sure it wasen\x92t a mirage, and tried not to get too excited. ']
#
# ['Do not exceed posted speed limit']
#
# ['high desserts of California in June.', 'I could drop from a heatstroke,', 'Trying to keep my balance in my dehydrated state.', 'Flat road was replaced by short, rolling hills.']
#
# ['Do not exceed Posted Speed Limit', 'town', ' l gathered a few pebbles and struck them in my mouth. I\x92d read once that sucking on stones help take your mind off thrist']
#
# ['town', '\x85I noticed the terrain changing. Flat road was replaced by short, rolling hills.', 'Gary and Wilber\x92s Fish camp\x85']
#
# ['The water bottle only contained a few tantallizg sips.', 'At some point a rediculously large  snak it really did look like dimond back\x96bloked the majority of the pavement.']
#
# ['The sun was beating down on me', 'The water bottles contained only a few tantalizing sips']
#
# ...
#
# ['old codgers', 'a test of [his] inner spirit.']
#
# ['and the growing realization that I could drop from a heat stroke simply because I had listened to some gentlemen who hadn\x92t been off their porches in a decade']
#
# ['Do Not Exceed Posted Speed Limit', 'wide rings of dried sweat circled my shirt, I could drop from heatstroke.', ' I had been hitting my water bottles pretty regularly, and I was travelling through the high deserts of California in June. ', 'the birds would pick (you) clean, leaving only some expensive out door gear']
#
# ['Rough Road Ahead Do not exeed the Posted Speed limit', 'The Speed limit was 55 mph. I was doing a water depleting 12 mph', 'A sandblasted picture of a young boy pouring @NUM1 refreshing glass of juice into his mouth']
#
# ['town', 'the birds will pick me clean,', 'saved']
#
# ['Rough Road Ahead: Do not Exceed Posted Speed Limit.', 'At some point, tumber weeds crossed my path and a ridiculously large snake-it really did look like a diamond back-back the majority of the pavement in front of me, I eased past, trying to keep my balance in my dehydrated state. ']
#
# [' on a gorgeous day in June caused him to laugh.', ' growing realization that l could drop from heatstroke ']
#
# ['The sun was beginning to beat down.', 'tumbleweeds crossed my path and a ridiculously large snake.', 'over one long, crippling hill.', 'Do Not Exceed Posted Speed Limit']
#
# [' i was travelling through the high deserts of California in June', 'towns', 'ghost towns', 'At some point, tumbleweeds crossed my path and a ridiculously large snake\x85 blocked the majority of the pavement in front of me.']
#
# ['Rough Road Ahead: Do Not Exceed Posted Speed Limit.']
#
# ["one ramshacure shed, several rusty pumps, and a comes that couldn't hold in the lamest mule greeted me. This sight was trouble.", 'there was no one in sight, not a building, car, or structure of any kind.']
#
# ['There was no one in sight, not a building, car, or structure of any kind.']
#
# ['Do Not Exceed Posted Speed Limit', 'The high deserts of California in June.', 'drop from heatstroke', 'crippling', 'There was no one in sight, not a building, or a structure of any kind']
#
# ['Rough Road Ahead: Do not exceed the Speed Limit', 'high deserts of California in June,', 'Rough Road Ahead.']
#
# ['Do Not @CAPS1 Posted Speed Limit', 'Flat road was replaced by short, rolling hills,']
#
# ['Rough Road Ahead']
#
# ['Rough Road Ahead: Do Not Exceed Posted Speed Limit,', 'Rough Road Ahead: Do Not Exceed Posted Speed Limit,']
#
# ['Rough Road Ahead: Do not exceed posted speed limit', 'the california desert in the middle of June']
#
# ['pumped the handle for several minutes but the water would not cool it tasted like battery acid.']
#
# ['I had been hitting my bottles pritty regularly, and I was traveling through the high desert of California in June', 'over one long, crippling hill, a building came into view']
#
# ['Rough Road Ahead: Do Not Exceed Posted Speed Limit,', 'several rusty pumps.', 'Flat roads were replaced by short, rolling hills.', 'There was noone in sight, not a building, car, or structure of any kind.']
#
# ['I rode into the morning with strong legs and a smile on my face.', 'ghost town', 'chuckled, checked my water supply, and moved on', 'One ramshackle shed, several thirsty pumps, and men', 'this was troubling', 'He failed on.', 'drop from a heatstroke.']
#
# ['Rough Road Ahead: Do not exceed posted speed limit,', 'Not two miles flat road was replaced by short rolling hills. The speed limit was 55. I was doing a water-depleting @NUM1.']
#
# ['old timers who haven\x92t left the confines of thier porches since Carter was in office', 'Welch\x92s Grape Juice Factory', 'Gary And Wilber\x92s FISH CAMP-IF YOU WANT BAIT FOR THE BIG ONES, WE\x92RE YOUR BEST BET!']
#
# ['The water bottles contained only a few tantalizing sips I could drop from a heatstroke ']
#
# ['came to a park of ???. One ramshackly shed, several rusty pumps and  a carrol that couldn\x92t hold in the hamest mule greeted me.This sight was troubling.', 'I was traveling strenght the high deserts of California in June. @CAPS1 ?? imagine, the heat, and unbareabalnes of the ??? journey still I face. @CAPS1 that bike seen endless.Then with a thrust gaining on him for example, ', '@CAPS1 him feel his constrain regrate on the journey @CAPS1 me feel his constrain sorrow for his endless journey he had to go through. Another example is, ']
#
# ['Do not exceed postal speed limit,', 'Never accept travel advice from a group of old- timers who haven\x92t left the confines of their porch since Carter was in office.', '\x85but on that morning it fit the traditional definition of a ghost town. Here, the author is trying to stop for water, but since no one lives in the town any more, he gets none. Finally, the lack of water has a huge effect on the cyclist. ', 'Summer time']
#
# [' Rough road ahead: Do not exceed pasted speed limit', ' In an @CAPS1 twist that should please all sadists\x85']
#
# ['Rough road ahead! Do not exceed posted speed limit.']
#
# ['Rough Road Ahead.', 'their advice', 'no sense of themselves when pointing out landmarks and spouting off town.']
#
# ['I eased past, trying to keep my balance in my dehydrated state. The water bottle contained only a few tantalizing sips. Wide rings of dried sweet circled my skirt, and the growing realization that I could drop from heartstroke on a gorgeous in June ', ' @CAPS1 example is ', '(Joe Kurmaskie, @NUM2)', 'I began breaking the ride down into distances. I could see on the horizon, telling myself that if I could make it this far, I\x92d be fine ']
#
# ['Rough Road Ahead', 'could die of heatstroke on a gorgeous day in June simply because of listened to some gentlemen who hadn\x92t been off their porch in decades caused me to laugh. a third way the cyclist was affected was was when he went inside the bait shop and cooled down. lastly when he rehydrated himself in the  so the setting was a main factory to the cyclist in the essay ']
#
# ['The water bottle contained only a few tantalizing sips.', 'About @NUM2 miles', 'Twenty miles up the road.']
#
# ['Rough Road Ahead', 'There was no one in sight, not a building car, or structure of any kind.', 'Rough Road Ahead']
#
# ['and the growing realization that I could die drop from heatstroke', 'ROUGH ROAD AHEAD: DO NOT EXCEED POSTED SPEED LIMIT']
#
# ['It was a sad, hopeless laugh, mind you...', 'I was traveling through the high deserts of California in June']
#
# [' a cyclist follows some bad advice, which leads him on a tough ride through the desert with little water. The setting has a large effect on the cyclist because it causes him to be dehydrated, which presents the main conflict of the story. ', ' the author states when his fresh water supply begins to run out. Another factor the setting presents to the cyclist is the extreme heat of the California desert. This adds to the cyclist thirst and dehydration. The reader can tell it is unpleasantly hot when reading, ']
#
# ['growing realization that [he] could drop from heatstroke', "had been @NUM1 Welch's Grape Juice Factory.", "'@ORGANIZATION2' rattled aroung in the dry honeycombs of (his) deteriorating brain.", 'with any luck I\x92d hit a bump and lodge one in my throat', 'drank deeply from the sink.']
#
# ['Do Not Exceed Posted Speed Limit']
#
# ["... last burst of energy, i mane'uvered down the hill,"]
#
# ['about @NUM1 miles into te pedal', ' still having confidence, he lack of water, he continues on. after a couple more miles, he comes to small fork with a pump. Thinking its cool, water he goes and pump, he finds out it is @NUM2°@CAPS1 and tastes like ']
#
# ['This sight was troubling\x85I had been hitting my water bottles regularly, and was traveling through the high deserts in California.', 'easy way out.']
#
# [' The sun was beginning to beat down but I barely noticed it']
#
# ['over one long, crippling hill, a building came into view.', 'Summertime ', '. It is summer time where he is riding and to keep his mind off of his thirst, he hums the song ', ' He wants to show that the heat cannot overtake his body. Also he says, ']
#
# ['That I could drop from heat stroke on a gorgeous day in June.', ' Flat road was replaced by short rolling hills.']
#
# ['Do Not Exceed Posted Speed @CAPS1,', 'the cool pines and rushing river of Yosemite had my name written all over them', 'one ramshackle shed, several rusts pump, and a corral that couldn\x92t hold in the lamest make.', 'The @CAPS2 of @CAPS3 @PERSON1.', 'Do Not Exceed posted Speed Limit']
#
# [' it shows that he is most likely in the middle of nowhere. This is true because tumbleweeds are usually signs in movies and t.v. shows that the place is deserted. Also, when the author writes', ' and when he writes ']
#
# ['Rough Road Ahead: Do not exceed Speed limit']
#
# ['flat road was replaced by short, rolling hills.', 'through the high deserts of California in June.']
#
# ['text states ']
#
# ['Rough Road Ahead: Do Not Exceed Posted Speed Limit,', 'shortcut']
#
# ['A better piece of advice for the solo cyclist would be, ']
#
# ['rough road ahead', 'I\x92d read once that sucking on stones helps take your mind off thirst by allowing what spit you had left to circulate', 'I wiped the sweat from my eyes to make sure it wasn\x92t a mirage.']
#
# ['Rough Road Ahead: Do Not Exceed Posted Speed Limit']
#
# ['I eased past trying to keep my balance in my dehydrated state', 'The glowing realization that I could die from a heat stroke,']
#
# ['set in']
#
# ['Rough Road Ahead: Do Not Exceed Speed Limit', 'The cool pines and rushing rivers of Yosemite had my name written all over it.', 'rushing', 'Not two miles into this section of the ride, I noticed the terrain changing.', 'There was no one in sight, not a building, car, or structure of any kind. ', 'over the long crippling hill, a building came into view.', 'crippling']
#
# ['It was a sad, hopeless laugh, mind you, but at least I still had the energy to feel sorry for myself.', 'brackish.']
#
# ['shortcut']
#
# [' I eased past, trying to keep my balance in my dehydrated state. ', ' if it looked like i was going to lose consciousness for the last time.']
#
# ['old-timers who haven\x92t left the confines of their porches since Carter was in office.', 'The cool pines and rushing rivers of Yosemite had my name written all over it.']
#
# ['\x85 I maneuvered down the hill.', 'When I tried a drop or two, it had the flavor of battery acid\x85', '\x85in the??? ???of two hundred degrees.']
#
# [' tomble weeds crossed my path is a ridiculously large snake.']
#
# [' The speed limit was @NUM1. The was doing a water depleting @NUM2, Sometimes life can feel so cruel.']
#
# ['The cool pines and rushing rivers of Yosemite had my name written all over them', 'Flat road was replaced by short, rolling hills', 'rough road ahead', 'the water bottles contained only a few tantalizing  sips.', 'ghost town']
#
# ['These was no one in sight, not a bulling, car or structure of any kind,']
#
# ['That you should never accept travel advice from old timers that haven\x92t left their porches since Carter was in office']
#
# ['tumbleweeds crossed my path']
#
# ['The water bottles contained only a few tantalizing sips.', 'and the growing realization that I could drop from heatstroke', 'I stumbled into a rather modern bathroom and drank deeply from the sink.']
#
# ['Rough Road Ahead: Do Not Exceed Posted Speed Limit', 'ghost']
#
# ['The water bottles contained only a few tantalizing sips.(Kurmaskie). Also the cyclist was lost because of the old men directions that got him know where because there directions were out of date. ']
#
# ['The old guys had sworn the next town only eighteen miles down the road. I could make that. I would conserve my water\x85']
#
# [' This affected the author mentally, making him remember he had no water. Which inturn affected him physically by becoming dehydrated as moments passed. So overall that setting features had a negative direction affect on the cyclist. Another example, ', ' This affected the cyclist mentally by making him think he was never going to see civilization again. It also affected him physically because the water tasted like ']
#
# ['Do not exceed the speed limit']
#
# ['arrived at the first \x91town\x92', 'town']
#
# ['Do Not Exceed Posted Speed Limit,', 'The sun was beginning to heat beat down, but I barely noticed it.', 'The speed limit was @NUM1. I was doing a water- depleting @NUM2.', 'I toiled on. At some point, tumbleweeds crossed my path and a ridiculously large snake. It really did look like a diamondback-blocked the majority of the pavement in front of me.', 'Do not Exceed Posted Speed Limit,']
#
# ['Do not exceed posted speed']
#
# ['town', 'building', 'chuckled, checked [his] water town supply, and moved.']
#
# ['shortcut', 'A sandblasted picture of a young boy pouring a refreshing glass of juice into his mouth couldstill be seen (Kurmaskie @NUM1). ', 'town', 'Wide rings of dried sweat circled my shirt.(Kurmaskie @NUM1).']
#
# ['Do not exceed the posted speed limit,', 'Do not exceed the posted speed limit.']
#
# ['Rough Road A head Do Not Exceed Posted Speed Limit']
#
# ['Do not exceed posted speed Limit', 'haven\x92t left the confines of their poaches since carter was in office. ', 'Cool pines and rushing rivers of Yosemite', 'There was no one in sight, not a building, car, or structure of any kind.']
#
# ['over one long, crippiling hill, a building came into view.']
#
# ['Do not exceed posted speed limit', 'old', 'there was no one in sight, not a building, car, or structure of any kind', 'In an ironic twist that should please all sadists reading this, the building,']
#
# ['I checked, checked my water supply & moved on. The sun was beginning to heat down, not I barely noticed it. The surroundings have little effect on him. Later, on he realizes his water was going down, & he is getting tired, his mood changed to exhaustion & defect. Here he writes ']
#
# ['Rough road ahead: do not exceed posted, speed limit ', 'one ramshockle shed, severall rusty pumps and a corrol that couldn\x92t hold these lamest mule. ', 'a sand blasted picture of a Young boy, ']
#
# ['Rough Road Ahead: Do not exceed posted speed limit,', '. Tumbleweeds crossed my path and a ridiculously large snake- it really did look like a diamondback- blocked the majority of the pavement in front of me. I eased past, trying to keep my balance in my dehydrated state. Also, the features of the setting give him determination. They give him determination, because each horizon he sees gives him hope. They give him hope since he knows he is that much @NUM1 to Yosemite National Park. The passage that supports this is when he drops,', ' In the story,']
#
# ['Flat road was replaced by short, rolling hills. ', ' @CAPS1 hills took a lot out of him and he was now on a highway. Before this terrain change the rider is very positive and thinks he can do this easily. ', ' But after the terrain change he looses hope and almost don\x92t make it. ']
#
# ['Rough Road Ahead: Do Not Exceed Posted Speed Limit', '\x85I was traveling through the high deserts of California in June.']
#
# ['Flat road. Was replaced by short, rolling hills']
#
# ['young boy pouring a refreshing a loss of juice into his mouth']
#
# ['Not the miley into this heat section of the ride, I noticed the terrain changing. Flat road was replaced by short, rolling hills. ', 'Then, as easily as running about, my troubles thirst, and nor were all behind me']
#
# ['I was traveling through the high deserts of California in June.', 'Flat road was replace by short, rolling hills.']
#
# ['\x85 high   deserts of California\x85 ', 'Flat road was replaced by short rolling hills ', '\x85 long, crippling hill\x85 ']
#
# ['I eased past, trying to keep my balance in my dehydrated state.']
#
# ['gorgeous day in June.']
#
# ['over one crippling hills\x85']
#
# ['Rough Road Ahead: Do Not Exceed Posted Speed Limit']

# %%
len(set3_keywords)
# Out:
# 1512

# %%
set3quotes = ['traveling through the high deserts of California in June', 'brackish water faling somewhere in the neighborhood of two hundred degrees', 'sun was beginning to beat down', 'growing realization that I could drop from heatstroke on a gorgous day in June', 'fit the traditional definition of a ghost town', 'trying to keep my balance in my dehydrated state', 'flat road was replaced by short rolling hills', 'water bottle contained only a few tantalizing sips', 'tarlike substance followed by brackish water', 'no one in sight, not a building, car, or structure of any kind', 'wide rings of dried sweat circled my shirt']

set3essayquotes = ['enjoyed the serenity of an early-summer evening', 'thriving little spot at one time', 'hitting my water bottles pretty regularly', 'high deserts of California', 'somewhere in the neighborhood of two hundred degrees', 'flat road was replaced by short rolling hills', 'ROUGH ROAD AHEAD: DO NOT EXCEED POSTED SPEED LIMIT', 'water bottles contained only a few tantalizing sips', 'Wide rings of dried sweat circled my shirt', 'drop from heatstroke on a gorgeous day', 'no one in sight, not a building, car, or structure of any kind', 'long, crippling hill', 'checked my water supply', 'birds would pick me clean']

set3_keywords = set(set3quotes + set3essayquotes)

# %%
list(set3_keywords)
# Out:
# ['trying to keep my balance in my dehydrated state',
#  'no one in sight, not a building, car, or structure of any kind',
#  'flat road was replaced by short rolling hills',
#  'hitting my water bottles pretty regularly',
#  'somewhere in the neighborhood of two hundred degrees',
#  'sun was beginning to beat down',
#  'drop from heatstroke on a gorgeous day',
#  'water bottles contained only a few tantalizing sips',
#  'high deserts of California',
#  'enjoyed the serenity of an early-summer evening',
#  'traveling through the high deserts of California in June',
#  'ROUGH ROAD AHEAD: DO NOT EXCEED POSTED SPEED LIMIT',
#  'long, crippling hill',
#  'tarlike substance followed by brackish water',
#  'thriving little spot at one time',
#  'fit the traditional definition of a ghost town',
#  'Wide rings of dried sweat circled my shirt',
#  'growing realization that I could drop from heatstroke on a gorgous day in June',
#  'water bottle contained only a few tantalizing sips',
#  'wide rings of dried sweat circled my shirt',
#  'checked my water supply',
#  'brackish water faling somewhere in the neighborhood of two hundred degrees',
#  'birds would pick me clean']

# %%
set4 = pd.read_csv('set4_features.csv')

# %%
set4_keywords = set()

for i in set4['essay']:
    unicode_converted = i.replace("\x93", '"').replace("\x94", '"').replace("\x85",  '')
    quotes = get_quotes(unicode_converted)
    if len(quotes) > 0:
        print(quotes, "\n")
        set4_keywords.update(quotes)

set4_keywords
# Out:
# ['Winter Hibiscus']
#
# ['when they come back, saeng vowed silently to herself, in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test again.']
#
# ['Winter Hibiscus,', 'many of the things that she had thought of as strange before had become, almost familiar to her now.']
#
# ['Almost reluctantly, she realized that many of the things that she had thought of as strange before had become, through the quiet repetition of season upon season, almost familiar to her now.', 'familiar']
#
# ['Not like the kind we had before.']
#
# ['I-I failed the test.', 'take that test again.', ' And that rich sweet scent- that was familiar, too, ', 'take the test again.', 'the quiet repetition of season opon season, almost familiar to her now. Like the geese.', ' when the snow melts and the geese return.']
#
# [' Winter Hibiscus,', ' When they come back, saeng vowed silently to herself, in the spring when the snow melt and the geese return and this hibiscus is budding , then I will take that test again.']
#
# ['Winter Hibiscus', 'When they came backthen I will take that test again.', 'I failed the test.', 'her gentle grandmother', 'mrs.Lambert', 'home', 'when the snow melts, and the geese return and the hibiscus is budding, then I will take the test again.', 'Winter Hibiscus']
#
# ['In the spring when the snow melts and the geese return and this hisbiiscus is budding, then I will take the test again.']
#
# [' when the snow melts and the geese return and the hibiscus is budding ,']
#
# ['I-I failed the test,']
#
# ['winter hibiscus,', 'I-I failed the test,']
#
# ['Winter hibiscus']
#
# [' winter hibiscus', 'many of the things that she thought of as strange before had become , through quite repetition of season upon season, almost familiar to her now .', 'then she will take that test again.']
#
# ['many of the things she had thought of as strange before had become almost familiar to her now.']
#
# ['The hibiscus will be budding']
#
# ['when the snow melts and the geese return', 'She lifted her head and watched as their distinctive V was etched against the evening sky', 'that many of the things that she had thought of as strange befere had become...familiar to her now']
#
# ['Saeng vowed silently to herself', 'then I will take that test again']
#
# ['when the snows melt and the geese return and this hibiscus is budding, then I will take that test again']
#
# [' I-I falled the test']
#
# ['Winter Hibiscus ', 'She closed her eyes and breathed in, deeply. The familiar fragrance filled her lungs, and saeng could almost feel the light strands of her grandmother\x92s long gray hair', ' When the hibiscus was lowered in the ground, a flock of geese flew by.']
#
# ['smooth and cool toward the end of the first page. When she first the plant back in Vietnam she thought that is just grew wildly. Then when she saw it in the United States she was suprised that it grew in a pot. For example she desribed the the smell of the hibiscus as a ']
#
# ['winter Hibiscus,']
#
# ['test', 'home', 'home']
#
# ['when [] this hibiscus is budding I will take that test again']
#
# ['It\x92s not like the wind we had at-at-.']
#
# ['the snow melt, and the geese return and the hibiscus is budding, then I will take the test again. ']
#
# ['hibiscus is budding.']
#
# ['I will try this test again']
#
# ['then I will take that test again']
#
# ['when they come back, in the spring, when the snow melt and the geese return and this hibiscus is budding, then I will take that test again']
#
# ['I will take the test again,']
#
# ['I will take the test again']
#
# [' Winter Hibiscus']
#
# ["I've seen this kind blooming along the lake. It's flowers arn't as pretty, but it`s strong enough to make it through the cold months here, this winter hibiscus. That's what matters."]
#
# ['I-I failed the @NUM1]. The hibiscus must make it through the winter, it also has to adjust to new surrounding to survive, just like Saeng. The mother says to Saeng,', '[@NUM2]. So,if the winter hibiscus\x92 job, or hurdle that it has to jump,it to make it, to stay alive during the winter months, then its job will be done in the spring. The author ends the story with Saeng telling herself, ', '[@NUM2]. If Saeng\x92s obstacle is completing, and passing the driver\x92s test, and she passes in the spring, right as the hibiscus passes it\x92s ']
#
# ['In the springthen I will take that test again.', 'it\x92s-it\x92s not a real one,', ' much preferred it to the Big Mac']
#
# ['if you just try, you might like it,']
#
# ['carefully Saeng dicked it up and smilled. She closed her eyes and breathed in, deeply. the familiar programe filled her lungs.']
#
# [' when snow melts  and  the  geese  return  and this hibiscus is budding ']
#
# ['when the snow melts and the geese return, and this hibiscus is budding, I will take that test again', 'Winter Hibiscus']
#
# ['Its flowers aren\x92t as pretty, but its strong enough to make it through the cold months here, this winter hibiscus. That\x92s what matters.']
#
# ['when the snow melts']
#
# ['almost reluctantly, she realized that many of the things that she had thought of strange before had become... almost farmllular to her now']
#
# ['Winter Hibiscus,']
#
# ['now.']
#
# ['Winter Hibiscus']
#
# ['reluctantly']
#
# ['Winter Hibiscus', 'budding']
#
# ["When they come back, Saeng vowed silently to herself, in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test again because Saeng doesn't want to give up yet. In the story Saeng mumbled, ", 'She found that she was still too shaky to say the words at home. ']
#
# ['cheep skip over live to you\x92re back she saw cheerfully']
#
# ['When they came back, Saeng vowed silently to herself, in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test again.', 'winter hibiscus', 'I\x92ve seen this kind blooming along the lake. Its flowers aren\x92t as pretty, but it is strong enough to make it through the cold months here, this winter hibiscus. That\x92s what matters.']
#
# ['Winter Hibiscus', "when they come back, Saeng's vowed silently to herself, in the spring, when the snow melts and the geese return and this hibiscus is budding, then I will take the test again.", 'comes back']
#
# ["as Saeng walks home after failing her driver's test", 'She sees a familier plant', ' where did you get it?', 'I bought it.']
#
# ['When they come back, Saeng vowed silently to herself, in the spring, when the snow']
#
# ['that helps explain why the author concludes this story with this paragraph since Saeng moved from her own country, she has not been very happy, she was upset pretty much the whole time and misses everyone and @CAPS1 from Vietnam; @CAPS1 she sees reminds her of it, that last paragraph, where it says, ']
#
# ['Winter Hibiscus', 'Saeng vowed silently to herself', 'I will take that test again', 'when the snow melts and the geese return and this hibiscus is budding...']
#
# ['Saeng  vowed silently to herself, ']
#
# ['When the snows melt and the geese return and this hibiscus is budding', 'it\x92s not like the kind we had before.']
#
# ['When they come back in the spring, When the snows melt and the geese return and this hibiscus is budding, then I will take that test again.', 'I\x92ve seen this kind blooming along the lake. Its flowers aren\x92t as pretty, but it\x92s strong enough to make it through the cold months here, this winter hibiscus.']
#
# ['V']
#
# ['Winter Hibiscus']
#
# ['Winter Hibiscus', 'Minfong Ho', 'when they come back, Saeng vowed silently to herself, in the spring, when the snow melts and the geese return and this hibiscus is budding, then I will take that test again. ', '. As many kids do, Saeng failed her driving test and she is crucially upset about it. nobody wants to fail at something and it is almost a humiliating experience to have failed at a test. knowing that others have already successfully passed. With the quote in the introduction paragraph, or the one in the question, it was written as a sign of symbolism. When the geese return back north, it is to show that they are ready to ', ' again or to ', '. When the hibiscus is budding it is trying to ']
#
# ['I will take that test again', 'when the snows melt and the geese return and this hibiscus is budding']
#
# ['when they come back, saeng vowed silently to herself, in the spring when the snows melt and the geese return and this hibiscus is buding, then I willtake that test agien.']
#
# ['almost reluctantly, she realized that many of the thing that she had thought of before had become through the quite repetition of season upon season, almost familiar to her now. ']
#
# ['Winter Hibiscus,', '\x92when they come back,\x92 Saeng vowed silently to herself,\x92in the spring, when the snow melts and the geese return and this hibiscus budding. then I will take that test again.\x92', 'She found she was still too shaky to say the words at home..']
#
# ['I will take that test again.']
#
# ['Winter Hibiscus', 'when they come back, Saeng vowed silently to herself, in the spring, when the snows melt and the geese return and this hibiscus  is budding, then I will take that test again.', 'almost familiar to her now', 'obstacle,']
#
# ['Winter Hibiscus', 'Almost reluctantly, she realized that many of the things that she had thought of as strange before had become, through the quite repititon of the season upon season, almost farmiliar to her now.']
#
# ['in the spring, when the snow melt and the geese return and this hibiscus is budding then I will take that test again.']
#
# ['Winter Hibiscus', 'She realized that many of the things that she had thought of as strange before had become, through the quiet repetition of season upon season, almost familar to her now', 'She found that she was still too shaky to say the words at home, lest she burst into tears again.']
#
# ['I will take that test again']
#
# ['Winter Hibiscus,', 'In the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test again,']
#
# ['winter Hibiscus', "The geese symbolize Saeng's determination to pass the test and try like the new country. Saeng explains, "]
#
# ['and this hibiscus is budding, then I will take that test again']
#
# ['comforts']
#
# ['Winter Hibiscus', 'dok faeng-noi,']
#
# [' Winter Hibiscus ', 'Almost  familiar to her now.', 'Its flowers aren\x92t as pretty, but its strong enough to make it through the cold months here.']
#
# ['I-I failed the test,']
#
# ['when they came back, Saeng vowed silently to herself, in the spring; when the shows melt & the gees return & this hibiscus is budding, then I will take the again']
#
# ['Winter Hibiscus', 'In the spring, when this hibiscus is budding']
#
# ['I failed the test']
#
# ['It felt smooth and cool, with a hint of velvet toward the center- just as she had known it would feel.', 'this hibiscus plant is budding,then l will take that test again']
#
# ['Winter Hibiscus', 'vowed', 'Winter Hibiscus']
#
# ['in the spring.I will take this test again']
#
# ['Saeng']
#
# ['I \x96 I failed the test.']
#
# ['Winter Hibiscus', "Saeng could almost feel the light strands of her grandmother's long gray hair, freshly washed, as she combed it out with the fine-toothed buffalo-horn comb", 'this hibiscus is budding,']
#
# ['when they come back, Saeng vowed silently to herself in the spring, when the snows melt and the geese return and the hibiscus is budding, then I will take that test again.']
#
# ['V']
#
# ['Winter Hibiscus', 'Plants she had not even realized she had known but had forgotten drew her back into her childhood work.']
#
# ['in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test again.']
#
# ['in the spring, when the snows melt and the geese return and this hibiscus is bidding, then I will take that test again']
#
# ['when they come back, Saeng vowed silently to herself, in the spring , when the snows melt and the geese return and this hibiscus is budding, then I will take that test again.', "I\x92ve seen this kind blooming along the lake. Its flowers aren't as pretty, but its strong enough to make it through the cold months here."]
#
# ['Winter hibiscus']
#
# ['Winter Hibiscus', 'when they come back, Saeng vowed silently to herself, in the spring when the snows melt and the geese return and this hibiscus is budding, then I will take that test again']
#
# ['Winter Hibiscus', '@CAPS1 in the garden, Saeng dig out a hole and carefully lowered the ', ' into it.']
#
# ['when they come back, in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take the test again', 'and this hibiscus is budding']
#
# ['Winter Hibiscus,', 'home,', 'through the quiet repetiton of season upon season, almost familiar to her now', 'like the Geese she lifited her head and watched as their distinctive v was etched,']
#
# ['Here let me help you mother.', 'almost reluctantly she realizes that many of the things that she had thought of as strange before had become, through a quiet repitition of season upon season, almost familier now.']
#
# ['Winter Hibiscus', 'she realized that many of the things that she had thought of are strange before had become, through the quick repetition of season upon season familiar to her now.', 'Saeng did not dare look at her mother in her eyes.']
#
# ['In the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test again.']
#
# ['you what? Her mother stared at her increously.']
#
# ['when they come back, Saeng vowed sileltly to herself, in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take the test again. ', 'Plants that she had not even realized she had known but had forgotten drew her back into childhood world.']
#
# ['Winter Hibiscus', 'when they come back, Saeng vowed silently to herself in the spring, when the snow melt and the geese return and this hibiscus is budding, then I will take that test again,']
#
# ['Winter Hibiscus', 'in the spring ,when the snowS melt and the geese return and hibiscus budding, then I will take the test again.', 'What happened with the driver\x92s test ,what was the point of that ?']
#
# ['vowed silently to herself, in the spring, when the snow melt and the geese return and the hibiscus is budding.']
#
# ['when they come back saeng vowed silently to herself, in the spring, when the snow melt and the geese return And this hibiscus is budding, then I will take that test again.']
#
# ['when they come back, saeng vowed silently to herself, in the spring, when the snows melt and the geese return and its hibiscus is budding, then I will take that test again.']
#
# ['When they come back, Saeng vowed silently to herself in the spring, when the snows melt and the geese return and hibiscus is budding ,then I will take that test again']
#
# ['Winter Hibiscus', 'when they come back, Saeng vowed silently to herself, in the spring, when the snow melts and the geese return and this hibiscus is budding, then I will take that test again.', 'plants that she had not even realized she had known but had forgotten drew her back into her childhood worth. ', 'the test', 'almost familiar to her now,']
#
# ["the sharp bitter melon and the hibiscus. These @CAPS1 lead Saeng to feel more at home and make it fitting to end with Saeng's acceptance that she will stay in @LOCATION1. @PERSON1 is also inspired by the hibiscus who is ", " This reads to Saeng's determination to make it through her new life. And finally, the geese Saeng recognizes that life in @LOCATION1 is becoming "]
#
# ['home']
#
# ['when the snow melt and the geese return and this Hibiscus is budding Then I will take that test agin']
#
# ['A wave of loss so deep and strong that it stung Saeng\x92s eye now swept over her. ']
#
# ['I-I  failed the test,', 'For a long moment MRS. Pan ouvong said nothing.', 'How would you like an omelet w/ slices of the bitter melon? ', 'I\x92d love it,']
#
# ['Winter Hibiscus', 'Winter Hibiscus']
#
# ['I mean, not like the kind we had at-at-']
#
# ['Winter Hibiscus', 'when they come back, Saeng vowed silently to herself, in the spring, when the snows melt ant the geese return and this hibiscus is budding, then I will take the test again', 'and in the warm moist shelter of the greenhouse, Saeng broke down and went']
#
# ['I failed']
#
# ['Then I will take that tes again', 'she realized that many of the things that she had thought of as strange before had become, through the quiet repetition of season upon season']
#
# ['in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test again.']
#
# ['winter hibiscus']
#
# [' I will try again next spring ', ', Almost reluctantly, she realized that many of the things that she had thought of as strange before had become, through the quiet repetition of season upon season almost familiar now.']
#
# ['Winter Hibiscus']
#
# ['geese return and this hibiscus is budding that I will take that test again.']
#
# ['Winter Hibiscus,', 'winter hibiscus', 'when they come back, in spring, when the snow melt and the geese return and this hibiscus is budding, then I will take that test again']
#
# ['In the spring when the snows melt and the geese return and this hibiscus is budding, then I will take that test again.']
#
# ['Winter Hibiscus', 'When they come back, Saeng vowed silently to herself, in the spring, when the snow melts, and the geese return and the hibiscus budding, then I will take the test again.']
#
# ['In the story it says, ', " This quote shows how these plants remind her of her homeland, which she misses dearly and is very important to her. By bringing this plant back to her house, it's like she's bringing a little piece of her homeland. This quote:\x96 "]
#
# ['Almost reluctantly, she realized that many of the things that she had thought of as strange before had become, through the quiet repetition of season upon season, almost familiar to her now. like geese.']
#
# ['in the warm moist shelter of the greenhouse, Saeng broke down and wept.', 'I\x92m glad you got it,']
#
# ['When the snow melts']
#
# ['overhead...geese...honk...familiar to Saeng now (second to last paragraph).', 'omelet with slices of bitter melon']
#
# ['when they come back in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test again']
#
# ['in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test again,']
#
# ['Winter Hibiscus', 'When they come back, in the spring when the snow melt and the geese return and this hibiscus is budding, then I will take that test again,']
#
# ['What happened.', 'I- I failed the test']
#
# ['when they come back, Saeng vowed silently to herself, in the spring, when the show melts and the geese return and this hibiscus is budding, then I will take that test again.']
#
# ['Winter Hibiscus', 'why do you spend so much money on this beautiful plant when you could a had the famed bee-maags', 'Then the snow will melt and geese return and this hibiscus is budding, then I will return to take the test again.']
#
# ['Not like the tird we had before']
#
# ['The wind was blowing harder, tearing of the last remnants of green in the chicory weeds that were growing.']
#
# ['winter Hibiscus,']
#
# ['it\x92s flowers aren\x92t as pretty, but it\x92s strong enough to make it through the cold months here']
#
# ['Winter Hibiscus']
#
# ['Winter  Hibiscus']
#
# ['Winter Hibiscus,']
#
# ['when they come back, saeng vowed Silently to herself, in the spring, when the snow melts and the geese return and this hibiscus is budding, then I will take that test again']
#
# [' and this hibiscus is budding, then I will take that test again,']
#
# ['Saeng vowed silently to herself in the spring I will take the test again.']
#
# ['winter Hibiscus', 'When they come backin the spring then I will take that test again', 'in the springwhenthis hibiscus is budding']
#
# ['winter hibiscus ', 'I-I failed the test (@NUM1) this shows @CAPS2 leaving her homeland and makes her even more so sad, but she then promises herself that in the spring when flowers @LOCATION1 she will try again. She does this when she says to herself ']
#
# ['when they come back, Saeng vowed silently to herself, in the spring, when the snow melts when the geese return and this hibiscus budding, then I will take that test again']
#
# ['Winter Hibiscus ', 'when they come back, Saeng  vowed silently to herself, in the spring, when the snows melt and the geese return and the hibiscus the budding, then  I will take that test again.', 'Saeng day out a hole and carefully lowered the plant into it']
#
# ['Winter Hibiscus']
#
# ['winter hibiscus', 'but its strong enough to make it through the cold months.']
#
# ['test', 'Then I will take that test again']
#
# ['winter Hibiscus']
#
# ['Winter Hibiscus,', 'slowly fading into the distance', 'When they come back', 'the geese return and this hibiscus is budding', 'This hibiscus is budding']
#
# ['Saeng felt a shock of recognition so intense , it was almost visceral ']
#
# [' Winter Hibiscus', "....but it's strong enough to make it through the cold months here, this winter hibiscus ....", 'strong', 'winter hibiscus', 'Almost reluctantly, she realized that many of the things she had though strange before had become almost familiar...', '..in the spring, the geese return and this hibiscus is budding, then I will take that test again', 'spring ']
#
# ['Look how root - bound it is, poor thing', 'I-I failed the test', 'breaking point']
#
# ['when they come back in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test again']
#
# ['Saeng vowed silently to herself ']
#
# ["A were of less so deep and strong that it stung Saeng's eye", 'it\x92s a beautiful plant she finally said in sad you got it']
#
# ['Winter Hibiscus.', 'when they come back, Saeng vowed silently to herself, in the spring, when the snow melts and the geese return and this hibiscus is budding, then I will take that test again. To show or emphasize that if the hibiscus, a plant reminding her of her home, can over then so can she. In the story after the author had failed her driving test and was walking back home, seeing the flowers reminded her of home & connected her to her past making her felt less alone. For example, when the author says A wave of loss so deep & strong that it stung Saeng\x92s eyes now swept over her.', 'like the geese the distinctive V against the sky.']
#
# [' don\x92t  give  up.']
#
# ['Winter Hibiscus', 'when they come back, Saeng vowed silently to herself, in the spring, when the snows melt and the geese return and the hibiscus is budding, then I will take that test again.']
#
# ['when they come back, Saeng vowed silently to  herself , in the spring. When the snows melt and the geese situation and this hibiscus is budding, then I will take that test again. ']
#
# ['And in the war on moist shelter of the greenhouse, Saeng broke down and wept. ']
#
# ['wave of loss']
#
# [' when  they  come  back , in the spring , when the snows melt and  the  geese  return  and  this  hibiscus is budding , then  I  will  take that  test  again.']
#
# ['hear']
#
# ['I\x96I failed the test.']
#
# ['Winter Hibiscus', 'the geese return and this hibiscus is budding, then I will take the test again', 'when they come back, in the spring, when the snows melt and the geese return and this hibiscus is budding']
#
# ['Winter Hibiscus ', 'The wind was blowing harder, tearing off the last remnants of green in the chicory weeds.', 'strong enough to make it through the cold months here', 'many of the things she had thought of as strange before had become, through the qunet  repition of season upon season, almost familiar to her']
#
# ['I-I failed the test,', 'I will take that test again.']
#
# ['Winter Hibiscus', 'she relazed that many of the things that she had thought of as strange befor had become, through the quiet repetition of season upon season, almost fimilar to her now. This means that with every season she get more used to her new home and if became more like her and with every season. Another is when the author say\x92s she lifted her head and watched as their distinctive V was etched against the evening sky, slowly fading to the distance.']
#
# ['When they come back, Saeng vowed silently to herself, in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test again.', 'one of the blossoms had fallen off, and carefully Saeng picked it up and smelled it.', 'she tipped the pot and deftly eased the ball of soil out, balancing the rest of the plant in her other hand.']
#
# [' She had lifted her head and watched as their distinctive was etched ,', ' almost familiar to her now ,']
#
# ['[I] felt a shock of recognition so intense, it was almost visceral.', 'She realized that many of the things she thought of was strange before had becomealmost familiar to her now.']
#
# ['When they come back,Saeng vowed silently to herself .in the spring ,when the snow melt and the geese return and his hibiscus is budding ,then I will take the test again ']
#
# ['When they came back, Saeng vowed silently to herself, in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test again']
#
# ['then I will take that test again', 'I-@CAPS1] failed the test, [Ho, @NUM2] which brought the whole story together. She yearned for comfort as she seeked the ', ' [Ho, @NUM3] for comfort. Seeing this brought back all the memories of her life ', ' [@NUM1] that kept her going. As a result, bonding with her mother erupted, and it brought another day of hope for her future in her new home. Enough hope for her to say, ']
#
# ['winter Hibiscus']
#
# ['Winter Hibiscus', 'when they come back, saeng vowed silently to herself, in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test again.']
#
# ['jasmine', 'not a real one', 'not like the kind we had before.']
#
# ['flour is it and bought', 'dok faeng \x96 noi', '@CAPS1 hibiscus', ' ']
#
# ['When they come back, Saeng vowed silently to herself, in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test again.']
#
# ['Winter Hibiscus']
#
# ['Winter Hibiscus', 'it\x92s-it\x92s not a real one,', 'winter hibiscus']
#
# ['Winter Hibiscus ', 'she was still too shaky to say the words at home ', 'I failed the test ', 'winter Hibiscus']
#
# ['Winter Hibiscus', 'Saeng', 'Saebba', 'Madagascar periwinkle', 'How strange to see it in a pot, Saeng thought. Back home it just grew wild.!! But as her tour grew with time, she soon relizes she is missing some of her memories, and begins to cry. As she reaches home she is greeted by her mother. ', " Saeng said. Saeng's mother is touched by her comment, and cheers her up with planting the "]
#
# ['winter Hibiscus end the way it does because the narrator realizes that with simply comes a new chance or opportunity to start over a rebirth. One passage from the text that shows the narrator\x92s hope, ', 'Winter Hibiscus']
#
# [' ... I will take the test again.']
#
# ['realized that many of the things that she had thought of as strange before had become, through queit repitition of season upon season, almost familiar to her now.']
#
# ['Beautiful or calming']
#
# ['Winter Hibiscus,', 'pass the test.']
#
# ['Its flowers aren\x92t pretty, but it\x92s strong enough to make it through the cold months.']
#
# ['tear stains and puffy eyes']
#
# ['@CAPS1 give up.']
#
# ['As  Saebba  nedae  tall  and  lush. And  surrounded  there  garden', 'She  realized  that  many  of  the  things that she had thought strange before  had becomealmost  familiar  to  her how', ' I will take that test again']
#
# ['When they come back, Saeng vowed silently to herself, in the spring, when the snows melt and the geese return and this hisbiscus is budding, then I will take that test again,']
#
# ['Winter Hibiscus', 'when they come back, Saeng vowed silently to herself, in the spring, when the snow melt and the geese return and this hibiscus is dudding, then I will take that test again']
#
# ['The familiar fragrance filled her lungs and Saeng could almost feel the light strands of her grandmother\x92s long grey hair.', '??? Seen this kind blooming along the lake, it\x92s flowers aren\x92t as pretty, but it\x92s strong enough to make through the cold months.', 'Overhead, a flock of Canada geese flew by their fault honks clear and yes-familiar to Saeng now. She realized that many of the things that she had thought of as strange before had become almost familiar to her now.']
#
# [' its flowers arent as pretty, but its strong enough to make it through the cold months here. This winter hibiscus']
#
# ['Winter Hibiscus ']
#
# ['Winter Hibiscus', 'when they come back, saeng vowed silently to herself, when the snows melt and the geese return and this hibiscus is budding, then I will take the test again']
#
# ['Winter Hibiscus,']
#
# ['in the maint shelter of the greenhouse (she) broke down and wept,', ' to take that test again', 'when the geese return  and the hibiscus is blooming ']
#
# ['In the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test again. ']
#
# ['Overhead a of Canada geese flew by,their faint hunks clear and \x96yes-fimiliar to Saeng now ']
#
# ['I mean, not like the kind we had at\x96at-']
#
# ['when they come back, Saeng vowed silently to herself, in the spring, whe the snow melts and the geese return and this hibiscus is building, then I will take the test again']
#
# ['when the snows melt and the geese return and this hibiscus is budding, then I will take that test again,']
#
# ['so intense, it was almost visceral.', 'and the geese return.', 'plant']
#
# ['When they come back, saeng vowed silently to herself, in the spring, when the snows melts and the geese return and this hibiscus is budding, then I will take that test again. ']
#
# ['This hibiscus is budding, then I will take that test again.']
#
# ['hidiscus is budding']
#
# ['  because  the  author  started  out  the  story  after  Saeng  failed  her  driving  test  .  Saeng  is  reminded  from  the  Hibiscus  about  her  homeland.  After  Saeng  wanted  the  Hibiscus  in  the  garden  ,']
#
# ['But she had herself much preferred it to a big Mac.']
#
# ['the winter hibiscus was in the ground now,.']
#
# ['Winter Hibiscus']
#
# ['Winter Hibiscus', 'in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test again']
#
# [' In the spring , when the snow melt and the geese return and this hibiscus is budding .']
#
# ['when they come back, Saeng vowed silently to herself, in the spring, when the snows melt and the geese return and this hibiscus is budding. Then I will take that test again.']
#
# ['when they come back, Saeng vowed silently to herself, in the spring, when the snow melt and the gees return and this hibiscus is budding, then I will take the test again.']
#
# ['she realized that many of the things she had thought strange before had become, through the quiet repetition of season upon season, almost familiarizes to her.', 'bloom.', 'bloom.']
#
# ['and the geese will return and this hibiscus in budding, then I will take that test again,']
#
# [' Winter Hibiscus', 'when they come back, Saeng vowed silently to herself, in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take test again,', 'Winter  Hibiscus', 'realized that many of the things that she had thought  of as strange before had become, through the guiet repetition of season upon season, almost familiar to her now. Like the geese.', 'Winter Hibiscus', 'The familiar  fragrance filled her lungs, and Saeng could  almost fast the light strures of her grandmothers long gray hair, freshly mashed.']
#
# ['in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that the test again', 'in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test again']
#
# ['winter Hibiscus']
#
# ['and this hibiscis is budding', 'then I will take that test again,']
#
# ['Winter Hibiscus', 'it\x92s strong enough to make it through the cold months. That\x92s what matters']
#
# ['Winter Hibiscus', 'I mean its not the kind we at-at-']
#
# ['Winter Hibiscus', 'when they come back, Saeng vowed silently to herself, in the spring, when the snows melt and the geese return and this hibiscus is budding, the I will take the test  again.']
#
# ['Winter Hibiscus', 'when the snow melts and the geese return.']
#
# ['Its not a real one', 'Not like the kind we had before.']
#
# ["She paused as she noticed the tearstains on her daughter's cheeks and her puffy eyes. ", ' then I will take the test again.']
#
# ['I will take that test again.']
#
# ['Winter Hibiscus']
#
# ['In the spring, when the snows melt and the geese return and this hibiscus is building, then I will take that test again.']
#
# ['@CAPS1 seen this kind blooming along the lake. Its flowers arent as pretty, but its strong enough to make it through the cold months here, this winter hibiscus. Thats what matters.']
#
# ['when they come back, Saeng vowed silently to herself, in the spring, when the snow melt and the geese return and this hibiscus is budding, then I will take that test again.', 'test', 'when they come back, Saeng vowed silently to herself, in the spring, when the snow melt and the geese return and this hibiscus is budding, then I will take that test again']
#
# ['As Saeng walks home after failing her driver\x92s test, she sees a familiar plant.', '@PERSON1 uttered a small cry of surprise and delight.', ' she said. ', ' That was a quote stating that her mother was excited to hear that. The story is concluded by that paragraph because after all saeng went through her mother was glad she bought it. ', ' she finally said. ']
#
# ['Winter Hibiscus', 'when they come back. Saeng vowed siletly to herself, iN the sprng, when the snows melt and the gesse return and this hibiscus is budding, then I will take that test again.', 'I paid over Nineteen dollars for it.', ' You what?', ' @CAPS1 facing. Na where did you gott that', 'winter hibiscus']
#
# ['When they come back, Saeng vowed silently to herself, in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test again,']
#
# ['I-I failed the test,']
#
# ['and the geese return and this hibiscus is budding,']
#
# ['Winter Hibiscus,', 'winter hibiscus', 'she could hear the sounds of cooking from the kitchen now,']
#
# ['When they come back, Saeng vowed silently to herself, iN the spring, wheN the @CAPS1 melt and the geese RetuRN and this hibiscus is budding, then I will take that test again']
#
# ['geese return and this hibiscus is budding']
#
# ['I will  take that test again,', ' when they come back.... when the show me it and the geese return,', ' She realized that many of the things that she had thought of as strange before had become  almost familiar to her. Like the geese,', ' When she uses ', ' she is saying how she will remember all the things she has forgotten when she moved over here to this country.']
#
# ['I-I failed the test,', 'She was still too shaky to say at home', 'When the snows melt and the geese return and this hibiscus is budding, then I will take this test again.']
#
# ['Winter Hibiscus', 'when they come back, Saeng vowed silently to herself, in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test again', 'And besides it was yet another old friend. a small shrub with waxy leaves and dainty flowers with purplish petals and white centers.', 'I-I failed the test']
#
# ['Plants that she had not even realized she had known but had forgotten drew her back into her childhood world.']
#
# ['comfort tone']
#
# ['winter hibiscus', 'when they came back, Saeng vowes silently to herself, in the spring, when the snow melt and the geese return and the hibiscus is budding, I will take that test again. I believe she concluded this story with these words she change because she is saying to you in that means when the birds flewaway. Even the bird seasons would be back like always. An example of this is when she says the birds eased into the hibiscus. Mingled because the last paragraph thinking that she would stay again next season and keys very what she likes to do. This what I get out as the last paragraph are the story ']
#
# ['will take that test again']
#
# ['Winter Hibiscus,', 'When they come back take that test again. ', '@CAPS1 I will take that test again.', 'And in the warm moist shelter of the greenhouse, Saeng broke down and wept.']
#
# ['When they come back, Saeng vowed silently to herself, when the snows melt and the geese return and this hibiscus is budding then I will take that test again.']
#
# ['When they come back, Saeng vowed silently to herself, in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test again.', 'I mean, not like the kind we had at home.']
#
# [' I failed the test .']
#
# ['I mean, not like the kind we had @NUM1at-']
#
# ['I will take that test again.', 'when the snow melts and the geese return and this hibiscus is budding.']
#
# ['When they come back, Saeng vowed silently to herself, in the spring, When the snows melt ant the geese return and this hibiscus is budding, then I will take the test again,', "'but its strong enough to make it Through the cold months here, This winter hibiscus That\x92s what matters.", '...When the snows melt...']
#
# ['Where Saeng vowed silently to herself,']
#
# ['When the snows melt and the geese return and this hibiscus is budding.', 'familiar to Saeng now ', 'strange before.', 'take that test again', 'When the snows melt']
#
# ['I will take that test again.', 'when they come back']
#
# ['In the spring, when the snows melt and geese return and this hibiscus is budding, then I will take that test again.']
#
# ['test']
#
# ['when they come back In the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take the test again.']
#
# ['Winter Hibiscus']
#
# ['when the snow  melts and the geese return and this hibiscus is budding, then  I will take that test again', 'renewed']
#
# ['home.', 'in the spring, and the geese return']
#
# ['It was like walking into another world. A hot, most world exploding with greenery.... Plants that she had not even realized she had known but had forgotten drew her back to into her childhood world.']
#
# ['Winter Hibiscus']
#
# ['when they come back, Saeng vowed silently to heRselF, in the spRing, when the snows melt and the geese REtuRn and this bibiscus is budding, then I will take that test again.']
#
# ['Winter Hibiscus', 'when they come back, Saeng vowed silently to herself, in the spring, when the snows melt, and the geese return and this hibiscus is budding, then I will take that test again, ', 'When the snows melt and then geese return', 'Like the geese. She lifted her head and watched as their distinctive I was etches against the evening sky, slowly seeing into the distance', 'when they come back, Saeng vowed silently to herself in the spring, when the snows melt and the geese return and this hibiscus is holding then I will take that test again']
#
# ['But its strong enough to make it through the cold months']
#
# ['Winter Hibiscus,', 'in the spring, when the snow melts and the geese return and this hibiscus is budding, then I will take the test again,']
#
# ['In the spring when the snows melt and the geese return and this hibiscus is budding, then I will take that test again']
#
# ['the winter hibiscus was in the ground now and Saeng tamped down the soil around it overhead at lock of Canada geese flew by']
#
# ['return', 'I paid nineteen dollars for  it']
#
# ['A wave of loss so deep and strong stang Saeng\x91s eyes now and swept over her ', ' in the warm moist shelter of the greenhouse, Saeng brake down and wept.', 'and this hibiscus is budding, I will take that test again.']
#
# ['Winter Hibiscus', 'when they come back, Saeng vowed silently to herself, in the spring when the snows melt and the geese return and this hibiscus is building, then I will take that test again. The auther finishes the story with that paragraph because in the beginning, Saeng had purchased hibiscus plant because it had reminded her of her hometown. (', ') So she purchased it, but since there was bad weather at the time, Saeng had to get the plant back in time and plant it in the graden. But she failed setting if there on time. That is why it says ']
#
# ['Winter Hibiscus', 'When they come back, \x91Saeng vowed silently to herself, in the spring, when the snow melts and the geese return and this hibiscus is budding, then I will take the test again.', 'Almost familiar to her now. Like geese.']
#
# ['Winter Hibiscus', ' When they come back, Saeng vowed silently to herself, in the spring, when the snows melt and the geese return and this hibiscus is budding  then I will take that test again. ', 'through the quiet repetition of season upon season, almost familiar to her now.']
#
# ['When they come back, Saeng vowed silently to herself in the spring, when the snows melt & the geese return & this hibiscus is budding, then I will take that test again,']
#
# ['vowed']
#
# ['almost familiar to her now']
#
# ['I failed the test,']
#
# ['When they come back, Saeng vowed silently to herself, in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test again,', 'You what?']
#
# ['Saeng']
#
# ['In the spring when the snow melts and the geese return and the hibiscus is budding, then I will take the test again']
#
# ['when the shows me', 'Saeng  brokedown and wept!', 'show will melt', 'yet another old friend']
#
# ['Winter Hibiscus', 'Saeng felt a shock recognition so intense, it was almost visceral. ']
#
# ["It\x92s-it's not a real one...I mean, not like the kind we had at..."]
#
# ['when the snow melts and the geese return and this hibiscus is budding, then I will take that test']
#
# ['I know', 'I\x92ve seen this kind blooming along the lake. It\x92s flower aren\x92t as pretty, but it\x92s strong enough to make it through the cold months here, this winter hibiscus.']
#
# ['familiar to her', '..she  realized that many of the things that she had thought of as strange before had become almost familiar to her now.', ' A work so deep and strong that it stung Saeng\x92s eyes now swept over her.', 'old friends']
#
# ['when the come back, Saeng vowed silently to herself, in the spring, when the snow melt and the geese return and this hibiscus is budding, then I will take that test again.']
#
# ['Winter Hibiscus', 'When they come back, Saeng vowed silently to herself, in the spring when the snow melts and the geese return and this hibiscus is budding, then I will take the test again']
#
# ['Winter Hibiscus', 'In the spring, when the snow melt and the geese return and this hibiscus is budding, then I will take that driving test again']
#
# ['when the snows melt and the geese return and his hibiscus is budding, then I will take that test again.', 'I-I failed the test.']
#
# ['aware of loss so deep and strong that it stung Saeng\x92s eyes now swept over her. ', 'The pungent small of bitter melon wafted out, and Saeng\x92s mouth watered,', 'The winter hibiscus\x92 was in the ground now', 'overhead a flock of Canada geese flew by, their faints honks clear and \x96 yes \x96 Familiar to Saeng now.']
#
# ['...and the geese return and this is budding, I will take that test again', 'gives her strength from her old country']
#
# ['I-I failed the test']
#
# ['to show how saeng has changed throughout the plot of the story. In the beginning she refers to her new home as, ', ' As teenager she had to move from Vietnam where traditions are so much different than in the United States. However, there is one plant that is similar, the winter Hibiscus. The plant connects her previous life and home to the life and home she lives now. It was hard to adapt to the situation of moving, but the plant created familiar scents and the ', 'which ', ' It was even difficult for saeng to say the words ']
#
# ['when the snows melt and the geese return', 'when this hibiscus is budding,']
#
# ['I will take the test again.']
#
# ['Winter Hibiscus', 'In the spring, when the snow melts and the geese return and this hibiscus is budding, then I will take that test again.']
#
# ['saeng .teenage  girl, and her family have moved to the united states of Vietnam.']
#
# ['winter Hibiscus ', 'it\x92s the flowers aren\x92t as pretty, but it\x92s strong enough to make it through the cold months here, thes winte hibiscus. That\x92s what matters.']
#
# ['when they come back, Saeng vowed silently to herself, in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test again', 'I \x96 I failed the test']
#
# [' ...and this hibiscus is budding, then I will take that test again.']
#
# ['When they come back, in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test again', ' A wave of loss so deep and strong that it stung Saeng\x92s eye now swept over her.']
#
# ['strong enough to make it through the cold months here.']
#
# ['when they come back... and this hibiscus is budding, then I will take that test again']
#
# ['Saeng vowed silently to herself', 'winter season', 'Hibiscus costs nineteen dollars', 'There was frail, wiry beauty to her Saeng mother that touched Saeng deeply']
#
# ['Winter Hibiscus,', 'when they comeback, in the spring, when the snow melts and the geese return and the hibiscus is budding then I will take that test again.', 'plant she had forgotten drew her back to her childhood world. ']
#
# [' I I failed the test,', 'saeng vowed silently to herself, in the spring, when the snow melts and the geese return and this hibiscus is budding ,then I will take that test again,']
#
# ['Winter Hibiscus', 'Saeng did not dare look her mother in the eye']
#
# [' I will take that test again']
#
# [' Winter Hibiscus']
#
# ['When they come back,', 'the snow melts', 'this hibiscus is budding,', 'take that test again']
#
# ['when the snow melt in the spring and the geese return and this hibiscus is budding, then I will take that test again. The flower was very important to her. She said, ']
#
# ['In the spring, when the snow melts and the geese return and this hibiscus is budding, then I will take that test again.']
#
# ['@CAPS1 Hibiscus', 'And in the warm moist shelter of the greenhouse, Saeng broke down and wept.', 'almost reluctantly, she realized that many of the things that she had thought of as strange before had become through the quiet repetition of season upon season, almost familiar to her now.', 'She found that she was still to shakey to say the word at home, lest she burst into tews again.']
#
# ['as the snow melts away;', 'exploding, shock ,intense']
#
# [' when they come back, Saeng vowed silently to herself, in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take the test again.', 'Its\x92 flower arn\x92t as pretty, but it\x92s strong enough to make it throu in here, this winter hibiscus.', 'like the geese she lifted her head and watched as their distinctive V was etered against the evening sky, slowly fading into the distance.']
#
# [' she noticed the tearstains on her daughter\x92s cheeks and her puffy eyes', 'she admitted to herself, she much preferred it to a Big Mac', 'she realized that many of the things that she had thought of as strange before had become familiar to her now ']
#
# ['You what?', '(Ho ). When her mothesaid this, it showed that she was displeased. The narrative states, ', '(Ho). Saeng was not proud to displease her parents in any way. By saying, ']
#
# ['then I will take that test again.']
#
# ['she reached out and touched petal gently. It felt smooth and cool, with a hint of velet toward the centre']
#
# ...
#  'when they come back, Saeng  vowed silently to herself, in the spring, when the snows melt and the geese return and the hibiscus the budding, then  I will take that test again.',
#  'when they come back, Saeng vowed sileltly to herself, in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take the test again. ',
#  'when they come back, Saeng vowed silently to  herself , in the spring. When the snows melt and the geese situation and this hibiscus is budding, then I will take that test again. ',
#  'when they come back, Saeng vowed silently to heRselF, in the spRing, when the snows melt and the geese REtuRn and this bibiscus is budding, then I will take that test again.',
#  'when they come back, Saeng vowed silently to herself in the spring, when the snow melt and the geese return and this hibiscus is budding, then I will take that test again,',
#  'when they come back, Saeng vowed silently to herself in the spring, when the snow melt and the geese return and this hibiscus is budding, then I will take that test again.',
#  'when they come back, Saeng vowed silently to herself in the spring, when the snows melt and the geese return and the hibiscus is budding, then I will take that test again.',
#  'when they come back, Saeng vowed silently to herself in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test again.',
#  'when they come back, Saeng vowed silently to herself in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test. From the story ',
#  'when they come back, Saeng vowed silently to herself in the spring, when the snows melt and the geese return and this hibiscus is holding then I will take that test again',
#  'when they come back, Saeng vowed silently to herself, In the spring, when the snow melt and geese return and this hibiscus Is budding, then I will take the test again.',
#  'when they come back, Saeng vowed silently to herself, in the spring , when the snows melt and the geese return and this hibiscus is budding, then I will take that test again.',
#  'when they come back, Saeng vowed silently to herself, in the spring when the snows melt and geese return and this hibiscus is budding, then I will take that test again.',
#  'when they come back, Saeng vowed silently to herself, in the spring when the snows melt and the geese return and this hibiscus is budding, then I will take that test again',
#  'when they come back, Saeng vowed silently to herself, in the spring when the snows melt and the geese return and this hibiscus is budding, then I will take that test again. The author\x92s reasoning for saying this is because the presence of memories from Saeng\x92s homeland comforts her. So much that they she will pass her test with ease because she will not be nervous. ',
#  'when they come back, Saeng vowed silently to herself, in the spring when the snows melt and the geese return and this hibiscus is building, then I will take that test again. The auther finishes the story with that paragraph because in the beginning, Saeng had purchased hibiscus plant because it had reminded her of her hometown. (',
#  'when they come back, Saeng vowed silently to herself, in the spring, whe the snow melts and the geese return and this hibiscus is building, then I will take the test again',
#  'when they come back, Saeng vowed silently to herself, in the spring, when the show melts and the geese return and this hibiscus is budding, then I will take that test again.',
#  'when they come back, Saeng vowed silently to herself, in the spring, when the snow melt and the gees return and this hibiscus is budding, then I will take the test again.',
#  'when they come back, Saeng vowed silently to herself, in the spring, when the snow melt and the geese return and this hibiscus is budding, the I will take that test again',
#  'when they come back, Saeng vowed silently to herself, in the spring, when the snow melt and the geese return and this hibiscus is budding, then I will take that test again',
#  'when they come back, Saeng vowed silently to herself, in the spring, when the snow melt and the geese return and this hibiscus is budding, then I will take that test again.',
#  'when they come back, Saeng vowed silently to herself, in the spring, when the snow melt and the geese return and this hibiscus is budding, then I will take thattest again',
#  "when they come back, Saeng vowed silently to herself, in the spring, when the snow melt and the geese return and this hibiscus is budding, then I will take the test again. The author ends the story in such a way in order to reveal the hope that lies in Saeng's future. After failing her drivers's test, Saeng returns home with disappointment and sadness. This last paragraph, however, shows that soon enough Saeng's luck will change. The reader is left with a hint that Saeng will retake her test and pass. Also, this ending paragraph reflects upon Saeng's determined personality to overcome many obstacles she is @CAPS1. This paragraph proves she will not give up even after she was forced to live in the United states instead of her home. Her success in fitting in with her new life is shown when through the quote, ",
#  'when they come back, Saeng vowed silently to herself, in the spring, when the snow melt and the geese return and this hibiscus is dudding, then I will take that test again',
#  'when they come back, Saeng vowed silently to herself, in the spring, when the snow melts and the geese return and this hibiscus is budding, then I will take that test again.',
#  'when they come back, Saeng vowed silently to herself, in the spring, when the snow melts and the geese return and this hibiscus is budding, then I will take that test again. ',
#  'when they come back, Saeng vowed silently to herself, in the spring, when the snow melts and the geese return and this hibiscus is budding, then I will take that test again. To show or emphasize that if the hibiscus, a plant reminding her of her home, can over then so can she. In the story after the author had failed her driving test and was walking back home, seeing the flowers reminded her of home & connected her to her past making her felt less alone. For example, when the author says A wave of loss so deep & strong that it stung Saeng\x92s eyes now swept over her.',
#  'when they come back, Saeng vowed silently to herself, in the spring, when the snow melts and the geese return and this hibiscus is budding, then I will take the test again.',
#  'when they come back, Saeng vowed silently to herself, in the spring, when the snow melts when the geese return and this hibiscus budding, then I will take that test again',
#  'when they come back, Saeng vowed silently to herself, in the spring, when the snows melt and the geese return and the hibiscus is budding, then I will take that test again.',
#  'when they come back, Saeng vowed silently to herself, in the spring, when the snows melt and the geese return and the hibiscus is buding, then I will take the test  again.',
#  'when they come back, Saeng vowed silently to herself, in the spring, when the snows melt and the geese return and this hibiscus  is budding, then I will take that test again.',
#  'when they come back, Saeng vowed silently to herself, in the spring, when the snows melt and the geese return and this hibiscus is budding ,then I will take that test again .',
#  'when they come back, Saeng vowed silently to herself, in the spring, when the snows melt and the geese return and this hibiscus is budding, than I will take that test again.',
#  'when they come back, Saeng vowed silently to herself, in the spring, when the snows melt and the geese return and this hibiscus is budding, the I will take the test  again.',
#  'when they come back, Saeng vowed silently to herself, in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take test again,',
#  'when they come back, Saeng vowed silently to herself, in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test again',
#  'when they come back, Saeng vowed silently to herself, in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test again,',
#  'when they come back, Saeng vowed silently to herself, in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test again.',
#  'when they come back, Saeng vowed silently to herself, in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take the test again. By concluding the story in that way it helps demonstrate the hope the hibiscus plant brought to her after she failed her drivers test. The hibiscus the helped give Saeng one step closer to adapting to her new home. It says in the story Almost reluctantly, she realized that many of the things that she had thought of strange before, through the quit repition of season upon season, almost femiliar to her now.',
#  'when they come back, Saeng vowed silently to herself, in the spring, when the snows melt and the geese return and this hibiscus is budding. Then I will take that test again.',
#  'when they come back, Saeng vowed silently to herself, in the spring, when the snows melt ant the geese return and this hibiscus is budding, then I will take the test again',
#  'when they come back, Saeng vowed silently to herself, in the spring, when the snows melt, and the geese return and this hibiscus is budding, then I will take that test again, ',
#  "when they come back, Saeng vowed silently to herself, in the spring, when the snows melt. and the geese return and this hibiscus is budding, then I will take that test again'' because the hibiscus represents hope and adapting to circumstances. Saeng is trying to adapt to the new changes in herlife but nothing is working out for her.",
#  'when they come back, Saeng vowed silently to herself, in the spring, when the snows melts and the geese return and this hibiscus budding, then I will take that test again.',
#  'when they come back, Saeng vowed silently to herself, in the spring. when the snows melt and the geese return and his hibiscus is budding, then I will take that test again.',
#  'when they come back, Saeng vowed silently to herself, it the spring, when the snow melt and the geese return and the hibiscus budding, then I will take the test again.',
#  'when they come back, Saeng vowed silently to herself., in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test again',
#  'when they come back, Saeng vowed silently to herself...,',
#  'when they come back, Saeng wowed silently to herself, in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test again',
#  "when they come back, Saeng's vowed silently to herself, in the spring, when the snow melts and the geese return and this hibiscus is budding, then I will take the test again.",
#  'when they come back, in spring, when the snow melt and the geese return and this hibiscus is budding, then I will take that test again',
#  'when they come back, in the spring, when the snow melt and the geese return and this hibiscus is budding, then I will take that test again',
#  'when they come back, in the spring, when the snow melt and the geese return and this hibiscus is budding, then I will take the test again.',
#  'when they come back, in the spring, when the snows melt and the geese return and this Hibiscus is budding, then I will take that test again.',
#  'when they come back, in the spring, when the snows melt and the geese return and this hibiscus is budding',
#  'when they come back, in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take the test again',
#  'when they come back, saeng vowed Silently to herself, in the spring, when the snow melts and the geese return and this hibiscus is budding, then I will take that test again',
#  'when they come back, saeng vowed silently to herself, in the sprinG, when the snows melt and the geese return and this hibiscus is buddiNG, then I will take that test again',
#  'when they come back, saeng vowed silently to herself, in the spring when the snow melts and the geese return and the hibiscus is budding, then i will take the test again',
#  'when they come back, saeng vowed silently to herself, in the spring when the snows melt and the geese return and this hibiscus is buding, then I willtake that test agien.',
#  'when they come back, saeng vowed silently to herself, in the spring, when the snows melt and the geese return and its hibiscus is budding, then I will take that test again.',
#  'when they come back, saeng vowed silently to herself, in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test again',
#  'when they come back, saeng vowed silently to herself, in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test again.',
#  'when they come back, saeng vowed silently to herself, when the snows melt and the geese return and this hibiscus is budding, then I will take the test again',
#  'when they come back. Saeng vowed siletly to herself, iN the sprng, when the snows melt and the gesse return and this hibiscus is budding, then I will take that test again.',
#  'when they come back... I will take that test again',
#  'when they come back... and this hibiscus is budding, then I will take that test again',
#  'when they come back... in the spring, when the snow melts and the geese return...',
#  'when they come back...then I will take that test again,',
#  'when they come back...then I will take the test again.',
#  'when they comeback, in the spring, when the snow melts and the geese return and the hibiscus is budding then I will take that test again.',
#  'when they comes back, saeng vowed silently to herself, in the spring, when the snows melt & the geese reture and this hibiscus is budding, then I will take that test again',
#  'when this hibiscus is blooming, I will take the test again.',
#  'when this hibiscus is budding,',
#  'which ',
#  'why do you spend so much money on this beautiful plant when you could a had the famed bee-maags',
#  'why they come back, Saeng vowed silently to herself, in the spring, when the snows melt and the geese return and this hibiscus is budding, then I will take that test again',
#  'will take that test again',
#  'winter',
#  'winter  hibiscus ',
#  'winter @CAPS1',
#  'winter Hibiscus',
#  'winter Hibiscus ',
#  'winter Hibiscus end the way it does because the narrator realizes that with simply comes a new chance or opportunity to start over a rebirth. One passage from the text that shows the narrator\x92s hope, ',
#  'winter Hibiscus saeng made a promise to herself that she would never fail the test again Saeng wanted to remember her past and homeland. That is why she bought the flowers. At the end of the story she vows,',
#  'winter Hibiscus,',
#  'winter hibiscus',
#  'winter hibiscus ',
#  'winter hibiscus,',
#  'winter hibiscus.',
#  'winter season',
#  'yet another old friend',
#  'you what? Her mother stared at her increously.',
#  '\x92when they come back,\x92 Saeng vowed silently to herself,\x92in the spring, when the snow melts and the geese return and this hibiscus budding. then I will take that test again.\x92'}

# %%
set4essay_quotes = ['will take that test again', 'many of the things that she had thought of as strange', 'not like the kind we had before', 'I failed the test', 'rich sweet scent', 'when the snow melts', 'geese return', 'hibiscus is budding', 'gentle grandmother', 'distinctive V was etched against the evening sky', 'familar fragrance filled her lungs', 'could almost feel light strands of her grandmother long gray hair', 'attitude towards her new country and her driving test', 'hibiscus plant in the winter is not as beautiful in the bitter cold', 'adapts and survives', 'returns to its beautiful state in the spring', 'bitter about her new country and driving test', 'new start or new opportunity', 'memories of home', 'overcoming her obstacles', 'noticed tear stains on her a daughter cheeks and her puffy eyes', 'symbolize change and adoption', 'make it through the winter into the spring', 'life is blooming', 'she was still too shaky to say the words at home', 'bitter melon']

# %%
set4[set4['domain1_score'] == 3]['essay'].sample(1).iloc[0]
# Out:
# 'The author concludes the story with this last paragraph because it shows by spring she will be ready to retake her test. It shows that like the geese who care and come back, she will have time to study and pass her test. In the story the author includes this last paragraph to truly show her dedication to eventually grow to be comfortable in her new home and to pass her drivers test all in good time. Saeng wants to be comfortable with her new life but isn\x92t yet because of what one misses. But she knows that after this she can go back and try again just like the geese do often our winter. This was a very effective way to end the story because it really communicated Saeng\x92s message of dedication and longing to overcome her obstacles, her new home and driving.  '

# %%
len(set4essay_quotes)
# Out:
# 21

# %%
set5 = pd.read_csv('set5_features.csv')

# %%
set5_keywords = set()

for i in set5['essay']:
    unicode_converted = i.replace("\x93", '"').replace("\x94", '"').replace("\x85",  '')
    quotes = get_quotes(unicode_converted)
    if len(quotes) > 0:
        print(quotes, "\n")
        set5_keywords.update(quotes)

set5_keywords
# Out:
# [' family']
#
# ['despite customs elsewhere, all of these cultures came together in solidarity and friendship', 'as many immagrants do, to give their children a better life', 'Mother and father had come to this country with such courage, without any knowledge of the language or the culture']
#
# ['family']
#
# ['I will never forget how my parents turned this simple house into a home', 'I will be grateful to my parents for their love and sacrifice', 'My mother and father came to this country with such courage, without any knowledge of the language or the culture']
#
# ['Home: The Blueprints of Our Lives', 'Here, the innocence of childhood, the congregation of family and friends, and endless celebrations that encompassed both, formed the backdrop to life in our warm houses.', "It was here where I learned the real definition of 'family'... I will never forget how my parents turned the simple house into a home.", 'Home: The Blueprints of Our Lives']
#
# ['I will never forget how my parents turned this simple house into a home.', 'family', 'My parents always kept their arms and their door open to the many people we considered family...', 'family', 'In our neighborhood, despite customs elsewhere, all these cultures came together in great solidarity and friendship.']
#
# ['I will always be grateful to my parents for their love and sacrifice.', 'Here, the innocence of childhood, the congregation family and friends, and endless celebrations that encompassed both, formed the backdrop to life in our warm home.']
#
# ['...and a love of cooking that is still with me today (and for which I am eternally grateful). Passionate cuban music (which I adore to this day) filled the air, mixing with the aromas, of the kitchen.']
#
# ['warmth', 'My parents always kept their arms and their door open to the many people we consider family, knowing that they would do the same for us.']
#
# ['They came selflessly, as many immigrants do, to give their children a better life, even though it meant leaving behind their families, friends, and careers in the country the loved,', 'It was here where I learned the real definition of ', ',', 'I will never forget how my parents turned this simple house into a home,']
#
# ['I will always be greatfull to my parents...']
#
# ['I will always be grateful to my parents for their love and sacrifice. The mood is also joyful because, although the author lived in just a simple house, inside, there was always music and he was influenced by his culture. ', ' After all a house is only a ', ' if you feel welcome and love, and that is exactly how the author felt. Lastly, the mood is loving because in his home, his parents welcomed anyone who needed help. Example from the memoir is, ']
#
# ['parents created our traditional Cuban home, part of which was the kitchen', 'My parents always kept their arms and their door to the many people he considered family']
#
# ['Here, the innocence of childhood, the congregation of family and friends, and endless celebrations that encompassed both, formed the back-drop to life in our warm home.', 'They came selflessly, as many immigrants do, to give their children a better life, even though it meant leaving behind their families, friends, and careers in the country they loved.', "It was here that I learned the real definition of the word 'family.' And for this, I will be forever grateful."]
#
# ['I will always be grateful to my parents for their love and sacrifice.', 'My parents always kept their Arms and door open to the many people we considered family.']
#
# ['Growing up in this enviroment instilled in me a great sense that ', ' had nothing to do with being a blood relative', 'I learned the real definition of ', '. And for this, I will never forget that house or its gracious neighborhood or the many things I learned there about how to love', 'family']
#
# ['@PERSON1 Rodriguez', 'My parents both shared cooking duties and unwittingly passed on to me their rich culinary skills', '...Formed the backdrop to life in our warm home', "I've often told them of my admiration for their strength and perseverance, and i've thank them repeatedly"]
#
# ['Narciso Rodriguez', 'I will never forget how my parents turned this simple little house into a home.']
#
# ['without any knowledge of the language or culture.', 'Countless extaded family members came & went- and there was often someone staying with us temporarily until they were able to get back on their feet. My parents always kept their arms & their door open to the many people we considered family, knowing that they would do the same for us.']
#
# ['together in a great solidarity and friendship.']
#
# ['I will never forget how my parents turned this simple house into a home']
#
# ['I will always be grateful to my parents for their love and sacrafice.']
#
# ['In our neighborhood, despite customs elsewhere, all of these cultures came together in great soliderity and friendship.', 'I will always be greatful to my parent for their love and sacrifice.', 'They showed me with their lives, and these teachings have been the basis of my life.']
#
# ['@PERSON1 creates a happy and loving mood. In a time when racism and segregation was normal in @LOCATION2, @PERSON2 and his family had many happy times in his home in Newark, New Jersey. His town was filled with Cuban, Spanish, and Italian immigrants. His neighborhood was united and hardworking. In his memoir, Rodriguez writes about his kind parents. In the memoir, it states, ', " (p. @NUM1). Rodriguez's family was always willing to help others because they knew the favor would be returned. The Rodriguez family used their strong kindness to help everyone in the neighborhood. In return, they were respected. Also, Narciso Rodriguez writes about the bravery of his parents.  He writes, ", ' (p.@NUM1-13).  His parents wanted to help their children and give them better lives. They sacrificed their needs and wants for their children.  The @CAPS1 loves his parents because of their sacrifice and love. Last but not least,  Narciso Rodriguez writes about the struggles of his parents.  He writes ']
#
# ['I would not know my real grand parents Narciso the Elder and consuelo, until 1970 when they were allowed to leave Cuba.']
#
# ['Narciso @CAPS1', 'Growing up in this enviroment instilled in me a great sense that ', ' had nothing to do with being blood related', 'It was a close knit community of honest, hardworking imigrants who extended a hand to people who, while not necessarily their own kind, were clearly in need.']
#
# ['Home: The Blueprints of Our Lives,', 'eternally grateful for his family and everything they did for him. For example, ', ' @CAPS1 admires ', ' @PERSON1 feels that ', ' @PERSON1 ', ' @PERSON1 ']
#
# ['My Parents both shared cooking duties and unwrittingly Passed on to me their rich culinary skills and a love of cooking that is still with me today']
#
# ['I will never forget how my parents turned this simple house into a home', 'It was a close \x96 knit community of honest, hardworking immigrants who extended a hand to people who, while not necessarily their own kind, were clearly in need', 'They came selflessly to give their children a better life I will always be grateful to my parents for their love and sacrafice']
#
# ['I will never forget how my parents turn this simple house into a home']
#
# ['@PERSON1 my babysitter and my first friend lived above us and @PERSON1 graced our table for meals more often than not.', 'I will never forget how my parents turned this simple house into a home.']
#
# ['@CAPS1 graced our kitchen table for meals more often than not.', 'there was often someone staying with us temporarily until they were able to get back on their feet.', 'I celebrated my first birthdays. Mood it was in the warmth of the kitchen in this humble house where a Cuban feast alwase filled the air.']
#
# ['My parents both shared a love of cooking duties and unwittingly passed on to me their rich culinary skills and a love of cooking that is still with me today (and for which I am externally grateful). Passionate Cuban music (which I adore to this day) filled the air, mixing with the aromas of the kitchen.', 'My parents always kept their arms and their door open to the money people we considered family, knowing they would do the same for us.', "I will always be grateful to my parents for their love and sacrific. I've often told them that what they did was a much more corageous thing that I could have ever done."]
#
# ['Created our traditional Cuban home, the very heart of which was the kitchen.']
#
# ['Narciso Rodriguez']
#
# ['I will always be grateful to my parents for their love and sacrifice.', 'Here in the innocence of childhood, the congregation of family and friends, and endless celebrations....', 'In our neighborhood despite customs elsewhere, all of these cultures came together.']
#
# ['eternally grateful for his rich culinary skills that were passed on to him by his parents. @PERSON1 also talked about the role of ']
#
# ['I learned there how to love. I will never forget, and parents turned this simple house into a home']
#
# ['@PERSON1', 'I will never forget how my parents turned this simple house into a home']
#
# ['My parents both shared cooking duties and unwillingly passed on to me their rich culinary skills and a love of cooking that is still with me today (and for which I am eternally greatful).', 'Passionate Cuban music (which I adore to this day) filled the air mixing with the aromas of the kitchen.', 'Our landlord and his daughter, Alegria (my babysitter and first friend), lived above us, and Alegria graced our kitchen table for meals more often then not.']
#
# ['solidority.', 'My parents both shared cooking duties and unwittingly passed on to me their non culinary skills and a love of cooking that is still with me to today (and for which I am eternally grateful). Passionate cuban music (which I adore to this day filled the air, mixing with the aromas of the kitchen.', 'growing up in this enviroment instilled in me a great sense that ', ' This is now the mood created by the author was ']
#
# ['Narciso Rodriguez', 'In our neighborhood, despite customs elsewhere, all of the cultures came together in great solidarity and friendship.', 'I was born into this simple house, situated, in a two-family, blond-brick, building in the Ironbound section of Newark, New Jersey,', 'I will never forget how my parents turned this simple house into a home,']
#
# ['Narciso Rodriguez', 'I will always be grateful to my parents for their love and sacrifice.']
#
# ['house', 'home', 'heart']
#
# ['Growing up in this enviorment instilled in me a great sence that ', ' had nothing to do with being blood relatives.', 'I will always be grateful to my parents for their love and sacrifice.The third and final example is in paragraph @NUM3 when the author writes, ']
#
# ['in our neighborhood despite customs else where, all of the cultures came together in a great solidarity and friendship. I say happy because the author was happy to enjoy having so many friends and family to come over everyday and have fun. another mood is grate full the author as it says in the story ', 'parents created our traditional Cuban home', 'passed on to me the rich culonary skills and love for cooking', 'where I celebrated my first birthdays']
#
# ['In our neighborhood despite customs elsewhere, all of these cultures came together in great solidarity and friendship.', 'I will always be grateful to my parents for their love and sacrifice.']
#
# ['family', 'family', 'simple house', 'It was here where I learned the definition of ']
#
# ['Narciso Rodriguez from Home: the blueprints of Our Lives,']
#
# ['our neighborhood was made up of mostly Spanish, Cuba, and Italian immigrants at a time when overt racism was the norm and segregation prevail in the United States.']
#
# ['Narciso Rodriguez', 'The faith that this struggle would lead them and their children to better times drove them to endure these hard times', 'My parents always kept there door open for the people we considered family', 'My mother and Father came to this country with such courage, with out knowlage of the language and culture. That quote showed that the family was hopeful enough that even without knowing about the country they still believed it would bring a better life. In the story ']
#
# ['Often someone staying with us temporarily until they were able to got back on their Feet.', 'my parents always kept their arms and their door open to many people we considered family']
#
# ['... formed the backdrop to life in our warm home.']
#
# ['house that his parents turned into a home.']
#
# ['Narciso Rodriguez', 'My parents always kept their arms and their door open to the many people we considered family.', 'I will never forget how my parents turned this simple house in to a home']
#
# ['eternal @CAPS1', 'a dore']
#
# ['Family']
#
# ['Growing up in this enviroment instilled in him a great sense that ', ' nothing to do with being a Blood relative.', 'even though it meant leaving behind their families.', 'home']
#
# ['In our neighborhood, despite customs elsewhere, all of these cultures came together in great solodalriy and friendship.']
#
# ['I will always be grateful to my parents for their love and sacrifice.', 'It was here I learned the real definition of family.']
#
# ['Here, the innocence of childhood, and the congregation of family and friends, and endless celebrations that encompassed both, formed the backdrop to life in our warm home.', 'My parents always kept their arms and their door open to the many people we considered family, knowing that they would do the same for us.', "traditional Cuban home, the very heart of which was the kitchen.... Unwittingly passed on to me they're rich culinary skills and a love of cooking that is still with me today (and for which I am eternally grateful). Passionate Cuban music (which I adored to this day) filled the air, mixing with the aromas of the kitchen.", 'But, in reality, there is no way to express my gratitude for the spirit of generosity impressed upon me... and the demonstration of how important family and friends are.... and these teachings have been the basis of my life.']
#
# ['after living for a year in a furnished one-room apartment, @NUM2-year-old Rawedia and twenty-sevem-year-old Narciso Rodriguez, Sr., could afford to move into a modest, three-room apartment I would soon call home.', 'I will always be grateful to my parents for their love and sacrifice.']
#
# ['they came selflessly as many immigrants do, to give their children a better life even though it meant leaving behind their families, friends, and carrears in the country they loved', 'I will never forget how my parents turned the simple house into a home.', 'But, in reality there is no way to express my gratitude for the spirit of generosity impressed upon me at such an early age and a demonstration of how important family and friends are.', 'the endless celebrations', 'a love of cooking that is still with me today... ']
#
# ['Home: The Blueprints Of Our Lives', "Within it's walls, my young parents created our traditional Cuban home, the very heart of which was my kitchen.", 'My parents both shared cooking duties and un wittingly passed on to me their rich culinory skills and a love for cooking that is still with me today.', 'I will always be grateful to my parents for their love and sacrifice.', 'My parents always kept their arms and their door open to the many people we consider family, knowing that they would do the same for us.']
#
# ['a love of cooking that is still with me today', 'formed a backdrop to life in our warm home', 'kept their arms and their doors open to the many people we considered family.', "I've often told them of my admiration for their strength and perseverance."]
#
# ['Warm homes']
#
# ['I will never forget how my parents turned this simple house into a home.']
#
# ['Narciso Rodriguez', 'Quite the contrary, our neighborhood was made up of mostly Spanish, Cuban, and Italian immigrants at a time when overt racism was the norm and racism prevailed in the United States.', 'My parents always kept their arms and their door opened to the many people we considered family, knowing that they would do the same for us.']
#
# ['could afford to into a modest three room apartment...', 'passionate Cuban music filled the air...']
#
# ['In our neighborhood, despite customs elsewhere, all of these cultures came together in great solidarity and friendship. It was a close-knit community of honest, hard working immagrants who extended a hand to people who, while not necessarily their own kind, were clearly in need.', 'family', 'There is no way to express my gratitude for the spirit of generosity and impressed upon me and the demonstration of how important family and friends are.']
#
# ['They came selflessly, as many immigrants do, to give thier children a better life, even thought it meant leaving behind their families, friends, and careers in the country they loved.']
#
# ['I learned the definition of ']
#
# ['In Cuba, Narciso, Sr., had worked in a laboratory and Rawedia Maria had studied chemical engineering. In the United States they had to start their lives over entirely, taking whatever work they could find.', ' Our neighborhood was made up of mostly Spanish, Cuban, and italian immigrants', 'It was a close \x96 knit community of honest hard working immigrants who extended a hand to people who while not necessary their own kind, were clearly in need.']
#
# ['Within its walls, my young parents created our traditional Cuban home, the very heart of which was the kitchen', 'eternally grateful', 'unwittingly passed on to meet their rich culinary skills and a love of cooking that is still with me today', 'Mixing with kitchen aromas.', 'Here, the innocence of childhood, congregation of family + friends, and endless celebrations form the backdrop to life in our warm home. I will never forget how my parents turned this house into a home.']
#
# ['I will always be grateful to my parents for their love and sacrifice.', "I've often told them that what they did was a much more courageous thing than I could have ever done. I've often told them of my admiration for their strength and perseverance, and I've thanked them repeatedly."]
#
# ['family.', '... this simple house into a home.', 'extended family', 'In our neighborhood..., all these cultures came together in great solidarity and friendship.', 'family', "' family' had nothing to do with being a blood relative."]
#
# ['Narciso Rodriguez', "I've often told them of my admiration for their strength and perseverance.", 'They came selflessly, as many immigrants do, to give their children a better life...']
#
# ['Here the innocence of childhood, the congregation of a family and friends, and endless celebrations that encompassed both, formed the backdrop to life in our warm home.', 'in our neighborhood, despite customs elsewhere, all of these cultures came together in great solidarity and friendship.', 'They come selflessly, as many immagrants do, to give their children a better life.']
#
# ['Narciso Rodriguez', 'Growing up in this enviroment instilled in me a great sense that ', ' had nothing to do with being a blood relative.', 'I will always be grateful to my parents for their love and sacrifice.']
#
# ['... still with me today (and for which I am eternally grateful.) It also shows that Narciso Rodriguez is proud to be Cuban.In paragraph @NUM2, it says ']
#
# ['family']
#
# ['Narciso Rodriguez', '...To give their children a better life', 'family has nothing to do with love relatives.', "I've often told them that what they did was a much more courageous thing that I could have ever done."]
#
# ['Narciso Rodriguez']
#
# ['passed on to me their rich culinary skills, and a love of cookig that is still with me today.', 'rich', 'all of these culture came together in great solidarity and friendship.', 'always filled the air with not just scent and music, but life and love.']
#
# ['Here, the innocence of childhood, the congregation of family and friends, and endless celebrations that encompassed both, formed the back drop to life in our warm home.', 'My parents both had to accept that they might not be able to find the knd of jobs they desurved... The faith that this struggle would lead them and their children to better times drove them to endure these hard times.', 'My parents always kept their arms and their door open to the many people we considered family, knowing that they would do the same for us.']
#
# ["Growing upin this environment instilled in me a great sense that 'family' had nothing to do with being a blood relative.", 'My parents always kept their arms and their door opentothe many people we considered family. Knowing that theywould do the same for us.']
#
# ['My parents always kept their arms and their door open to the many people we considered family, knowing that they would do the same for us. ']
#
# ['Growing up in this environment instilled in me a great sense that ', ' had nothing to do with being a blood relative.', 'They came selflessly, as many immigrants do, to give their children a better life, even though it meant leaving behind their families, friends, and careers in the country they loved.', 'I will always be grateful to my parents for their love and sacrifice.']
#
# ['melting pot']
#
# ['In 1961, I was born into this simple house, situated in a two-family... my young parents created our traditional cuban home.', 'They Struggled both personally and financially, braving the harsh northern winters while yearning for their native tropics and facing cultural hardships.', 'I will always be grateful to my parents for their love and sacrifice.']
#
# ['I was born into this simple house...my young parents created our traditional Cuban home...the innocence of childhood, congregation of family and friends and endless celebrations that encompassed both, formed the backdrop to life in our warm home.', 'My parents always kept their arms open and their door open to the many people we considered family, knowing that they would do the same for us.', 'The barriers to work were strong and high, and my parents both had to accept that they might not be able to find the kind of jobs they deserved.']
#
# ['Passionate Cuban music, filled the air, mixing with the aromas of the kitchen.', 'I will always be grateful to my parents for their love and sacrafice', 'warmth of the kitchen in this humble house where a cuban feast alway filled the air, with not just the sent but life and love.']
#
# ['countless extended family members came and went-and there was often someone Staying with us temporarily until they were able to get back on their feet']
#
# ['In our neighborhood, dispite customs elsewhere, all of these cultures came together in great solidarity and friendship. Narciso was proud and grateful to his parents because they gave up everything to come to the United States to give their family a better life. Without knowing alot about this new country, they struggled to overcome problems. Narciso is grateful to his parents for living their life to start over. ']
#
# ['Home: the blue prints of our lives', 'they-came selflessly, as many immigrants do, to give their children a better life, even though it meant leaving behind their families, friends, and careers in the country they loved.']
#
# ["within it's walls, my young parents created our traditional cuban home, the very heart of which was the kitchen,", 'Passionate Cuban music...filled the air, mixing with the aromas of the kitchen.', 'Here, the innocence of childhood, the congregation of family, and friends, and endless celebrations that encommpassed, both, formed a backdrop, to life in our warm home.']
#
# ['I will never forget how my parents turn to the simple house into a home']
#
# ['Narciso Rodriguez', 'my parents, originally from Cuba, arrived in the United States in 1956.', 'in 1961, I was born into the simple house, situated in a two-family, blonde-brick building in the @CAPS1 bound section of Newark, New Jersey.']
#
# ['a rough life,']
#
# ['my parents always kept their arms and their door open to the many people we considered family, knowing that they would do the same for us.', 'I will never forget how my parents turned this simple house into a home.']
#
# ['... all of these cultures came together in great solidarity and friendship.']
#
# ['Home: The blueprints of our lives, is very thankFul. ', ' ', ' @CAPS1 like these that are scattered thro-ugh out the excerpt show greatfulness, and love for his parents. Some other @CAPS1 like ', ' and ', '. Throughout the excerpt he tries to express how greatful he is to his parents, and community. One quote that can to mind when reading paragraphs @NUM1 & @NUM2 is ']
#
# ['cuban music (which I adore to this day) filled the air, mixing with the aromas of the kitchen.', "I've often told them of my admiration for their strength and perseverance,...", 'I will always be grateful to my parents for their love and sacrifice.']
#
# ['I will never forget how my parents turned this simple house into a home.']
#
# ["often told them of my admiration for their strength and perseverance, and I've thanked them repeatedly.", 'I will always be grateful to my parents for their love and sacrifice.']
#
# ['Narciso Rodriguez']
#
# ['I will always be grateful to my parents for their love and sacrifice.', 'to give their children a better life.', 'their strength and perseverance.']
#
# ['I Learned there about how to love. I will never forget how my parents turned this simple house into a home.', 'Countless extended family members came and whent-and there was often someone staying with us temperally until they were able to get back on there feet.', 'Could not afford to move into a moddest three room appartment', 'They struggled both personally and financially. This is a sad @CAPS1 because they are haveing trouble getting by. There is more then @NUM1 @CAPS1 in this story, but the most import @CAPS1 I think is loving. A example of loving is when it states ']
#
# ['My parents both shared cooking duties and unwittingly passed on to me their... love of cooking that is still with me today (and for which I am eternally grateful).', 'I will always be grateful to my parents for their love and sacrifice.']
#
# ['Narciso Rodriguez', '@CAPS1 also states ', '. Ive often told them that what they did was a much more courageous thing I could ever have done']
#
# ["'family' had nothing to do with being a blood relative. This meant that all the people around you that care about you are your ", ". Another reason why the mood of the memoir is happy is because I think if my parents were in the same situation that Narciso's parents were in, my parents would have done the same thing. My parents would have also wanted, "]
#
# ['@PERSON1', 'my parents created our traditional Cuban home', 'My parents welcomed other refugees to celebrate thier arrival to this country', '@PERSON2']
#
# ['Narciso Rodriguez', 'I will never forget how my parents turned this simple house into a home']
#
# ['Narciso Rodriguez', 'all of these cultures came together in great solidarity and friendship.', 'honest, hardworking immigrants who extended a hand to people who, while not necessarily of their own kind, were clearly in need.']
#
# ['traditional Cuban home, the very heart of which was the kitchen.', 'My parents always kept their arms and their doors open to the many people we considered family, knowing they would do the same for us.']
#
# ['In our neighborhood, despite customs elsewhere, all of these cultures came together in great solidarity and friendship.']
#
# ['family, friends, and careers in the country they loved.', 'there was often someone staying with us temporarely until they were able to get ba- ck on their feet.']
#
# ['Within its walls, my young parents created our traditional Cuban home... Both shared cooking duties and unwittingly passed on to me their rich culinary skills and a love of cooking that is still with me today... Here the innocence of childhood, the congregation of family and friends, the endless celebrations that encompassed both, formed the backdrop to life in our warm house.']
#
# ['I will always be greatful to my parents for the love and sacrifice. When he is saying this he is showing he is happy w/ his parents. I the memoir he talks about how he loves his house and why he loves his house and all the great memories in that house and that shows that this memoir mood is a more happy mood instead of sad for example paragraph @NUM2 when he says ', ' Also when he said in paragraph @NUM2 that']
#
# ['In our neighborhood, despite the customs elsewhere, all of these culture came together in a great solidarity and friendship.']
#
# ['originally from cuba but arrived in the united states in 1956. After living for a year in a furnished one room apartment, twenty one years old Rawedia Maria and twenty seven year old @ORGANIZATION1 could afford to move into a modest three room apartment I would soon call home. ']
#
# ['family', 'family']
#
# ['Here the innocence of childhood, the congregation of family and friends, and  endless celebrations that encomposed both, formed the backdrop to life in our warm home']
#
# ["growing up in this environment istilled in me a great sense that 'family' had nothing to do with being a blood relative.", 'my mother and father had came to this country with such courage, without any knowledge of the language or the coltur.']
#
# ['growing up in this environment instilled in me a great sense that family had nothing to do with being a blood relative']
#
# ['family', 'family']
#
# ['Narciso Rodriguez,', 'Narciso Rodriguez,']
#
# ['Within its walls, my young parents created our traditional Cuban home, the very heart of which was the kitchen.', 'My parents both shared cooking duties and unwittingly passed on to me their rich culinary skills and a love of cooking that is still with me today.']
#
# ['I will never forget how my parents turned the simple house into a home.']
#
# ['@PERSON1', 'aromas,', 'endless,', 'encompassed,', 'instilled,', '(and for which I am eternaly grateful)', '(which I adore to this day)', 'I will always be grateful to my parents for thir love and sacrifice.', '@PERSON1', '@PERSON1']
#
# ["I've thanked them repeatedly,", 'Narciso Rodriguez']
#
# ['I will always be grateful to my parents for their Love and sacrifice.', 'family']
#
# ['@PERSON1', 'growing up in this envionment instilled in me a great sense that ', ' had nothing to do with being a blood relative. Over here, he is saying that your friends can be your family or the people that you love. Secondly he says ', 'I will never forget how my parents turned this simple house into a home. Here he is saying that ']
#
# ['Narciso Rodriguez', 'I will allways be grateful to my parents for their love and sacrifice.', 'Growing up in this enviorment instilled in me a great sense that ', ' had nothing to do with a blood relative.']
#
# ['Growing up in this environment instilled in me a great sense that ', ' had nothing to a blood relative.']
#
# ['Growing up in this environment instilled in me a great sense that family had nothing to do with being a blood relative', 'It was a close nit community of honest hardworking immigrants who extend a hand to people who, while not necessarily their own kind, were Clearly in need']
#
# ['Narciso Rodriguez']
#
# ['My mother and father had come to this country with such courage, without any knowledge of the language or the culture. They came selflessly, as many immigrants do, to give their children a better life, even though it meant leaving behind their families friends, and careers in the country they loved .', "I will always be grateful to my parents for their love and sacrifice. I've often told them that what they did was a much more courageous thing than I could have ever done. I've often told them my admiration for the strength and perseverance, and I've thanked them repeatedly. But, in reality, there is no way to express my gratitude for the spirit of generosity impressed upon me at such an early age and the demonstration of how important family and friends are."]
#
# ['And for which I am eternally grateful', 'They Came selflessly, as many immigrants do, to give their Children a better life']
#
# ['here, the innocence of childhood, the congregation of family and friends, and endless celebrations that encompassed both, formed the backdrop to life in our warm house.', 'I will never forget how my parents turned this simple house into a home.']
#
# ['simple house', 'traditional Cuban home', 'Passionate Cuban music.', 'a love of cooking']
#
# ['Turned their simple house into a home']
#
# ['always kept their arms and their door open to the many people we consider family.', 'will always be grateful for their love and sacrifice.', 'will never forget how my parents turned this simple house into a home.']
#
# ['Passionate Cuban music (which I dore to this day)', 'Growing up in this enviroment instilled in me a great sense that ', ' had nothing to do with being a blood relative, And for that true you dont have to be related to someone who really love to say that he/@CAPS3 is @CAPS5 of your family is Just enoght that he/@CAPS3 love and care about you like you for he/@CAPS3. Last thing is when the @CAPS2 said ']
#
# ['Narciso Rodriguez', 'I will always be greatful to my parents for their love and sacrifice,', 'Narciso Rodriguez,']
#
# ['twenty-one-year-old @PERSON2 and twenty-seven-year-old Narciso Rodriguez, Sr., could afford to move into a modest, @NUM2-room apartment.', "Within it's walls, my young parents created our traditional cuban home.", 'In our neighborhood all of those cultures came together in great solidarity and friendship.', 'Even though it meant leaving behind their families, friends and carrers in the country they loved.', 'The barriers to work were strong and high, and my parents both had to accept that they might not be able to find the kind of jobs they deserved.']
#
# ['I will always be greatful to my parents for their love and sacrifice.', 'At tine when overt racism was the norm... All of the cultures came together in great soidarity and friendship.']
#
# ['My mother and father had come to this country with such courage, without any knowledge of the language or the culture. They came selflessly, as many immigrants do to give their children a better life, even though it meant leaving behind their families, friends, and careers in the country they love.', "I will always be grateful to my parents for their love and sacrifice. I've often told them that what they did was a much more courageous thing then I could have ever done"]
#
# ['Home: The Blueprints of Our Lives', "Growing up in this environment instilled in me a great sense that 'family' had nothing to do with being a blood relative... a close knit community.", 'Our landlord and his daughter, Alegria... lived above us, and Alegria graced our kitchen table... more often than not. Also at the table... my surrogate grandparents.', 'I will always be grateful to my parents for their love and sacrifice.']
#
# ['Passionate Cuban music (which I adore to this day) filled the air, mixing with aromas of the kitchen.', 'I will always be grateful to my parents for their love and sacrifice.']
#
# ['I will never forget how my parents turned this simple house to a home']
#
# ["I will always be grateful for their love and sacrifice. I've often told them that what they did was a much more courageous thing and I could have ever done.", 'they came, as many immigrants do, to give their children a better life, even though it meant leaving behind their families, friends, and careers in the country they love.']
#
# ['Growing up in the enviorment instilled in me a great sense that family had nothing to do with being a blood relative.', 'It was in this simple house that my parents welcome other refugees to celebrate their arival to this country and where I celebrated my first birthdays.', 'It was in the warmth of the kitchen in this humble house where a Cuban feast always filled the air with not just scent and music but life and love. It was here where I learned the real definition of family.']
#
# ['my young parents created our traditional cuban home.', 'Growing up in this enviroment instilled in me a great sense that ', ' had nothing to do with being a blood relative.', 'I will always be greatful to my parents for their love and sacrifice.', 'cultures came together a great solidarity and friendship.', 'My parents always kept their arms and door open to many people we considered family...']
#
# ["learned the definition of 'family' ", 'I often tell them that what they did was a much more courageous thing than I could have ever done.']
#
# ['Narciso Rodriguez', 'passionate Cuban music filled the air, mixing with the aromas of the kitchen', 'within its walls, my young parents created our traditional Cuban home the very heart of our kitchen', 'it was in this simple house that my parents welcomed other refugees to celebrate their arrival to this country and @CAPS1 celebrated my first birthdays', 'Narciso Rodriguez']
#
# ['family']
#
# ['It was a close-knit community of honest, hardworking immigrants who extended a hand to people,', 'extended a hand,', '(and for which I am eternally thankful)', 'within its walls, my young parents created our traditional Cuban home, the very heart of which was the kitchen.']
#
# ['Narciso Rodriguez', 'family', 'family', 'family', 'family']
#
# ['family', 'countloss extended family members cane and went.', 'to give their children a better life', 'I will always be grateful to my parents for their love and sacrife.']
#
# ['They came selflessly, as many immigrants do, to give their children a better life, even though it meant leaving behind their families, friends, and careers in the country they loved.']
#
# ['My parents created our traditional Cuban home, the very heart of which was the kitchen.']
#
# ['I will never forget how my parents turned this simple house into a home']
#
# ['The passionate cuban music filled the air, mixing with The aromas of the kitchen.']
#
# ['Growing up in this environment instilled in me a great sense that ', " had nothing to do with being a blood relative. This shows that just because your  not related by blood does'nt mean your not family. Another reason why I would describe the mood of the authour as soft in compassionate is at the end of the memoir Narciso Rodriguez says "]
#
# [' family', 'Growing up in this environment instilled in me a great sense that ', ' had nothing to do with being a blood relative. Quite the contrary, our neighborhood was made up of mostly spanish, cuban, and Italian immigrants at a time when overt racism was the norm and segregation prevailed in the @LOCATION1', 'family']
#
# ['definition of family', 'Spanish, Cuban, and Italian immigrants', 'blood relatives']
#
# ['Narciso Rodriguez,', 'My parents both shared cooking duties and un wittingly passed on to me their rich culinary skills and a love of cooking that is still with me today. Passionate Cuban music filled the air, mixing with the aromas of the kitchen. The author shows a feeling of a warm, wonderful household with music and cooking. Next, the author shows a feeling of a nice warm child hood here: ']
#
# ["Growing up in this enviornment instilled in me a great sense that 'family' had nothing to do with being a blood realitive.", 'They came selflessly, as immigrants do, to give their children a better life, even though it meant leaving behind their families, friends, and careers in the country they loved.']
#
# ['(and for which I am each currently grateful). ... (Which I adore to this day). second of all the mood of the author is appreciation. For example ', ' @CAPS1 I think another mood of the author is definitely love. I kno this because he talks about love and his family and friends alot. For example ']
#
# ['which I [Narciso] a door to this day.', 'I am eternally grateful.', 'It was a close -knit community of honest, hardworking immigrants who extended a hand...', 'They came selflessly... to give thir children a better life.']
#
# ['Narciso Rodriguez', 'My parents both shared cooking duties and unwittingly passed on to me their rich culinary skills and a love for cooking that is still with me today. Narciso was very grateful that his parents came to @LOCATION1 to help him make his home seem more like a traditional Cuban home. ', 'family']
#
# ["I will always be grateful to my parents for their love and sacrifice; I've often told them that what they did was a much more courageous thing then I could of ever done.", 'They showned me with their lives, and these teachings have been the basis of my life.', 'family']
#
# ['Narciso Rodriguez', 'It was here I learned the real meaning of family, and that you can turn a simple house into a home.']
#
# ['Narciso Rodriguez', 'In Cuba @PERSON2,had worked in a laboratory and @LOCATION1 had studied chemical engineering.']
#
# ['Narciso Rodriguez', 'that all cultures came together in solidarity and friendship', 'In @ORGANIZATION1 and Maria worked first class careers, but it was the exact opposite in @LOCATION1.']
#
# ['I will always be greatful to my parents for their love and sacrifice.', 'But in reality there is no way to express my gratitude.']
#
# ['@PERSON1', 'family.']
#
# ['Narciso Rodriguez', 'Growing up in this environment instilled in me a great sense that ', ' had nothing to do with being a blood relative.']
#
# ['Narciso Rodriguez', 'My parents originally came from Cuba...', 'Our neighborhood was made up of mostly Spanish, Cuban, and Italian immigrants...', 'Narciso Rodriguez,']
#
# ['I will always be greatful for their love and sacrifice', "I've often told them of my admiration for their strength and perseference... but, in reality, there is no way to express my gratitude for their spirit and generosity...", 'I will never forget how my parents turned this simple house into a home.']
#
# ['and for which I am eternally grateful', 'all of these cultures came together showing great solidarity and friendship.', 'I will always be grateful to my parents for their love and sacrifice,', 'these teachings have been the basis of my life']
#
# ['Rich culinary skills....a love of cooking....passionate cuban musci (which I adore to this day)', 'had nothing to do with being a blood relative,', 'came together in great solidarily and friendship.  ', 'i will never forget how my parents turn this simple house into a home.']
#
# ['I will never forget how my parents turned this simple house into a home.']
#
# ['Here, the innocence of childhood, the congregation of family and friends, and endless celebrations that encompassed both, formed the backdrop to life in our warm house.']
#
# ['I will always be grateful to my parents for their love and sacrifice @CAPS1 is so thankful that her parents brought her to @LOCATION1 so @CAPS1 could live a wonderful life.Another way @CAPS1 shows @CAPS1 is grateful is @CAPS1 says ', ' @CAPS1 respects what her gone through to make her life enjoyable and not like what her parents lives were.The last way @CAPS1 shows gratefulness is @CAPS1 thanks her parents every day for what they have done. ']
#
# ['I will always be grateful to my parents for their love and sacrifice.', 'But, in reality, there is no way to express my graditude for the spirit of generosity impressed upon me at such an early age and the demonstration of how important family and friends are.']
#
# ['... always kept their arms and their door open to the many people (they) consider family, knowing that they would do the ', ' (@NUM1). Even though', ' (@NUM2) they all cared for each other as if they were one family. Prior to moving to the United States, ']
#
# ['Narciso Rodriguez', 'Home: The Blueprints of our Lives', 'growing up in this environment instilled in me a great sense that ', ' had nothing to do with being a blood relative', 'I will never forget how my parents turned the simple house into a home.']
#
# ['vibe']
#
# ['family']
#
# ['I will always be grateful to my parents for their love and sacrifice']
#
# ['family', 'great solidarity and friendship.', 'family']
#
# ['parents not able to get the right jobs', 'facing cultural hardships.']
#
# ['In our neighborhood, despite customs elsewhere, all of these cultures came together in great solidarity and friendship.']
#
# ['I will always be grateful to my parents for their love and sacrafice.', 'A Cuban feast always filled the air with not just scent and music but life and love.', 'I will never forget that house or its gracious neighborhood or the many things I learned there about how to love.']
#
# ['My parents both shared cooking duties and unwittingly passed on to me their rich culinary skills and a love of cooking that is still with me today (and for which I am eternally grateful).', 'I will always be grateful to my parents for their love and sacrifice.', "I've often told them of my admiration for their strength and perseverance, and I thanked them repeatedly.", 'And for this, I will never forget that house or its gracious neighborhood or the many things I learned there about how to love.']
#
# ['family']
#
# ['family']
#
# ['rich culinary skills and love of cooking,', 'passionate Cuban music...mixing with the aromas of the kitchen.', 'family members']
#
# ['love and sacrifice.', 'My parents always kept their arms and their door open to the many people we considered family, knowing that they would do the same for us.', '...my parents welcomed other refugees to celebrate their arrival to this country...']
#
# ['(and for wich I am eternally greatful).', 'I will allways be greatful to my parents for their love and sacrifice.', "I've often told them of my admiration for their strength and perseverance and I've thanked them repetedly."]
#
# ['even though it meant leaving behind their families, friends, and careers in the country they loved.']
#
# ['Cooking duties and the work around the house.']
#
# ['passionate', 'rich', 'thanked', 'Had come to this country with such courage, without any knowledge of the language or the culture.']
#
# ['I will always be grateful to my parents for their love and sacrafice.', 'family.', 'I will never forget how my parents turned this simple house into a home.']
#
# ['Narciso Rodriguez', 'Growing up in this environment instilled in me a great sense that ', ' had nothing to do with being a blood relative.']
#
# ['Passionate Cuban music filled the air, mixing with the aromas of the kitchen.', 'Countless extended family members came and went-and there was often someone staying with us temporarily until they were able to get back on their feet.']
#
# ['home', 'home']
#
# ['immigrants who extended a hand to people who, while not necessarily their own kind, were clearly in need.']
#
# ['Narciso Rodriguez', 'My young parents created our traditional cuban home.']
#
# ["I've often told them what they did was a much more courageous thing than I could have ever done. I've often told them of my admiration for their strength and perseverance."]
#
# ["The innocence of childhood, the congregation of the family and friends, and endless celebrations that encompassed both, forms the backdrop to life in our warm home. Also when the author says this it creats a happy @CAPS1 and shows how greatful he is to his parent's, ", 'It was in the warmth of the kitchen in this humble house where a cuban feast always filled the air with not just scent and music but life and love./I will never forget how my parents turned this simple house into a home.']
#
# ['A love of cooking that is still with me today.', 'I will always be grateful to my parents For their love and sacrifice.', 'It was in this simple house that my parents welcomed other refugees to celebrate their arrival to this country']
#
# ['alegrai graced our kitchen table more often Than noT.']
#
# ['a time when overt racism was the norm and segregation prevailed in the United States. In our neighborhood, despite customs elsewhere, all of these cultures came together in great solidarity and friendship. It was a close \x96 knit community of honest, hardworking immigrants who extended a hand to people who, while not necessarily their own kind, were clearly in need']
#
# ['Family']
#
# ...
#  'Here, in innocence of childhood, the congregation the family and friends, and endless celebrations that encompassed both, formed the backdrop to life in our warm home.',
#  'kept their arms and their doors open to the many people we considered family.',
#  ' The first quote shows he was very free with feeling and the second quote shows that he was ',
#  ' inside.This quote shows that the mood the author changed to be very loving. ',
#  'It was in the warmth of the kitchen in this humble house where a Cuban feast always filled the air with not just scent and music but life and love',
#  'And for what I am eternally grateful,',
#  'My parents both shared cooking duties and unwittingly passed on to me their rich culinary skills and a love of cooking is still with me today (and for which I am eternally grateful). Passionate Cuban music (which I adore to this day) filled the air,',
#  "I've often told them of my admiration for their strength and perseference... but, in reality, there is no way to express my gratitude for their spirit and generosity...",
#  'a love of (cuban) cooking which is still with me (the author) today',
#  'there was often someone staying with us temporarely until they were able to get ba- ck on their feet.',
#  "@CAPS1 often told them of my admiration for their strength and perseverance, and I've thanked them repeatedly. But, in reality, there is no way to express my gratitude for the Spirit of generosity impressed upon me at such an early age and the demonstration of how important family and friends are.",
#  'for their love and sacrifice',
#  ' had nothing to do with being blood relative',
#  'struggle',
#  'Home: The @CAPS1 of our Lives',
#  'In our neighborhood despite customs elsewhere, all of these cultures came together in great solidarity and friendship.',
#  'until they got back on their feet.',
#  'It was in this simple house that my parents welcomed other refuges to celebrate their arrival to this country, and where I celebrated my first birthdays.',
#  'came selflessly,',
#  'close-knit community',
#  'family has nothing to do with love relatives.',
#  'It was a close-knit community of honest, hardworking immigrants who extended a hand to people who, while not necessarily their own kind, were clearly in need.',
#  'joyful',
#  ' A love of cooking that is still with me today (and for which I am eternally grateful).',
#  ' I will always be grateful to my parents for their love and scrifice',
#  '... a love of cooking that is still with me today (and for which I am eternally grateful). Passionate Cuban music (which I adore to this day) filled the air, mixing with the aromas of the kitchen.',
#  'Here, the innocence of childhood, the congregation of family and friends, and endless celebrations that encompassed both, formed the backdrop to life in our new home',
#  'they came selflessly as many immigrants do, to give their children a better life even though it meant leaving behind their families, friends, and carrears in the country they loved',
#  'Passionate Cuban music (which I adored to this day) filled the air, mixing with the aromas of the kitchen.',
#  'Growing up in this envirement instilled me a great sense that ',
#  'filled the air with not just scent and music but life and love.',
#  'My parents always kept their arms and their door open to the many people we consider family',
#  'My parents always kept their arms open and their door open to the many people we considered family, knowing that they would do the same for us.',
#  ' countless extended family members came and went... my parents always kept their arms and their doors open to the many people we considered family...',
#  'A close-knit community of honest, hardworking immigrants',
#  'They came selflessly, as many immigrants do, to give their children a better life, even though it ment leaving behind their families, freinds, and careers in the country they love.',
#  'growing up in this environment instilled in me a great sense that ',
#  ' had nothing to do with being blood relative.',
#  'My mother and father had come to this country with such courage, without any knowledge of the language or culture. They came selflessly, as many immigrants do, to give their children a better life.',
#  'Innocence of childhood... endless celebrations.',
#  ' in paragraph @NUM2, or ',
#  'Here, the innocence of childhood, and the congregation of family and friends, and endless celebrations that encompassed both, formed the backdrop to life in our warm home.',
#  "I will always be greatful to my parents for their love and sacrifice. I've often told them what they did was a much more courageous thing that I could have ever done. I've often told them of my admiration for their Strength and perseverance and I've thanked them repeatedly. But, in reality, there is no way to express my gratitude for the spirit of generosity impressed upon me at such an early age and the demonstration of how important family and friends are. These are two lessons that my parents did not just tell me. They showed me With their lives, and those teachings have been the base of my life.",
#  'made a house a home',
#  "I will always be grateful to my parents for their love and sacrifice. I've often told them that what they did was much more courageous thing than I could have ever done",
#  'My Parents both shared cooking duties and unwrittingly Passed on to me their rich culinary skills and a love of cooking that is still with me today',
#  'My parents always kept their arm and their doors open to the many people we considered family.',
#  ' ',
#  'came selflessly, as many immigrants do, to give their children a better life',
#  'The passionate Cuban music (which I adore to this day) filled the air, mixing with the aromas of the kitchen.',
#  'happiness is nothing without appreciating it',
#  '.. the congregation of family and friends...',
#  '...culinary skills and a love of cooking that is still with me today (and for which I am eternally grateful).',
#  'I learned the real defenition of family And for this I will never forget that house or its gracious neighborhood. @CAPS1 cares about his familey @CAPS1 now feel what his parents showed him thats why the overall mood is happy.In the memoir ',
#  'there is no way to express my gratitude for the spirit of generosity impressed upon me at such an early age',
#  'my admiration',
#  'I will always be thankful to my parents for their love and sacrifice.',
#  "I will always be grataful to my parents for their love and sacrifice. I've often told them What they did was a much more courageous thing than I could have ever done...",
#  'and unwittingly passed on to me their rich culinary skills and a love of cooking that is still with me today (and for which I am eternally grateful).',
#  'They came...to give their children a better life',
#  'families, friends, and careers in the country they loved.',
#  'parents created their traditional Cuban home',
#  '. The last thing That discribes The @CAPS1 is The love and sacrifice That They gave there son. ',
#  'my parents always kept their arms and their door open to the many people we considered family, knowing that they would do the same for us.',
#  '... endless celebrations that encompassed both, formed the backdrop to life in our warm home',
#  'I will never forget that house or its gracious neighborhood or the many thing I learned there about how to love.',
#  'My parents always kept their arms and their doors open to the many people we considered family, knowing they would do the same for us.',
#  "I will always be grateful to my parents for their love and sacrifice. I've often told them what they did was a much more courageous thing than I could have ever done.",
#  'extended a hand to people who were clearly in need.',
#  'the innocence of childhood, the congregation of family and friends and endless celebrations that encompassed both, forms the backdrop to life in our warm house.',
#  ' could have ever done',
#  'Within its walls, my young parents created our traditional Cuban home, the very heart of which was the kitchen. My parents both shared cooking duties and unwittingly passed on to me their rich culinary skills and a love of cooking that is still with me today (and for which I am eternally grateful).',
#  'selflessly, as many immigrants do, to give their children a better life, even though it meant leaving behind their families, friends, and careers',
#  'there was often someone staying with us temporarily until they were able to get back on there feet. My parent always kept their arms and their door open to the many people we considered family',
#  ' is showing an @CAPS1 of love. Also, when he says, ',
#  'The congregation of family and friends and end less celebration. The last mood created by the author was appreciative. ',
#  '... endless celebrations...',
#  'courageous',
#  'But, in reality, theres is no way to express my gratitude for the spirit of generosity impressed upon me at such an early age and the demonstration of how important family and friends are.',
#  'I will never forget that house or its gracious neighborhood...',
#  'Here in the innocence of childhood, the congregation of family and friends, and endless celebrations....',
#  'They came selflessly as many immigrants do, to give their children a better life, even though it meant leaving behind their families friends, and careers,',
#  'it was in this simple house that my parents welcomed other refugees to celebrate their arrival to this country and @CAPS1 celebrated my first birthdays',
#  '... There is no way to express my gratitude...',
#  'home',
#  "I've often told them of my admiration for their strength and perseverance, and I've thanked them repeatedly.",
#  '... All of these cultures came together in great solidarity and friendship.',
#  'the congregation of family and friends, and endless celebrations that encompassed both, formed the backdrop to life in a warm home.',
#  'They came selflessly to give their children a better life I will always be grateful to my parents for their love and sacrafice',
#  'what they [her parents] did was a much more courageous thing that I could have ever done.',
#  'they struggled both personally and financially, braving the harsh northern winters while yearning for their native tropics and facing cultural hardships.',
#  'Spanish, Cuban and Italian immigrants at a time when overt racism was the norm and there was segregation.',
#  'of honest, hardworking immigrants.',
#  'It was a simple house that my parents opened to other refugees.',
#  'cultures came together in great solidarity and friendship',
#  'house',
#  'Here the innocence of childhood, the congregation of family and friends, and endless celebrations that encompassed both, formed the backdrop to life in our warm home.',
#  '(and for which I am eternally grateful.)',
#  ' had an incredibly happy mood. Next, the memoirs mood shows that Rodriguez is obviously proud of his hardworking parents. ',
#  'They came selflessly as many immigrants do, to give their children a better life, even though it meant leaving behing their families, friends, and careers in the country they loved',
#  'admires the strenght and preseverance and have thanked them repeatedly.',
#  'countless extended family members came and went-and there was often someone staying with us temporaily until they were able to get back on their feet',
#  'started their lives over entirely',
#  'Passionate Cuban music...filled the air, mixing with the aromas of the kitchen.',
#  "...passed on to me they're rich culinary skills and a love of cooking that is still with me today (and for which I am eternally grateful). Passionate Cuban music (which I adore to this day)...",
#  'countless extended family members came and went- and their was often someone staying with us temporarily untill they were able to get back on their feet. My parents always kept their arms and doors open to the many people we considered family, knowing that they would do the same for us.',
#  'My parents always kept their arms and their door open to the many people we considered family, knowing that they would do the same for us. ',
#  "I've often told them that what they did was a much more courageous thing that I could have ever done. Narciso is very thankful and feels very much beloved in his family. In the mood in this memoir is not just thoughtful or kind or caring, it's the feeling loved and loving that feeling. ",
#  "my Mother and father had come to this country with such courage I've often told them that what they did was a much more courageous thing then I could have ever done",
#  'But, in reality, there is no way to express my graditude for the spirit of generosity impressed upon me at such an early age and the demonstration of how important family and friends are.',
#  'But, in reality there is no way to express my gratitude for the spirit of generosity impressed upon me at such an early age and a demonstration of how important family and friends are.',
#  'It was here where I learned the real definition of family... [that it] had nothing to do with being a blood relative.',
#  '. Throughout the excerpt he tries to express how greatful he is to his parents, and community. One quote that can to mind when reading paragraphs @NUM1 & @NUM2 is ',
#  'the innocence of childhood, the congregation of family and friends, and endless celebrations that encompassed both, formed the backdrop of life to our warm home.',
#  'Here, the innocence of childhood, the congregation of family and friends, and the endless celebrations that encompassed both, form the backdrop to life in our warm home',
#  'family had nothing to do with being a blood relative. I mean his house was a peaceful and a safe place. Everyone was always at his house. His parents ',
#  'In Cuba @PERSON2,had worked in a laboratory and @LOCATION1 had studied chemical engineering.',
#  'always be greatful for my parents',
#  'Created our traditional Cuban home, the very heart of which was the kitchen.',
#  'My mother and Father came to this country with such courage, with out knowlage of the language and culture. That quote showed that the family was hopeful enough that even without knowing about the country they still believed it would bring a better life. In the story ',
#  'home is where one lived as a child.',
#  'their love and sacrifice.',
#  'It was in the warmth of the kitchen in this humble house where a Cuban feast always filled the the air with not just scent but life and love',
#  'and for which I am eternally greatful.',
#  'they came, as many immigrants do, to give their children a better life, even though it meant leaving behind their families, friends, and careers in the country they love.',
#  'Home: The Blueprints of our Lives,',
#  'community of honest, hardworking immigrants.',
#  '... instilled in me a great sense that ',
#  'no way to express my gratitude',
#  'My young parents created our traditional cuban home',
#  'got back on their feet.',
#  ". Another reason why the mood of the memoir is happy is because I think if my parents were in the same situation that Narciso's parents were in, my parents would have done the same thing. My parents would have also wanted, ",
#  'passionte Cuban-music, and ',
#  "I learned the real definition of 'family'. And for this, I will never forget that house or its gracious neighbor hood or the many things I learned there about how to love. I will never forget how my parents turned this simple house into a home.",
#  'close-knit community of honest, hard-working immigrants.',
#  'I was born into a simple house situated in a two-family, blonde brinck building in the *** section of Newark, New jersy. My young parents created our traditional Cuban home.',
#  'But, in reality, there is no way to express my gratitude for the spirit of generosity impressed upon me at such an early age and the demonstration of how important family and friends are.',
#  'I will never Forget how my parents turned this simple house into a home.',
#  'was born into a two-family blond-brick building in the Ironbound section of Newark, New jersey',
#  ' This quote shows that the author is very loving because he says, ',
#  ...}

# %%
set5essay_quotes = ['always be grateful to my parents for their love and sacrifice', 'rich culinary skills', 'love of cooking', 'passionate Cuban music', 'aromas of the kitchen', 'innocence of childhood', 'congregation of family and friends', 'endless celebrations', 'our warm home', 'came together in great solidarity and friendship', 'close-knit community of honest, hardworking immigrants', 'kept their arms and door open to the many people we considered family', 'came selflessly', 'struggled both personally and financially', 'facing cultural hardships', 'overt racism was the norm', 'drove them to endure these hard times', 'their strength and perseverance', 'love and sacrifice', 'spirit of generosity impressed upon me at such an early age', 'demonstration of how important family and friends are', 'teachings have been basis of my life', 'warmth of the kitchen', 'humble house', 'not just scent and music but life and love', 'definition of family', 'never forget how my parents turned this simple house into a home']

# %%
set6 = pd.read_csv('set6_features.csv')
set6['num_words'].mean()
# Out:
# 153.29833333333335

# %%
set6_keywords = set()

for i in set6[set6['domain1_score'] == 4]['essay']:
    unicode_converted = i.replace("\x93", '"').replace("\x94", '"').replace("\x85",  '')
    quotes = get_quotes(unicode_converted)
    if len(quotes) > 0:
        print(quotes, "\n")
        set6_keywords.update(quotes)

set6_keywords
# Out:
# ['When the German dirigible Hindenburg was destroyed by fire in Lakehurst, New Jersey, on May 6, 1937, the owners of the Empire State Building realized how much worse that accident could have been if it had taken place over a densely populated area such as downtown New York.', 'Even if the dirigible were tethered to the mooring mast, the back of the ship which swivel around and around the mooring mast.', 'This law would make it illegal for a ship to ever tie up to a building or even approach the area.', 'By the late 1930s, the idea of using the mooring mast for dirigibles and their passengers had quietly disappeared.']
#
# ["The steel frame of the Empire State Building would have to be modified and strengthened to accommodate this new situation. Over @MONEY1 worth of modifications had to be made to the building's framework.", 'dangling high above pedestrians on the street']
#
# ["The stress of the dirigible's load and wind pressure would have to be transmitted all the way to the building's Foundation, which was nearly eleven hundred Feet below.", " Al Smith realized that he was close to losing the title of the world's tallest building, and on December 11, 1929, he announced that the Empire State Building would now reach the height of 1,250 Feet.", ' Dirigibles moored in open landing fields could be weighted down in the back with lead weights, but using these at the Empire State Building, where they would be dangling high above pedestrians on the street, was neither practical nor safe.']
#
# ["The stress of the dirigibles load and the wind pressure would have to be transmitted all the way to the building's foundation.", 'The greatest obstacles to successful mooring was nature itself.']
#
# ["over @NUM1 thousand dollar's worth of modifications had to be made to the building's framework", 'safety', 'nature', 'neither practical nor safe', 'an existing law against airships flying to low over urban areas', 'illegal for a ship to ever tie up to the building or even approach the area.']
#
# ['The winds on top of the building were constantly shifting due to violent air currents,', 'although two dirigibles did attempt to reach the building before the entire idea was dropped.']
#
# ['Should have been apparent before it was ever constructed. One of the problems that they faced was that many dirigibles ', ' This factor caused that the owners of the Building to worry about the safety of the many civilians that lived in downtown New York. Another factor that the builders face was that the winds ', ' This caused problems because in landing fields the blimps could be weighted down with lead weights but that could not be done at the Empire State Building; many dirigibles would not be able to reach the Building either due to the winds. One last factor that was faced is that it is against the law to have airships fly to low over the urban areas. This ', ' All these factors caused ']
#
# ['dream of aviation pioneers,']
#
# ['The Mooring Mast']
#
# ["A thousand-foot dirigible moored at the top of the building... would add stress to the building's frame.", 'the winds on top of the building were constantly shifting due to violent air currents.', 'most dirigibles from outside of the united states used Hydrogen... and Hydrogen is highly flammable.']
#
# ['The Mooring Mast', "over sixty thousand dollars' worth of modifications had to be made to the buildings framework", 'The greatest reason was one of safety... hydrogen is highly flammable', 'The greatest obstacle to the successful use of the mooring mast was nature itself']
#
# ['The Mooring Mast', 'The winds on the top of the building were constantly shifting due to the violent currents. Even if the dirigible were tethered to the mooring mast, the back of the ship would swivel around and around the mooring mast. The final problem the builders faced was, even if they did manage to figure out a way to put the mooring mast up, there was still a law stating dirigibles illegal to land there. Lüsted said in paragraph @NUM2, ']
#
# ["the stress of the dirigible's load and the wind pressure would...be transmitted all the way to the building's foundation...nearly eleven hundred feet below", 'where they would be dangling high above pedestrians on the street, was neither practical nor safe', 'Los Angeles', "the wind would blow the dirigible into the sharp spires of other buildings in the area, which would puncture the dirigible's shell"]
#
# ['The Mooring Mast', 'The winds on top of the building were constantly shifting due to violent air currents.']
#
# ['nature itself. The winds, on top of the building were constantly shifting due to violent air currents.', 'U.S. Navy dirigible Los Angeles approached the mooring mast but could not get close enough to tie up because of forceful winds. A concern for safety was that ', ' If something wrong were to happen, there could be great consequences for the heavily populated downtown of @LOCATION2. A third and final obstacle that occurred was ']
#
# ['Most dirigibles from outside of the United States used hydrogen rather than helium; and hydrogen is highly flammable.', 'The winds on top of the building were constantly shifting due to violent air currents', 'This law would make it illegal for a ship to ever tie up to the building or even approach the area']
#
# ["could not simply drop a mooring mast on top of the Empire State Building's flat roof...", "would add stress to the building's frame", 'hydrogen instead of helium', 'constantly shifting due to violent air currents', 'flying too low over urban areas.', 'illegal for a ship to ever tie up to the building or even approach the area.']
#
# ['The @CAPS1 Mast', '...realized how much worse that accident could have been if it had taken place above a densely populated area such as downtown New York.']
#
# ["The stress of the dirigible's load and wind pressure would have to be transmitted all the way to the building's foundation...", "Over sixty thousand dollars' worth of modifications had to be made to the building's framework", 'Most dirigibles from outside the United States used Hydrogen rather than helium, and hydrogen is highly flammable']
#
# ['The Mooring Mast', "Over sixty thousand dollars' worth of modifications had to be made to the building's framework.", 'This law would make it illegal for a ship to ever tie up to the Building or even approach the area. ']
#
# ['The Mooring Mast,', "a thousand-foot dirigible moored at the top of the building, held by a single cable tether, would add stress to the building's frame,", "most dirigible's built outside the United States use hydrogen rather than helium, and hydrogen is highly flammable", 'an existing law against airships flying too low over urban areas.']
#
# ['The Mooring Mast', 'The architects could not simply drop a mooring mast on top of the empire state Buildings flat roof, it would add to much stress to the buildings frame']
#
# ['The Mooring Mast', 'master']
#
# ["The stress of the dirigible's load and the wind pressure would have to be transmitted all the way to the building's foundation.", 'greatest obstacle to the successful use of the mooring mast was nature itself.', 'swivel around']
#
# ['Los Angeles']
#
# ['Most dirigibles used hydrogen rather than helium, and hydrogen is highly flammable.', 'an existing law against airships flying too low over urban areas']
#
# ['The architects could not simply drop a mooring mast on top of the empire state buildings flat roof.', 'The other practical reason why dirigibles could not moor at the empire state building was an existing law against airships flying to low over urban areas.', 'The winds on top of the building were constantly shifting due to violent air currents.']
#
# ['The Mooring Mast,', 'Most dirigibles from outside of the United States used hydrogen rather than helium, and hydrogen is highly flammable.', 'using [lead weights] at the Empire State Building, where they would be dangling high above pedestrians on the street, was neither practical or safe.', '[There] was an existing law against airships flying too low over urban areas. This law would make it illegal for a ship to ever tie up to the building.']
#
# ['Empire State Building was an existing law against airships flying too low over urban areas', 'The winds on top of the building were constantly shifting due to violent air currents', 'When the German dirigible Hindenburg was destroyed by fire in Lakehurst, New Jersey.']
#
# ['how much worse that accident could have been if it had taken place of a densely populated area.', 'airships flying to low over urban areas']
#
# ['highly flammable', 'dangling high above pedestrians', 'too low over urban areas']
#
# ['transportation of the future', "The stress of the dirigibles load and the wind pressure would have to be transmitted all the way to the building's foundation", 'Most dirigibles from outside of the united states used hydrogen rather than helium, and hydrogen is highly flammable.', ' Even if the back of the dirigibles were weighted down with lead, it would not be safe; as the lead would be ', ' There was also a law stating that airships could not fly too low above urban areas. Nature itself presented many more problems, such as winds blowing the dirigible onto the ', ' As numerous problems became apparent after the building was finished, the idea of dirigibles being the ']
#
# ["over sixty thousand dollars worth of modifications had to be made to the building's framework,", 'hydrogen is highly flammable.', 'constantly shifting due to violent air currents.', 'an existing law against airships flying too low over urban areas.']
#
# ['The steel frame of the Empire State Building would have to be modified and strengthened to accommodate this new situation.', 'Even if the dirigibles were tethered to the mooring mast, the back of the ship would swivel around and around the mooring mast.']
#
# ['would add stress to the building.', 'were constantly shifting due to violent air currents.']
#
# ['Most dirigibles from outside of the United States used hydrogen rather than, helium, and hydrogen is highly flammable.', 'The other practical reason why dirigibles could not moor at the Empire State Building was an existing law against airships flying too low over urban areas.', 'The @CAPS2 Mast', "Fearing that the wind would blow the dirigibles onto the sharp spires of other buildings in the area, which would puncture the dirigible's shell."]
#
# ['densely populated area.', 'would be dangling high above pedestrians on the street,', 'was neither practical nor safe.']
#
# ['The Mooring @CAPS1']
#
# ['The Mooring Mast,', "could not simply drop a mooring mast on top of the Empire State building's flat roof,", "hydrogen rather than helium, and hydrogen is highly flammable...the owners of the empire state building realized how much worse the accident could've been.", 'the U.S. Navy dirigible, Los Angeles approached the mooring mast but could not close enough to tie up because of forceful winds.']
#
# ['The greatest obstacle was nature itself', 'existing law against airships flying too low over urban areas.', 'hydrogen is highly flameable']
#
# ['The Mooring Mast', 'refueling or service, and to let passengers on and off.']
#
# ['most dirigibles from outside of the United States used hydrogen rather than helium', 'the winds at the top of the building were constantly shifting due to violent air currents.', 'the back of the ship would swivel around and around the mooring mast', "the wind would blow the dirigible onto the sharp spires of other buildings in the area, which would puncture the dirigible's shell", 'airships flying too low over urban areas', 'illegal for a ship to ever tie up to the building or even approach the area']
#
# ['The Mooring Mast', 'Most dirigibles... used hydrogen... highly flammable...', 'The winds on top of the building were constantly shifting due to violent air currents... neither practical nor @NUM1). The construction workers realized that having passengers moving on and off the mast, could be very dangerous in harsh weather conditions. The final obstacle the construction workers faced was an overlooked airship law. The story says, ']
#
# ['A thousand-foot dirigible moored at the top of the building, held by a single cable tether,', 'when the German dirigible Hindenburg was destroyed by fire in Lakehurst, New Jersey, on May 6, 1937, the Owners of the Empire State Building realized how much worse the accident could have been if it had taken place above a densely populated area such as downtown New York.']
#
# ['hydrogen [which] is highly flammable,', 'winds on top of the building... shifting due to... air currents', 'would be dangling above pedestrians.']
#
# ['The greatest obstacle to the successful use of the mooring mast was nature itself. The winds on top of the building were constantly shifting due to violent air currents.', 'This law would make it illegal for a ship to ever tie up to the building or even approach the area...', '... the owners of the Empire State Building realized how much worse the accident could have been...']
#
# ['The greatest reason was one of safety. Most dirigibles from outside the United States used hydrogen rather than helium, and hydrogen is highly flammable', 'Owners of the Empire State Building realized how much worse the accident could have been if it had taken place above a densely populated area such as downtown New York', 'The winds on top of the building were constantly shifting due to violent air currents', 'Even if the dirigible were tethered to the mooring mast, the back of the ship would swivel around and around the mooring mast', 'This law would make it illegal for a ship to ever tie up to the building or even approach the area']
#
# ["The architects could not simply drop a mooring mast on top of the @ORGANIZATION1 flat roof. A thousand foot dirigible moored at the top of the building, held by a single cable tether, would add stress to the buildings frame. The stress of the dirigible's load and the wind pressure would have to be transmitted all the way to the building's foundation."]
#
# ['The Mooring Mast', 'Hindenburg']
#
# ['The Mooring Mast,', 'most dirigibles from outside the United States used hydrogen rather than helium,', 'the greatest obstacle to the successful use of the mooring mast was nature itself.']
#
# ['mooring mast', 'transportation of the future.']
#
# ['the mooring Mast', 'Most dirigibles from outside of the United States used hydrogen rather than helium, and hydrogen is highly flammable', 'The wind on top of the building were constantly shifting due to violent air currents', 'This law would make it ilegal for a ship to ever tie up to the building or even approach the area', 'The Mooring Mast']
#
# ["the stress of the dirigible's load... would have been transmitted all the way to the building's foundation", 'violent', 'even if the dirigible were tethered to the mooring mast, the back of the ship would swivel around', 'against airships flying too low over urban areas']
#
# ['The winds on top of the building were constantly shifting due to violent air currents.', 'This law would make it illegal for a ship to ever tie up to the building or even approach the area,', 'Most dirigibles from outside of the United States used hydrogen rather than helium, and hydrogen is highly flammable.']
#
# ["The stress of the dirigible's load and the wind pressure would have to be transmitted all the way to the building's foundation.", 'When the German dirigible Hindenburg was destroyed by fire... The owners realized how much worse have it been taking place above a densely populated area.', 'The winds on top of the building shifts due to violent air currents.']
#
# ["Over sixty thousand dollars' worth of modifications had to be made to the building's framework.", 'When the German dirigible Hindenburg was destroyed by fire in Lakehurst on May 6, 1937, the owners of the empire State Building realized how much worse the accident could have been if it had taken place above a densely populated area.', 'using these at the Empire State Building, would be dangling over pedestrians on the street, was neither practical nor safe.']
#
# ['... was destined to never fulfill its purpose [Empire State building being a dock for dirigibles], for reasons that should have been apparent before it was ever constructed.']
#
# ['the lack of a suitable landing area.']
#
# ['Most dirigibles outside of the United States used hydrogen rather than helium, and hydrogen is highly flammable. When the German dirigible Hindenburg was destroyed by fire in Lakehurst, New Jersey, on May 6, 1937, the owners of the Empire State Building realized how much worse that accident could have been if it had taken place above a densely populated area such as downtown New York.', 'Even if the dirigible were tethered to the mooring mast, the back of the ship would swivel around and around the mooring mast.', 'This law would make it illegal for a ship to ever tie up to the building, or even approach the area.']
#
# ['most dirigibles from outside the United States used hydrogen rather than helium']
#
# ['The Mooring Mast', 'was an existing law against airships flying too low over urban areas.', 'violent air currents.', 'used hydrogen rather than helium,']
#
# ['The Mooring Mast,', 'Most dirigibles from outside of the United States used hydrogen rather than helium, and hydrogen is highly flammable.', 'a densely populated area such as downtown New York.', 'were constantly shifting due to violent air currents.', 'weighted down with lead weights... where they would be dangling high above pedestrians on the street.', 'neither practical nor safe.', 'was an existing law against airships flying too low over urban areas. This would make it illegal for a ship to ever tie up to the building or even approach the area.', 'that should have been apparent before it was ever constructed.']
#
# ['The greatest reason was one of safety: dirigibles outside @LOCATION1 used hydrogen, which is highly flammable.', 'laws against airships flying too low over urban areas.', 'The winds on top of the building were constantly shifting due to violent air currents.', 'the complete dirigible mooring equipment had never been installed.']
#
# ['the greatest obstacle to the successful use of the mooring mast was nature itself.', 'The winds on top of the building were constantly shifting due to violent air currents.', 'Most dirigibles from outside the United States use hydrogen rather than helium, and hydrogen is highly flammable.']
#
# ["thousand foot dirigible moored at at the top of the building held by a single cable tether would add stress to the building's frame...", 'over sixty thousand dollars', ' An example of this safety violation occurred with the burning of a dirigible in Lakehurst, New Jersey, causing builders to reflect on the possible severity of this possible accident in the heavily populated area of New York. Thirdly, New York had ', ' which could cause the rear of the dirigibles to swivel and shift. The only possible solution was to way down the back with lead blocks, but this would be ']
#
# ["the stress of the dirigible's load and the wind pressure would have to be transmitted all the way to the building's foundation, which was nearly eleven hundred feet below"]
#
# ['Most dirigibles from outside the United States used hydrogen rather than helium, and hydrogen is highly flammable. When the German dirigible Hindenburg was destroyed by fire in Lakehurst, New Jersey, on May 6, 1937, the owners of the Empire State Building realized how much worse that accident could have been if it had taken place above a densely populated area such as downtown New York', 'The winds on top of the building were constantly shifting due to violent air currents.', '. There additionally was a law which dated airships cannot fly that low over an urban area. Thus, the multiple obstacles which were faced through this ']
#
# ['constantly shifting due to violent air currents,', "would add stress to the building's frame,"]
#
# ['highly flammable.', 'Violent air currents', 'airships [from] flying too low over urban areas,']
#
# ['... practical nor safe.']
#
# ["The stress of the dirigible's load and the wind pressure would have to be transmitted all the way to the building's Foundation, which was nearly eleven hundered feet below.", 'Safety was also another big issue.']
#
# ['The Mooring Mast,', 'hydrogen is highly flammable', 'above a densely populated area such as downtown New York', 'the back of the ship would swivel around', 'was neither practical nor safe', 'flying too low over urban areas']
#
# ['A thousand-foot dirigible moored at the top of the building, held by a single cable tether, would add stress to the buildings frame.', 'Even if the dirigible were tethered to the mooring mast, the back of the ship would swivel around and around the mooring mast.', 'an existing law against airships flying too low over urban areas.']
#
# ['The Mooring Mast', 'Most dirigibles from outside of the United States used hydrogen rather than helium, and hydrogen is highly flammable.', 'The other reason practical reason why dirigibles could not moor at the Empire State Building was existing law against airships flying too low over urban areas.', 'In December 1930, the U.S Navy dirigible @CAPS1 Angeles approached the mooring mast could not get close enough to tie up because of forceful wind.']
#
# ['The winds on top of the building were constantly shifting due to violent air currents. Even if the dirigible was tethered to the mooring mast, the back of the ship would swivel around.', 'The Hindenburg']
#
# ["the architects could'nt just drop a mooring mast on top of the Empire State Building's flat roof. A thousand-foot dirigible moored at the top of the building, held by a single cable tether, would add stress to the building's frame. The stress of the dirigible's load & the wind pressure would have to be transmitted all the way to the buildings foundation.", 'Hindenburg', 'Hindenburg accident', 'highly populated area such as downtown New York.', 'nature itself.', 'was neither practical nor safe.']
#
# ['winds on top of the building were constantly shifting due to violent air currents.']
#
# ["A thousand-foot dirigible moored at the top of the building, held by a single cable tether, would add stress to the building's frame."]
#
# ['The Mooring Mast,', "The stress of the dirigible's load into the wind pressure would have to be transmitted all the way to the building's foundation, which was nearly eleven hundred feet below. The steel frame of the Empire State Building would have to be modified and strengthened to accommodate this new situation.", "The Mooring Mast  of the Empire State Building was destined never to fulfill it's purpose. Most dirigibles from outside of the United States used hydrogen rather than helium, and hydrogen is highly flammable."]
#
# ['most dirigibles from outside of the United States used hydrogen rather than helium, and hydrogen is considered highly flammable', 'winds on top of the building', 'were constantly shifting due to violent air currents', 'would make it illegal for ship to ever tie up to the building or even approach the area. Unless the law was revoked, the mooring mast would never be able to work. However, the obstacle that the builders faced when designing the actual mast itself were that ', ' because ', ' which turned out to be ']
#
# ['most dirigibles from outside of the United States used hydrogen rather than helium, and hydrogen is highly flammable.', 'the winds on top of the building were constantly shifting due to violent air currents,', 'an existing law against airships flying to low over urban areas.']
#
# ['The owners of the Empire State building realized how much worse the accident could have been if it had taken place above a densely populated area such as downtown New York,', 'The greatest obstacle to the successful use of the mooring mast was nature itself.']
#
# ['the greatest obstacle to the successful use of the mooring mast was nature itself.', 'an existing law against airships flying too low over urban areas.']
#
# ['the architects could not simply drop a mooring mast on the top of the @ORGANIZATION1 flat roof', 'were constantly shifting due to violent air currents', 'swivel around and around the mooring mast']
#
# ['Most dirigibles from out side the United States used hydrogen rather than helium, and hydrogen is highly flammable.', 'The winds on top of the @ORGANIZATION1 were constantly shifting due to violent air currents.', 'was an existing law against airships flying too low over urban areas']
#
# ['using these at the Empire State Building, where they would be dangling high above pedestrians on the street, was neither practical nor safe.']
#
# ["the stress of the dirigible's load and wind pressure would have to be transmitted... to the building's foundation.", 'the owners of the Empire @CAPS1 Building realized how much worse that accident could have been', 'nature itself.', 'neither practical or safe.']
#
# ['quick fix']
#
# ['The winds on top of the building were constantly shifting due to violent air currents,']
#
# ["over sixty thousand dollars' worth of modifications", 'Hindenburg,', 'highly flammable.', 'forceful winds']
#
# ['drop a mooring mast on top of the Empire State Building.', 'the steel frame of the Empire State Building would have to be modified and strengthened to accommodate the new situation', 'The greatest obstacle of the successful use of the mooring mast was nature itself,', 'violent air currents.']
#
# ["The steel frame of the empire state building would have to be modified and strengthened to accommodate this situation. over sixty thousand dollars' worth of modifications had to be made to the buildings framework.", ' The 102 story floor building was predicted to be a success and predicted to become the new age of aviation travel. Another obsitcle that the workers faced was realizing that dirigibles outside the @CAPS1 were highly flammable because they contain hydrogen. It would be disastrous if one caught on fire on the top of the building in New York City. ', ' (@CAPS2 @NUM2).']
#
# ['The Mooring Mast', 'The winds on the top of the building were constantly shifting due to violent air currents.']
#
# ['Most dirgibles from outside of the United States used hydrogen instead of Helium', 'was an existing law against airships flying too low over urban areas... this would make it illegal for a ship to ever tie up to the building or even approach the area.']
#
# ["The stress of the dirigible's load and the wind pressure would have to be transmitted all the way to the building's foundation, which was nearly eleven hundred feet below. The steelframe of the Empire State Building would have to be modified and strengthened to accommodate this new situation", 'When the German dirigible Hindenburg was destroyed by fire in Lakehurst, New Jersey, on May 6, 1937, the owners of the Empire State Building realized how much worse that accident could have been if it had taken place above a densely populated area such as downtown New York', 'The winds on top of the building were constantly shifting due to violent air currents. Even if the dirigible were tethered to the mooring mast, the back of the ship would swivel around and around the mooring mast']
#
# ['The Mooring @CAPS1', 'The greasest issues was one of safety.', 'nature itself.', 'The winds on top of the building were constantly shifting due to violent air currents.', 'a law against airships flying too low over urban areas.', 'The Mooring Mast.']
#
# ["the stress of the dirigible's load and windpressurs"]
#
# ['most dirigibles from outside the United States used hydrogen rather than helium, and hydrogen is highly flammable.', 'The winds on top of the building were constantly shifting due violent air currents.', 'an existing law against airships flying too low over urban areas.', 'in December 1930, the U.S Navy dirigible Los Angeles approached the mooring mast but could not get close enough to tie up because of forceful winds.']
#
# ['The Mooring Mast', 'Hindenburg', ' (paragraph @NUM1). Another obstacle was the existing law against low-flying airships in urban areas. This law makes is so that it is ', ' (paragraph @NUM2). The greatest obstacle of all however, was mother nature. The winds that high in the sky were ']
#
# ['Most dirigibles from outside of the United States used hydrogen rather than helium, and hydrogen is highly flammable.', 'Even if the dirigible were tethered to the mooring mast, the back of the ship would swivel around and around the mooring mast.', 'This law would make it illegal for a ship to tie up to the building or even a produced area...']
#
# ["The stress of dirigibles load and the wind pressure would have to be transmitted all the way to the building's foundation"]
#
# ["the architects could not simply drop a mooring mast on top of the Empire State Building's flat roof", 'a single cable tether', 'over sixty thousand dollars worth of modifications', 'nature itself', 'constantly shifting due to violent air currents', 'practical nor safe.', 'law against airships flying too low over urban areas', 'Make it illegal for a ship to ever tie to the building.']
#
# ['... engineers here in New York [are] trying to dope out a practical, workable arrangement', ' (paragraph @NUM2). Another obstacle was that most dirigibles outside of the @LOCATION2 use hydrogen, which is very flammable. When the ', ' was destroyed by fire, ', ' (paragraph @NUM3). The most significant obstacle was ', ' (paragraph @NUM4). Due to violent air currents, ', ' (paragraph @NUM4) in open areas, dirigibles could be weighted down by lead weights, but this poses a threat to pedestrians on the street, as the weights would be dangling above them. Lastly, there was ']
#
# ["A thousand foot dirigible moored at the top of the building, held by a single cable tether, would add stress to the building's frame.", 'When the German dirigible Hindenburg was destroyed by a fire in Lakehurst, New Jersey, on May 6, 1937, the owners of the Empire State Building realized how much worse that accident could have been if it had taken place above a densely populated area, such as downtown New York']
#
# ['they would be dangling above pedestrians on the street... neither practical nor safe.', 'never fulfilled its purpose, for reasons that should have been apparent before it was ever constructed.']
#
# ['The owners of the Empire State Building realized how much worse that accident could have been if taken place above a densely populated area.']
#
# ['... have to be modified and strengthened to accommodate this new situation.', '... rather than helium, and hydrogen is highly flammable.', 'dirigibles moored in open landing fields could be weighed down in the back with lead weights...', 'law against airships flying too low over urban areas.']
#
# ['The Mooring Mast', 'Hindenburg', 'densely populated', 'swivel', 'existing laws against aircrafts flying too low over urban areas.', 'Mooring Mast', 'the unsolved problems of mooring airships to a fixed mast at such a height that made it desirable to postpone to a later date the final installation of the landing gear.']
#
# ['Over sixty thousand dollars', 'Most dirigibles from outside of the United States used hydrogen rather than helium, and hydrogen is highly flammable.']
#
# ['The as yet unsolved problems of mooring air ships to a fixed mast at such a height made it desirable to postpone to a later date the final installation of the landing gear.']
#
# ['The Mooring Mast', "The stress of the dirigible's load and the wind pressure would have to be transmitted all the way to the building's foundation, which was nearly eleven hundred feet below."]
#
# ['The Mooring Mast']
#
# ['how much worse the accident could have been (paragraph @NUM1) if it had occurred in a city like New York. The greatest obstacle they faced however was nature. The violent air currents caused the wind to constantly shift which would cause the docked aircrafts to ']
#
# ['The steel frame of the Empire State building would have to be modified and strengthened to accommodate this new situation. (paragraph @NUM1) ']
#
# ["the dirigibles load and the wind pressure would have to be transmitted all the way to the building's foundation.", 'the owners of the @ORGANIZATION2 realized how much worse that accident could have been if it had taken place above a densely populated area.']
#
# ['The Mooring Mast', 'modify and strengthen the empire state building to this new situation.', 'accident to take place above a densely populated area such as downtown New York. Lastly builders would have to face the obstacle of Nature. With winds so strong up top the building the dirigibles would need to be weighted down in back with lead weights which would be neither safe nor practical dangling high above pedestrians in New York City. In conclusion ']
#
# ['The Mooring Mast', 'densely populated area such as downtown New York', 'Even if the dirigible were tethered to the mooring mast, the back of the ship would swivel around and around the mooring mast.', 'The Mooring Mast']
#
# ['Held by a single cable tether', 'shiny glass and chrome-nickel stainless steel tower', 'law against airships flying too low']
#
# ['A thousand-foot dirigible moored at the top of the building held by a single cable tether, would add stress to the building frame', 'the owners of the Empire State realized how much worse the accident could have been if it had taken place above a densely populated area such as downtown New York.']
#
# ['Much worse if it had taken place above a densely populated area.', 'An existing law against air ships flying too low over urban areas. This law would make it illegal for a ship to ever tie up to the building or even approach the area. The greatest obstacle though was nature itself as stated in paragraph @NUM3. ', ' @CAPS1 the wind would make the dirigible swivel around and around the mooring mast. An idea came into plan that said ']
#
# ['The Mooring Mast', 'The Fate of the Mast', 'The greatest obstacle to the successful use of the mooring mast was nature itself. Strong winds due to violent air currents would make it impossible to dock a dirigible on the Empire State Building. The wind would blow the dirigible off the mast into New York City. In paragraph @NUM2 under ', ', a line states ', ' This law made it illegal for dirigibles and other aircraft to even fly in such and urban area like New York. One final obstacle is safety precautions. In paragraph @NUM3 a line states, ']
#
# ['The Mooring Mast', 'Most dirigibles from outside of the United States used hydrogen, rather than helium, and hydrogen is highly flammable.', 'The winds on top of the building were constantly shifting due to violent air currents. Even if the dirigible were tethered to the mooring mast, the back of the ship would swivel around and around the mooring mast.', 'The other practical reason why dirigibles could not moor at the Empire State Building was an existing law against airships flying too low over urban areas.']
#
# ['the winds on top of the building were constantly shifting due to violent air currents.', 'The steel frame of the Empire State Building would have to be modified and strengthened to accommodate...', 'an existing law against airships flying too low over urban areas']
#
# ["The stress of the dirigible's load and the wind pressure would have to be transmitted all the way to the building's foundation... over sixty thousand dollars' worth of modifications had to be made to the buildings framework", 'The winds on top of the building were constantly shifting due to violent air currents.', 'This law would make it illegal for a ship to ever tie up to the building or even approach the area']
#
# ['The Mooring Mast', 'the owners of the Empire State Building realized how much worse the accident could have been if it had taken place above a densely populated area such as downtown New York']
#
# ['the stress of the dirigibles load and the wind pressure would have to be transmitted all the way to the buildings foundation...', 'Even if the dirigibles was tethered to the mooring mast, the back of the ship would swivel around and break the mooring mast.', 'most dirigibles from outside the U.S use hydrogn rather than helium, and hydrogen is highly flammable.']
#
# ["would add stress to the building's frame", 'swivel around and around the mooring mast', "the sharp spires of other buildings in the area [could] puncture the dirigible's shell"]
#
# ["The steel frame of the Empire State Building would have to be modified and strengthened to accommodate this new situation. Over sixty thousand dollars' worth of modifications had to made to the building's framework.", 'When the German dirigible Hindenburg was destroyed by fire... The owners of the Empire State The building realized how much worse that accident could of been if it had taken place above a densely populated area such as downtown New York.', 'The winds on top of the building were constantly shifting due to violent air currents... The back of the ship would swivel around and around the mooring mast.']
#
# ['violent air currents']
#
# ['U.S. Navy dirigible Los Angeles approached the mooring mast but could not get close enough to tie up because of forceful winds']
#
# ['when the German dirigible Hindenburg was destroyed by fire in Lakehurst, New Jersey on May 6, 1937, the owners of the Empire state building realized how much worse that accident could have been if it had taken place above a densely populated area such as downtown New York.', 'This law would make it illegal to ever tie up to the building or even approach the area']
#
# ['The Mooring Mast', 'the greatest obstacle to the successful use of the mooring mas was nature itself.', 'Most dirigibles from outside the United States used hydrogen rather than helium, and hydrogen is highly flammable']
#
# ['The Mooring Mast', "Over sixty thousand dollars' worth of modifications had to be made to the building's framework", 'hydrogen is highly flammable']
#
# ['an existing law against airships flying too low over urban areas', 'Most dirigibles from outside of the United States used hydrogen rather than helium, and hydrogen is highly flammable', 'The winds on top of the building were constantly shifting due to violent air currents']
#
# ['used hydrogen rather than helium, and hydrogen is highly flammable.', '... that the wind would blow with the dirigible onto the sharp spires of other buildings in the area...']
#
# ['The greatest obstacle to the successful use of the mooring mast was nature itself.']
#
# ['The owners of the Empire State Building realized how horrible an accident could be if it takes place in a highly populated area.         The greatest obsticle the builders faced was nature itself. ', ' paragraph @NUM2 states. They could have weighted it down with lead weights, but using these where they would be hanging above pedestrians was not safe.     The last obsticle the builder faced was the law was against airships flying too low over urban areas. This law would make it illegal for any ship to dock at the @ORGANIZATION1 on the excerpt from The Mooring Mast, there were many obsticles builders faced to allow dirigibles to dock there']
#
# ["the stress of the dirigible's load and the wind pressure would have to be transmitted all the way to the building's foundation...the building would have to be modified and strengthened to  accomodate the situation.", 'the owners of the empire state building realized how much worse that accident would have been over a densely populated area such as downtown @LOCATION1', 'were neither practical nor safe.', 'an existing law against airships flying too low over urban areas.']
#
# ["The architects could not simply drop a mooring mast on top of the Empire State Building's flat roof", 'which was nearly eleven hundred feet below.', 'used hydrogen rather than helium, and hydrogen is highly flammable', 'Even if the dirigible were tethered to the mooring mast, the back of the ship would swivel around and around the mooring mast']
#
# ['..., The owners of the Empire State building realized how much worse that accident could have been if it had taken place above a densely populated area such as downtown New York.', 'The winds on top of the building were consular shifting due to violent air currents.', 'neither practical or safe.', 'The other practical reason why dirigibles could not moor at the Empire State Building was an existing law against airships flying too low over urban areas']
#
# ['Rather than building a utilitarian mast without any ornametation, the architects designed a shiny glass and chrome-nickel stainless steel tower. They were able to overcome that obstacle. Another obstacle was safety. ', ' @CAPS1 obstacles did that bring? Well, hydrogen is highly flammable. When a German dirigible was destroyed by a fire in New Jersey, the owners of the ', 'The greatest obstacle to successful use of the mooring mast was nature itself. The winds on top of the building made it unsafe the only solution would be tethering the dirigible and weighing down the back with lead weights but using these at the building ']
#
# ['the winds on top of the building were constantly shifting due to violent air currents']
#
# ["would add stress to the building's frame", "over sixty thousand Dollars' worth", 'an existing law against airships flying too low over urban areas,', 'the winds on the top of the building were constantly shifting.', 'wind would blow the dirigible onto sharp spires,', 'hydrogen is extremely flammable.', 'above a densely populateD area.']
#
# ['The Mooring Mast', "The stress of the dirigible's load and the wind pressure would have to be transmitted all the way to the buildings foundation.", 'The winds on top of the building were constantly shifting due to violent air currents.', 'This law would make it illegal for a ship to ever tie up to the building.']
#
# ['equipped for an age of transportation that was then only the dream of aviation pioneers,', 'lighter than air,', 'destined to never fulfill its purpose.']
#
# ['The Mooring Mast', "A thousand-foot dirigible moored at the top of abuilding, held by a single cable tether, would add stress to the building's frame", 'Most dirigibles from outside the United States used hydrogen rather than helium, and hydrogen is highly flammable', 'The greatest obstacle to the successful use of the mooring mast was nature itself.']
#
# ["A thousand- foot dirigible moored at the top of the building, held by a single cable tether, would add stress to the building's frame... The steel frame of the Empire State Building would have to be modified and strengthened to accommodate this new situation.", 'The winds on top of the building were constantly shifting due to violent air currents.', 'Most dirigibles from outside of the United States used hydrogen rather than helium, and hydrogen is highly flammable.']
#
# ['the winds at the top of the building were constantly shifting due to violent air currents', 'how much worse that accident could have been if it had taken place above a densely populated area such as a downtown New York']
#
# ["could not simply drop a mooring mast on top of the Empire State Building's flat roof", "sixty thousand dollars' worth of modifications", 'the greatest obstacle to successful use of the mooring mast was nature itself', 'Columbia', 'Los Angeles']
#
# ['Even if the dirigible were tethered to the mooring mast, the back of the ship would swivel around and around the mooring mast.']
#
# ['Constantly shifting due to violen air currents', "Fearing that the wind would blow the dirigible onto the sharp spires of the othe building in the area, which would puncture the dirigible's shell."]
#
# ['The Mooring Mast', 'Most dirigibles from outside the U.S. used hydrogen rather than helium, and hydrogen is highly flammable', 'was an existing law against airships flying too low over urban area', 'The winds on top of the building were constantly shifting due to violent air currents... The back of the ship would swivel around... dangling high above pedestrians on the street']
#
# ["The architects could not simply drop a mooring mast on top of the Empire State Building's flat roof. A thousand foot dirigible moored at the top of the building, held by a single cable tether, would add stress to the buildings frame.", 'The greatest obstacle to the successful use of the mooring mast was nature itself.']
#
# ["stress of the dirigible's load and wind pressure would have to be transmitted all the way to the building's foundation.", 'the winds on top of the building were constantly shifting due to violent air currents.']
#
# ['used hydrogen rather than helium, and hydrogen is highly flamable.', 'the winds on top of the building were constantly shifting due to violent air currents.', 'this law would make it illegal for a ship to ever tie up to the building.']
#
# ['The Mooring Mast,', 'The greatest obstacle ...was nature itself.', 'Hindenburg', 'Most dirigibles from outside the United States used hydrogen rather than helium, and hydrogen is highly flammable.', '...existing law against airships flying too low over urban areas.', 'The Mooring Mast,']
#
# ['... an existing law against airships flying too low over urban areas. This law would make it illegal for a ship to ever tie up to the building or even approach the area...', 'Most dirigibles... used hydrogen... hydrogen is highly flammable', '... violent air currents... back of the ship would swivel around... high above pedestrians,']
#
# ['The steel frame of the [building] would have to be modified and strengthened to accommodate [the added pressure from the dirigible].', 'Even if the dirrigible were tethered to the mooring mast, the back of the ship would swivel around and around the mooring mast.', 'could not get close enough to tie up because of forceful winds.']
#
# [' As quoted by the passage, ']
#
# ["The architects could not simply drop a mooring mast on top of the Empire State Building's flat roof", 'Even if the dirigible were tethered to the mooring mast, the back the ship would swiveled around, and around the mooring mast']
#
# ['Winds were constantly shifting due to violent air currents']
#
# ['The Mooring Mast']
#
# ["The stress of the dirigibles load and the wind pressure would have to be transmitted all the way to the building's foundation", 'the winds on top of the building were constantly shifting due to violent air currents', 'neither practical nor safe.']
#
# ['...could not simply drop a mooring mast,', "...single cable tether, would add stress to the building's frame. The stress of the dirigibles load and the wind pressure would have to be transmitted all the way to the building's foundation...", 'The winds on top of the building were constantly shifting due to violent air current.', '...an existing law against airships flying too low over urban areas.', 'highly flammable.', 'much worse.']
#
# ["... held by a single cable tether, would add stress to the building's frame", "Over sixty thousand dollars'", '... down to the eighty-sixth floor, where baggage and ticket areas would be located', 'The greatest obstacle to the successful use of the moor mast was nature itself']
#
# ["The stress of the dirigible's load and the wind pressure would have to be transmitted all the way to the building's foundation.", 'The owners of the Empire State Building realized how much worse [an] accident could [be] if it had taken place above a densely populated area such as downtown New York.', 'Even if the dirigible were tethered to the mooring mast, the back of the ship would swivel around and around the mooring mast.']
#
# ['The Mooring Mast', 'The winds on top of the building were constantly shifting due to violent air currents.', "The stress of the dirigible's load and the wind pressure would have to be transmitted all the way to the building's foundation.", 'an existing law against airships flying too low over urban areas.', 'mooring']
#
# ...
#  'greatest obstacle to the successful use of the mooring mast was nature itself.',
#  'greatest reason was one of safety',
#  'highly flammable',
#  'highly flammable.',
#  'highly populated area such as downtown New York.',
#  'how much worse that accident could have been if it had taken place above a densely populated area such as a downtown New York',
#  'how much worse that accident could have been if it had taken place of a densely populated area.',
#  'how much worse the accident could have been (paragraph @NUM1) if it had occurred in a city like New York. The greatest obstacle they faced however was nature. The violent air currents caused the wind to constantly shift which would cause the docked aircrafts to ',
#  'hydrogen [which] is highly flammable,',
#  'hydrogen instead of helium',
#  'hydrogen is extremely flammable.',
#  'hydrogen is highly flameable',
#  'hydrogen is highly flammable',
#  'hydrogen is highly flammable.',
#  "hydrogen rather than helium, and hydrogen is highly flammable...the owners of the empire state building realized how much worse the accident could've been.",
#  'illegal for a ship to ever tie up or approach of building.',
#  'illegal for a ship to ever tie up to the building or even approach the area',
#  'illegal for a ship to ever tie up to the building or even approach the area.',
#  'in December 1930, the U.S Navy dirigible Los Angeles approached the mooring mast but could not get close enough to tie up because of forceful winds.',
#  'it illegal for ship to ever tie up to the building or even approach the area',
#  'it illegal for ship to ever tie up to the building or even approach the area.',
#  'lack of a suitable landing area.',
#  'law against airships flying too low',
#  'law against airships flying too low of urban areas',
#  'law against airships flying too low over urban areas',
#  'law against airships flying too low over urban areas.',
#  'laws against airships flying too low over urban areas.',
#  'lighter than air,',
#  'master',
#  'modify and strengthen the empire state building to this new situation.',
#  'moored in open landing fields',
#  'mooring',
#  'mooring mast',
#  "most dirigible's built outside the United States use hydrogen rather than helium, and hydrogen is highly flammable",
#  'most dirigibles from outside United States use hydrogen rather than helium, and hydrogen is highly flammable.',
#  'most dirigibles from outside of the United States used hydrogen rather than helium',
#  'most dirigibles from outside of the United States used hydrogen rather than helium, and hydrogen is considered highly flammable',
#  'most dirigibles from outside of the United States used hydrogen rather than helium, and hydrogen is highly flammable.',
#  'most dirigibles from outside of the united states used Hydrogen... and Hydrogen is highly flammable.',
#  'most dirigibles from outside the U.S use hydrogn rather than helium, and hydrogen is highly flammable.',
#  'most dirigibles from outside the U.S used hydrogen rather than helium, & hydrogen is highly flammable.',
#  'most dirigibles from outside the United States used hydrogen rather than helium',
#  'most dirigibles from outside the United States used hydrogen rather than helium,',
#  'most dirigibles from outside the United States used hydrogen rather than helium, and hydrogen is highly flammable.',
#  'most of dirigibles outside of the United States used hydrogen rather than helium, and hydrogen is highly flammable.',
#  'much worse.',
#  'nature',
#  'nature itself',
#  'nature itself.',
#  'nature itself. The winds, on top of the building were constantly shifting due to violent air currents.',
#  'neither practical nor safe',
#  'neither practical nor safe.',
#  'neither practical or safe.',
#  'neither pratical or safe',
#  'never fulfilled its purpose, for reasons that should have been apparent before it was ever constructed.',
#  'no airships are allowed to fly low over urban areas.',
#  'or blimp',
#  'over @MONEY1',
#  "over @NUM1 thousand dollar's worth of modifications had to be made to the building's framework",
#  "over sixty thousand Dollars' worth",
#  "over sixty thousand dollar's worth of modifications",
#  "over sixty thousand dollar's worth of modifications had to be made to the building's framework",
#  'over sixty thousand dollars',
#  'over sixty thousand dollars worth of modifications',
#  "over sixty thousand dollars worth of modifications had to be made to the building's framework,",
#  'over sixty thousand dollars worth of modifications.',
#  "over sixty thousand dollars' worth of modifications",
#  "over sixty thousand dollars' worth of modifications had to be made to the building's framework.",
#  "over sixty thousand dollars' worth of modifications had to be made to the buildings framework",
#  "over sixty thousand dollars' worth of modifications... to the building's framework",
#  'over sixty thousand dollars...',
#  'owners... realized how much worse that accident could have been... above... New York',
#  'practical nor safe.',
#  'quick fix',
#  'quietly disappeared',
#  'realize how much worse the accident could have been,',
#  'realized how much worse that accident could have been',
#  'realized how much worse that accident could have been if it had taken place above a densely populated area such as downtown New York.',
#  'reasons that should have been apparent before it was even constructed',
#  'refueling or service, and to let passengers on and off.',
#  'roof had to be completed before the framing of the mooring mast could take place.',
#  'safety',
#  'sharp spires of other buildings.',
#  'shiny glass and chrome-nickel stainless steel tower',
#  "sixty thousand dollars' worth of modifications",
#  "stress of the dirigible's load and wind pressure would have to be transmitted all the way to the building's foundation.",
#  'swivel',
#  'swivel around',
#  'swivel around and around',
#  'swivel around and around the mooring mast',
#  'swivel around and around the mooring mast.',
#  'swivel around and around the mooring mast... dangling high above pedestrians on the street.',
#  'swivel around the mooring mast,',
#  'swivelling around the mooring mast.',
#  'tethered to the mooring mast,',
#  'that should have been apparent before it was ever constructed.',
#  'the U.S. Navy dirigible, Los Angeles approached the mooring mast but could not close enough to tie up because of forceful winds.',
#  'the architects could not simply drop a mooring mast on the top of the @ORGANIZATION1 flat roof',
#  "the architects could not simply drop a mooring mast on top of the Empire State Building's flat roof",
#  "the architects could'nt just drop a mooring mast on top of the Empire State Building's flat roof. A thousand-foot dirigible moored at the top of the building, held by a single cable tether, would add stress to the building's frame. The stress of the dirigible's load & the wind pressure would have to be transmitted all the way to the buildings foundation.",
#  'the back of the ship would swivel around',
#  'the back of the ship would swivel around and around the mooring mast',
#  'the back of the ship would swivel around... the mooring mast',
#  'the complete dirigible mooring equipment had never been installed.',
#  "the dirigibles load and the wind pressure would have to be transmitted all the way to the building's foundation.",
#  'the greatest obstacle to successful use of the mooring mast was nature itself',
#  'the greatest obstacle to the successful use of the mooring mas was nature itself.',
#  'the greatest obstacle to the successful use of the mooring mast was nature itself.',
#  'the greatest obstacle... was nature itself.',
#  'the idea of using the mooring mast for dirigibles and their passengers had quietly disappeared',
#  'the lack of a suitable landing area.',
#  'the mooring Mast',
#  'the owners of the @ORGANIZATION2 realized how much worse that accident could have been if it had taken place above a densely populated area.',
#  'the owners of the Empire @CAPS1 Building realized how much worse that accident could have been',
#  'the owners of the Empire State Building realized how much worse the accident could have been if it had taken place above a densely populated area such as downtown New York',
#  'the owners of the Empire State Building realized how much worse the accident could have been if it taken place above a densely populated areas such as downtown New York City.',
#  'the owners of the Empire State realized how much worse the accident could have been if it had taken place above a densely populated area such as downtown New York.',
#  'the owners of the empire state building realized how much worse that accident would have been over a densely populated area such as downtown @LOCATION1',
#  'the owners realized how much worse that accident could have been if it had taken place above a density populated area such as downtown New York.',
#  "the sharp spires of other buildings in the area [could] puncture the dirigible's shell",
#  "the sharp spires of other buildings in the area, which would puncture the dirigible's shell.",
#  'the steel frame of the Empire State Building would have to be modified and strengthened to accommodate the new situation',
#  'the steelframe [of the building had] to be modified and strengthened...',
#  "the stress of the dirigible's load and the wind pressure would have to be transmitted all the way to the building's foundation, which was nearly eleven hundred feet below",
#  "the stress of the dirigible's load and the wind pressure would have to be transmitted all the way to the building's foundation...the building would have to be modified and strengthened to  accomodate the situation.",
#  "the stress of the dirigible's load and the wind pressure would...be transmitted all the way to the building's foundation...nearly eleven hundred feet below",
#  "the stress of the dirigible's load and wind pressure would have to be transmitted... to the building's foundation.",
#  "the stress of the dirigible's load and windpressurs",
#  "the stress of the dirigible's load... would have been transmitted all the way to the building's foundation",
#  "the stress of the dirigibles load and the wind pressure would have been transmitted all the way to the building's foundation...",
#  'the stress of the dirigibles load and the wind pressure would have to be transmitted all the way to the buildings foundation...',
#  'the unsolved problems of mooring airships to a fixed mast at such a height that made it desirable to postpone to a later date the final installation of the landing gear.',
#  "the wind would blow the dirigible into the sharp spires of other buildings in the area, which would puncture the dirigible's shell",
#  "the wind would blow the dirigible onto the sharp spires of other buildings in the area, which would puncture the dirigible's shell",
#  'the winds at the top of the building were always moving and full of violent air currents,',
#  'the winds at the top of the building were constantly shifting due to violent air currents',
#  'the winds at the top of the building were constantly shifting due to violent air currents.',
#  'the winds on the top of the building were constantly shifting.',
#  'the winds on top of the building were constantly shifting due to violent air currents',
#  'the winds on top of the building were constantly shifting due to violent air currents,',
#  'the winds on top of the building were constantly shifting due to violent air currents.',
#  'they would be dangling above pedestrians on the street... neither practical nor safe.',
#  'this law would make it illegal for a ship to ever tie up to the building or even approach the area.',
#  'this law would make it illegal for a ship to ever tie up to the building.',
#  "thousand foot dirigible moored at at the top of the building held by a single cable tether would add stress to the building's frame...",
#  'thousand-foot dirigible moored at the top of the building, held by a single cable tether,',
#  'tie up to the building',
#  'too low over urban areas',
#  "transmite pressure from the dirigibe's load to the buildings foundation.",
#  'transportation of the future',
#  'transportation of the future.',
#  'used hydrogen rather than helium',
#  'used hydrogen rather than helium,',
#  'used hydrogen rather than helium, and hydrogen is highly flamable.',
#  'used hydrogen rather than helium, and hydrogen is highly flammable',
#  'used hydrogen rather than helium, and hydrogen is highly flammable.',
#  'used hydrogen rather than helium...',
#  'using [lead weights] at the Empire State Building, where they would be dangling high above pedestrians on the street, was neither practical or safe.',
#  'using these (dirigibles) at the Empire State Building, where they would be dangling high above pedestrians on the street, was neither practical nor safe.',
#  'using these at the Empire State Building, where they would be dangling high above pedestrians on the street, was neither practical nor safe.',
#  'using these at the Empire State Building, where they would be dangling, is neither practical nor safe.',
#  'using these at the Empire State Building, would be dangling over pedestrians on the street, was neither practical nor safe.',
#  'violent',
#  'violent air currents',
#  'violent air currents.',
#  'was an existing law against airships flying too low over urban area',
#  'was an existing law against airships flying too low over urban areas',
#  'was an existing law against airships flying too low over urban areas.',
#  'was an existing law against airships flying too low over urban areas. This would make it illegal for a ship to ever tie up to the building or even approach the area.',
#  'was an existing law against airships flying too low over urban areas... this would make it illegal for a ship to ever tie up to the building or even approach the area.',
#  'was destroyed by fire in @LOCATION1.',
#  'was neither practical nor safe',
#  'was neither practical nor safe.',
#  'weighted down with lead weights... where they would be dangling high above pedestrians on the street.',
#  'were constantly shifting due to violent air currents',
#  'were constantly shifting due to violent air currents.',
#  'were constantly shifting.',
#  'were neither practical nor safe.',
#  'when the German dirigible ',
#  'when the German dirigible Hindenburg was destroyed by fire in Lakehurst, New Jersey on May 6, 1937, the owners of the Empire state building realized how much worse that accident could have been if it had taken place above a densely populated area such as downtown New York.',
#  'when the German dirigible Hindenburg was destroyed by fire in Lakehurst, New Jersey, on May 6, 1937, the Owners of the Empire State Building realized how much worse the accident could have been if it had taken place above a densely populated area such as downtown New York.',
#  'where they would be dangling high above Pedestrians on the street, was neither practical or safe.',
#  'where they would be dangling high above pedestrians on the street, was neither practical nor safe',
#  'which was nearly eleven hundred feet below.',
#  'wind would blow the dirigible onto sharp spires,',
#  'winds on top of the building',
#  'winds on top of the building were constantly shifting due to violent air currents',
#  'winds on top of the building were constantly shifting due to violent air currents.',
#  'winds on top of the building... shifting due to... air currents',
#  'would add stress',
#  "would add stress to the building's frame",
#  "would add stress to the building's frame,",
#  'would add stress to the building.',
#  'would be dangling above pedestrians.',
#  'would be dangling high above pedestrians on the street,',
#  'would be equipped For an age of transportation that was then only the dream of aviation pioneers',
#  'would have to be modified and strengthened to accommodate this new situation',
#  'would make it illegal for a ship to ever tie up to the building or even approach the area.',
#  'would make it illegal for ship to ever tie up to the building or even approach the area. Unless the law was revoked, the mooring mast would never be able to work. However, the obstacle that the builders faced when designing the actual mast itself were that '}

# %%
set6[set6['domain1_score'] == 4]['essay'].sample(1).iloc[0]
# Out:
# "The dream for the Empire State Building was to allow dirigibles to dock On the top of it. It sounded like a great idea but the builders faced many obstacles trying to reach the goal of having them dock there. The first problem they faced was that dirigible's load and the wind pressure would have to be transmitted to the buildings foundation so it wouldn't stress the building's frame. To do this over sixty thousand dollars worth of modifications had been made. A glass and chrome nickel steel tower was made with a illuminated inside. The building was now 102 floors. Even though all the hard work the building was never used for docking purposes because of safety. One of the safety obstacles was that dirigibles wer highly flamable, after one caught on fire in New Jersey the owners of the Empire State building didn't want the same to happy in the highly populated New York City. Also another big obstacle was caused by the terrible winds. Even though there was a landing sight the dirigible could never be tied down so the passengers could get off. Also there was a law that stated the air craft's can't fly to low to urban areas. Through all the money and obstacles the builders had to go through to make this dream possible was never achieved."

# %%
set6essay_quotes = ['one of safety', 'dirigibles from outside of the United States used hydrogen instead of helium', 'nature itself', 'winds on top of the building were constantly shifting', 'violent air currents', 'law against airships flying too low over urban areas', 'moored in open landing fields', 'could be weighted down in the back with lead weights', 'dangling high above pedestrians on the street was neither practical nor safe', 'swivel around and around the mooring mast', 'how much worse that accident could have been', 'could not simply drop a mooring mast on top of the empire state building flat roof', 'stress of the dirigible load', 'mooring air ships to a fixed mast', 'neither practical nor safe']

# %%
max([len(i.split()) for i in set6essay_quotes])
# Out:
# 16

# %%
import pandas as pd
set3 = pd.read_csv('set3_features.csv')
set4 = pd.read_csv('set4_features.csv')

# %%
set3['domain1_score'].value_counts()
# Out:
# 2    657
# 1    607
# 3    423
# 0     39
# Name: domain1_score, dtype: int64

# %%
set4['domain1_score'].value_counts()
# Out:
# 1    636
# 2    570
# 0    311
# 3    253
# Name: domain1_score, dtype: int64
